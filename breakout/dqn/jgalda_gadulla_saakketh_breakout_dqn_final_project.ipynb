# %%
# !sudo update-alternatives --config python3
# Out:
# There are 2 choices for the alternative python3 (providing /usr/bin/python3).
#
#   Selection    Path                 Priority   Status
# ------------------------------------------------------------
# * 0            /usr/bin/python3.12   2         auto mode
#   1            /usr/bin/python3.10   1         manual mode
#   2            /usr/bin/python3.12   2         manual mode
#
# Press <enter> to keep the current choice[*], or type selection number: 1
# update-alternatives: using /usr/bin/python3.10 to provide /usr/bin/python3 (python3) in manual mode

# %%
# !python3 -m pip install --upgrade pip
# !python3 -m pip install "gymnasium[atari]" ale-py autorom
# Out:
# /usr/bin/python3: No module named pip
# /usr/bin/python3: No module named pip

# %%
# !which python3
# !python3 --version
# Out:
# /usr/bin/python3
# Python 3.10.12

# %%
# !wget https://bootstrap.pypa.io/get-pip.py
# !python3 get-pip.py
# Out:
# --2025-12-03 07:08:19--  https://bootstrap.pypa.io/get-pip.py
# Resolving bootstrap.pypa.io (bootstrap.pypa.io)... 151.101.0.175, 151.101.64.175, 151.101.128.175, ...
# Connecting to bootstrap.pypa.io (bootstrap.pypa.io)|151.101.0.175|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2182415 (2.1M) [text/x-python]
# Saving to: ‘get-pip.py’
#
# get-pip.py          100%[===================>]   2.08M  --.-KB/s    in 0.008s
#
# 2025-12-03 07:08:19 (249 MB/s) - ‘get-pip.py’ saved [2182415/2182415]
#
# Collecting pip
#   Downloading pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Collecting setuptools
#   Downloading setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting wheel
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Downloading pip-25.3-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 49.7 MB/s  0:00:00
# Downloading setuptools-80.9.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 50.9 MB/s  0:00:00
# Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
# Installing collected packages: wheel, setuptools, pip
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pip]
# Successfully installed pip-25.3 setuptools-80.9.0 wheel-0.45.1

# %%
# !python3 -m pip --version
# Out:
# pip 25.3 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)

# %%
# !python3 -m pip install "gymnasium[atari]==0.29.1"
# !python3 -m pip install "ale-py==0.8.1"
# !python3 -m pip install autorom
# Out:
# Collecting gymnasium==0.29.1 (from gymnasium[atari]==0.29.1)
#   Downloading gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Collecting numpy>=1.21.0 (from gymnasium==0.29.1->gymnasium[atari]==0.29.1)
#   Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting cloudpickle>=1.2.0 (from gymnasium==0.29.1->gymnasium[atari]==0.29.1)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-extensions>=4.3.0 (from gymnasium==0.29.1->gymnasium[atari]==0.29.1)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting farama-notifications>=0.0.1 (from gymnasium==0.29.1->gymnasium[atari]==0.29.1)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Collecting shimmy<1.0,>=0.1.0 (from shimmy[atari]<1.0,>=0.1.0; extra == "atari"->gymnasium[atari]==0.29.1)
#   Downloading Shimmy-0.2.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting ale-py~=0.8.1 (from shimmy[atari]<1.0,>=0.1.0; extra == "atari"->gymnasium[atari]==0.29.1)
#   Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Collecting importlib-resources (from ale-py~=0.8.1->shimmy[atari]<1.0,>=0.1.0; extra == "atari"->gymnasium[atari]==0.29.1)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 45.8 MB/s  0:00:00
# Downloading Shimmy-0.2.1-py3-none-any.whl (25 kB)
# Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 71.5 MB/s  0:00:00
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 171.0 MB/s  0:00:00
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Installing collected packages: farama-notifications, typing-extensions, numpy, importlib-resources, cloudpickle, gymnasium, ale-py, shimmy
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [shimmy]
# Successfully installed ale-py-0.8.1 cloudpickle-3.1.2 farama-notifications-0.0.4 gymnasium-0.29.1 importlib-resources-6.5.2 numpy-2.2.6 shimmy-0.2.1 typing-extensions-4.15.0
# Requirement already satisfied: ale-py==0.8.1 in /usr/local/lib/python3.10/dist-packages (0.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ale-py==0.8.1) (2.2.6)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py==0.8.1) (6.5.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from ale-py==0.8.1) (4.15.0)
# Collecting autorom
#   Downloading AutoROM-0.6.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting click (from autorom)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting requests (from autorom)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting charset_normalizer<4,>=2 (from requests->autorom)
#   Downloading charset_normalizer-3.4.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests->autorom)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->autorom)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests->autorom)
#   Downloading certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (153 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading certifi-2025.11.12-py3-none-any.whl (159 kB)
# Installing collected packages: urllib3, idna, click, charset_normalizer, certifi, requests, autorom
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [autorom]
# Successfully installed autorom-0.6.1 certifi-2025.11.12 charset_normalizer-3.4.4 click-8.3.1 idna-3.11 requests-2.32.5 urllib3-2.5.0

# %%
# !python3 -m pip install "gymnasium[atari]" ale-py AutoROM AutoROM.accept-rom-license

# !python3 -m AutoROM.accept_rom_license --accept-license
# Out:
# Requirement already satisfied: ale-py in /usr/local/lib/python3.10/dist-packages (0.8.1)
# Requirement already satisfied: AutoROM in /usr/local/lib/python3.10/dist-packages (0.6.1)
# Collecting AutoROM.accept-rom-license
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: gymnasium[atari] in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (2.2.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (0.0.4)
# Requirement already satisfied: shimmy<1.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from shimmy[atari]<1.0,>=0.1.0; extra == "atari"->gymnasium[atari]) (0.2.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py) (6.5.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from AutoROM) (8.3.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from AutoROM) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->AutoROM) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->AutoROM) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->AutoROM) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->AutoROM) (2025.11.12)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=autorom_accept_rom_license-0.6.1-py3-none-any.whl size=446709 sha256=40446691984c31a336fe4bb0f7e0e2693ce41c3705b38b85affcdb3da8e737c0
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: AutoROM.accept-rom-license
# Successfully installed AutoROM.accept-rom-license-0.6.1
# /usr/bin/python3: No module named AutoROM.accept_rom_license

# %%
import gymnasium as gym
import ale_py

gym.register_envs(ale_py)
print("Atari envs registered!")

gym.pprint_registry()
# Out:
# Atari envs registered!
# ===== classic_control =====
# Acrobot-v1                  CartPole-v0                 CartPole-v1
# MountainCar-v0              MountainCarContinuous-v0    Pendulum-v1
# ===== phys2d =====
# phys2d/CartPole-v0          phys2d/CartPole-v1          phys2d/Pendulum-v0
# ===== box2d =====
# BipedalWalker-v3            BipedalWalkerHardcore-v3    CarRacing-v3
# LunarLander-v3              LunarLanderContinuous-v3
# ===== toy_text =====
# Blackjack-v1                CliffWalking-v1             CliffWalkingSlippery-v1
# FrozenLake-v1               FrozenLake8x8-v1            Taxi-v3
# ===== tabular =====
# tabular/Blackjack-v0        tabular/CliffWalking-v0
# ===== None =====
# Ant-v2                      Ant-v3                      GymV21Environment-v0
# GymV26Environment-v0        HalfCheetah-v2              HalfCheetah-v3
# Hopper-v2                   Hopper-v3                   Humanoid-v2
# Humanoid-v3                 HumanoidStandup-v2          InvertedDoublePendulum-v2
# InvertedPendulum-v2         Pusher-v2                   Reacher-v2
# Swimmer-v2                  Swimmer-v3                  Walker2d-v2
# Walker2d-v3
# ===== mujoco =====
# Ant-v4                      Ant-v5                      HalfCheetah-v4
# HalfCheetah-v5              Hopper-v4                   Hopper-v5
# Humanoid-v4                 Humanoid-v5                 HumanoidStandup-v4
# HumanoidStandup-v5          InvertedDoublePendulum-v4   InvertedDoublePendulum-v5
# InvertedPendulum-v4         InvertedPendulum-v5         Pusher-v4
# Pusher-v5                   Reacher-v4                  Reacher-v5
# Swimmer-v4                  Swimmer-v5                  Walker2d-v4
# Walker2d-v5
# ===== env =====
# Adventure-v0                Adventure-v4                AdventureNoFrameskip-v0
# AdventureNoFrameskip-v4     AirRaid-v0                  AirRaid-v4
# AirRaidNoFrameskip-v0       AirRaidNoFrameskip-v4       Alien-v0
# Alien-v4                    AlienNoFrameskip-v0         AlienNoFrameskip-v4
# Amidar-v0                   Amidar-v4                   AmidarNoFrameskip-v0
# AmidarNoFrameskip-v4        Assault-v0                  Assault-v4
# AssaultNoFrameskip-v0       AssaultNoFrameskip-v4       Asterix-v0
# Asterix-v4                  AsterixNoFrameskip-v0       AsterixNoFrameskip-v4
# Asteroids-v0                Asteroids-v4                AsteroidsNoFrameskip-v0
# AsteroidsNoFrameskip-v4     Atlantis-v0                 Atlantis-v4
# AtlantisNoFrameskip-v0      AtlantisNoFrameskip-v4      BankHeist-v0
# BankHeist-v4                BankHeistNoFrameskip-v0     BankHeistNoFrameskip-v4
# BattleZone-v0               BattleZone-v4               BattleZoneNoFrameskip-v0
# BattleZoneNoFrameskip-v4    BeamRider-v0                BeamRider-v4
# BeamRiderNoFrameskip-v0     BeamRiderNoFrameskip-v4     Berzerk-v0
# Berzerk-v4                  BerzerkNoFrameskip-v0       BerzerkNoFrameskip-v4
# Bowling-v0                  Bowling-v4                  BowlingNoFrameskip-v0
# BowlingNoFrameskip-v4       Boxing-v0                   Boxing-v4
# BoxingNoFrameskip-v0        BoxingNoFrameskip-v4        Breakout-v0
# Breakout-v4                 BreakoutNoFrameskip-v0      BreakoutNoFrameskip-v4
# Carnival-v0                 Carnival-v4                 CarnivalNoFrameskip-v0
# CarnivalNoFrameskip-v4      Centipede-v0                Centipede-v4
# CentipedeNoFrameskip-v0     CentipedeNoFrameskip-v4     ChopperCommand-v0
# ChopperCommand-v4           ChopperCommandNoFrameskip-v0 ChopperCommandNoFrameskip-v4
# CrazyClimber-v0             CrazyClimber-v4             CrazyClimberNoFrameskip-v0
# CrazyClimberNoFrameskip-v4  Defender-v0                 Defender-v4
# DefenderNoFrameskip-v0      DefenderNoFrameskip-v4      DemonAttack-v0
# DemonAttack-v4              DemonAttackNoFrameskip-v0   DemonAttackNoFrameskip-v4
# DoubleDunk-v0               DoubleDunk-v4               DoubleDunkNoFrameskip-v0
# DoubleDunkNoFrameskip-v4    ElevatorAction-v0           ElevatorAction-v4
# ElevatorActionNoFrameskip-v0 ElevatorActionNoFrameskip-v4 Enduro-v0
# Enduro-v4                   EnduroNoFrameskip-v0        EnduroNoFrameskip-v4
# FishingDerby-v0             FishingDerby-v4             FishingDerbyNoFrameskip-v0
# FishingDerbyNoFrameskip-v4  Freeway-v0                  Freeway-v4
# FreewayNoFrameskip-v0       FreewayNoFrameskip-v4       Frostbite-v0
# Frostbite-v4                FrostbiteNoFrameskip-v0     FrostbiteNoFrameskip-v4
# Gopher-v0                   Gopher-v4                   GopherNoFrameskip-v0
# GopherNoFrameskip-v4        Gravitar-v0                 Gravitar-v4
# GravitarNoFrameskip-v0      GravitarNoFrameskip-v4      Hero-v0
# Hero-v4                     HeroNoFrameskip-v0          HeroNoFrameskip-v4
# IceHockey-v0                IceHockey-v4                IceHockeyNoFrameskip-v0
# IceHockeyNoFrameskip-v4     Jamesbond-v0                Jamesbond-v4
# JamesbondNoFrameskip-v0     JamesbondNoFrameskip-v4     JourneyEscape-v0
# JourneyEscape-v4            JourneyEscapeNoFrameskip-v0 JourneyEscapeNoFrameskip-v4
# Kangaroo-v0                 Kangaroo-v4                 KangarooNoFrameskip-v0
# KangarooNoFrameskip-v4      Krull-v0                    Krull-v4
# KrullNoFrameskip-v0         KrullNoFrameskip-v4         KungFuMaster-v0
# KungFuMaster-v4             KungFuMasterNoFrameskip-v0  KungFuMasterNoFrameskip-v4
# MontezumaRevenge-v0         MontezumaRevenge-v4         MontezumaRevengeNoFrameskip-v0
# MontezumaRevengeNoFrameskip-v4 MsPacman-v0                 MsPacman-v4
# MsPacmanNoFrameskip-v0      MsPacmanNoFrameskip-v4      NameThisGame-v0
# NameThisGame-v4             NameThisGameNoFrameskip-v0  NameThisGameNoFrameskip-v4
# Phoenix-v0                  Phoenix-v4                  PhoenixNoFrameskip-v0
# PhoenixNoFrameskip-v4       Pitfall-v0                  Pitfall-v4
# PitfallNoFrameskip-v0       PitfallNoFrameskip-v4       Pong-v0
# Pong-v4                     PongNoFrameskip-v0          PongNoFrameskip-v4
# Pooyan-v0                   Pooyan-v4                   PooyanNoFrameskip-v0
# PooyanNoFrameskip-v4        PrivateEye-v0               PrivateEye-v4
# PrivateEyeNoFrameskip-v0    PrivateEyeNoFrameskip-v4    Qbert-v0
# Qbert-v4                    QbertNoFrameskip-v0         QbertNoFrameskip-v4
# Riverraid-v0                Riverraid-v4                RiverraidNoFrameskip-v0
# RiverraidNoFrameskip-v4     RoadRunner-v0               RoadRunner-v4
# RoadRunnerNoFrameskip-v0    RoadRunnerNoFrameskip-v4    Robotank-v0
# Robotank-v4                 RobotankNoFrameskip-v0      RobotankNoFrameskip-v4
# Seaquest-v0                 Seaquest-v4                 SeaquestNoFrameskip-v0
# SeaquestNoFrameskip-v4      Skiing-v0                   Skiing-v4
# SkiingNoFrameskip-v0        SkiingNoFrameskip-v4        Solaris-v0
# Solaris-v4                  SolarisNoFrameskip-v0       SolarisNoFrameskip-v4
# SpaceInvaders-v0            SpaceInvaders-v4            SpaceInvadersNoFrameskip-v0
# SpaceInvadersNoFrameskip-v4 StarGunner-v0               StarGunner-v4
# StarGunnerNoFrameskip-v0    StarGunnerNoFrameskip-v4    Tennis-v0
# Tennis-v4                   TennisNoFrameskip-v0        TennisNoFrameskip-v4
# TimePilot-v0                TimePilot-v4                TimePilotNoFrameskip-v0
# TimePilotNoFrameskip-v4     Tutankham-v0                Tutankham-v4
# TutankhamNoFrameskip-v0     TutankhamNoFrameskip-v4     UpNDown-v0
# UpNDown-v4                  UpNDownNoFrameskip-v0       UpNDownNoFrameskip-v4
# Venture-v0                  Venture-v4                  VentureNoFrameskip-v0
# VentureNoFrameskip-v4       VideoPinball-v0             VideoPinball-v4
# VideoPinballNoFrameskip-v0  VideoPinballNoFrameskip-v4  WizardOfWor-v0
# WizardOfWor-v4              WizardOfWorNoFrameskip-v0   WizardOfWorNoFrameskip-v4
# YarsRevenge-v0              YarsRevenge-v4              YarsRevengeNoFrameskip-v0
# YarsRevengeNoFrameskip-v4   Zaxxon-v0                   Zaxxon-v4
# ZaxxonNoFrameskip-v0        ZaxxonNoFrameskip-v4
# ===== ALE =====
# ALE/Adventure-v5            ALE/AirRaid-v5              ALE/Alien-v5
# ALE/Amidar-v5               ALE/Assault-v5              ALE/Asterix-v5
# ALE/Asteroids-v5            ALE/Atlantis-v5             ALE/Atlantis2-v5
# ALE/Backgammon-v5           ALE/BankHeist-v5            ALE/BasicMath-v5
# ALE/BattleZone-v5           ALE/BeamRider-v5            ALE/Berzerk-v5
# ALE/Blackjack-v5            ALE/Bowling-v5              ALE/Boxing-v5
# ALE/Breakout-v5             ALE/Carnival-v5             ALE/Casino-v5
# ALE/Centipede-v5            ALE/ChopperCommand-v5       ALE/CrazyClimber-v5
# ALE/Crossbow-v5             ALE/Darkchambers-v5         ALE/Defender-v5
# ALE/DemonAttack-v5          ALE/DonkeyKong-v5           ALE/DoubleDunk-v5
# ALE/Earthworld-v5           ALE/ElevatorAction-v5       ALE/Enduro-v5
# ALE/Entombed-v5             ALE/Et-v5                   ALE/FishingDerby-v5
# ALE/FlagCapture-v5          ALE/Freeway-v5              ALE/Frogger-v5
# ALE/Frostbite-v5            ALE/Galaxian-v5             ALE/Gopher-v5
# ALE/Gravitar-v5             ALE/Hangman-v5              ALE/HauntedHouse-v5
# ALE/Hero-v5                 ALE/HumanCannonball-v5      ALE/IceHockey-v5
# ALE/Jamesbond-v5            ALE/JourneyEscape-v5        ALE/Kaboom-v5
# ALE/Kangaroo-v5             ALE/KeystoneKapers-v5       ALE/KingKong-v5
# ALE/Klax-v5                 ALE/Koolaid-v5              ALE/Krull-v5
# ALE/KungFuMaster-v5         ALE/LaserGates-v5           ALE/LostLuggage-v5
# ALE/MarioBros-v5            ALE/MiniatureGolf-v5        ALE/MontezumaRevenge-v5
# ALE/MrDo-v5                 ALE/MsPacman-v5             ALE/NameThisGame-v5
# ALE/Othello-v5              ALE/Pacman-v5               ALE/Phoenix-v5
# ALE/Pitfall-v5              ALE/Pitfall2-v5             ALE/Pong-v5
# ALE/Pooyan-v5               ALE/PrivateEye-v5           ALE/Qbert-v5
# ALE/Riverraid-v5            ALE/RoadRunner-v5           ALE/Robotank-v5
# ALE/Seaquest-v5             ALE/SirLancelot-v5          ALE/Skiing-v5
# ALE/Solaris-v5              ALE/SpaceInvaders-v5        ALE/SpaceWar-v5
# ALE/StarGunner-v5           ALE/Superman-v5             ALE/Surround-v5
# ALE/Tennis-v5               ALE/Tetris-v5               ALE/TicTacToe3D-v5
# ALE/TimePilot-v5            ALE/Trondead-v5             ALE/Turmoil-v5
# ALE/Tutankham-v5            ALE/UpNDown-v5              ALE/Venture-v5
# ALE/VideoCheckers-v5        ALE/VideoChess-v5           ALE/VideoCube-v5
# ALE/VideoPinball-v5         ALE/WizardOfWor-v5          ALE/WordZapper-v5
# ALE/YarsRevenge-v5          ALE/Zaxxon-v5

# %%
import gymnasium as gym
import ale_py
import numpy as np
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from collections import deque

gym.register_envs(ale_py)


class LazyFrames:
    def __init__(self, frames):
        self._frames = frames
    def __array__(self, dtype=None):
        out = np.concatenate(self._frames, axis=0)
        return out.astype(dtype) if dtype else out


class FrameStack:
    def __init__(self, env, k=4):
        self.env = env
        self.k = k
        self.frames = deque(maxlen=k)

    def reset(self):
        obs, info = self.env.reset()
        obs = np.expand_dims(obs, 0)
        for _ in range(self.k):
            self.frames.append(obs)
        return LazyFrames(list(self.frames)), info

    def step(self, action):
        obs, reward, terminated, truncated, info = self.env.step(action)
        obs = np.expand_dims(obs, 0)
        self.frames.append(obs)
        return LazyFrames(list(self.frames)), reward, terminated, truncated, info

    def close(self):
        if hasattr(self.env, "close"):
            self.env.close()



# 2. Breakout Environment

def make_env():

    env = gym.make("ALE/Breakout-v5", frameskip=1)

    env = gym.wrappers.AtariPreprocessing(
        env,
        grayscale_obs=True,
        frame_skip=4,
        screen_size=84
    )

    # Stack 4 frames
    env = FrameStack(env, k=4)
    return env




# DQN CNN

class DQN(nn.Module):
    def __init__(self, action_dim):
        super().__init__()
        self.conv1 = nn.Conv2d(4, 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)

        self.fc1 = nn.Linear(64 * 7 * 7, 512)
        self.out = nn.Linear(512, action_dim)

    def forward(self, x):
        x = x / 255.0
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        return self.out(x)



# Replay Buffer

class ReplayBuffer:
    def __init__(self, size=100_000):
        self.buffer = deque(maxlen=size)

    def add(self, s, a, r, ns, d):
        self.buffer.append((s, a, r, ns, d))

    def sample(self, batch_size):
        s, a, r, ns, d = zip(*random.sample(self.buffer, batch_size))
        return (
            np.array([np.array(x) for x in s], dtype=np.uint8),
            np.array(a),
            np.array(r),
            np.array([np.array(x) for x in ns], dtype=np.uint8),
            np.array(d),
        )

    def __len__(self):
        return len(self.buffer)



# DQN Agent

class DQNAgent:
    def __init__(self):
        self.env = make_env()
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        self.n_actions = self.env.env.action_space.n
        print("Action space:", self.n_actions)

        self.policy = DQN(self.n_actions).to(self.device)
        self.target = DQN(self.n_actions).to(self.device)
        self.target.load_state_dict(self.policy.state_dict())

        self.optimizer = optim.Adam(self.policy.parameters(), lr=1e-4)
        self.buffer = ReplayBuffer()

        self.gamma = 0.99
        self.batch = 32
        self.train_start = 10_000
        self.update_target_every = 5000

        self.eps = 1.0
        self.eps_min = 0.05
        self.eps_decay = 1_000_000
        self.step = 0

    # ε-greedy action
    def act(self, state):
        self.step += 1
        self.eps = max(self.eps_min, 1 - self.step / self.eps_decay)

        if random.random() < self.eps:
            return random.randint(0, self.n_actions - 1)

        s = torch.tensor(np.array(state), dtype=torch.float32).unsqueeze(0).to(self.device)
        with torch.no_grad():
            return torch.argmax(self.policy(s)).item()

    # Train step
    def train_step(self):
        if len(self.buffer) < self.train_start:
            return

        s, a, r, ns, d = self.buffer.sample(self.batch)

        s = torch.tensor(s, dtype=torch.float32, device=self.device)
        ns = torch.tensor(ns, dtype=torch.float32, device=self.device)
        a = torch.tensor(a, device=self.device).unsqueeze(1)
        r = torch.tensor(r, dtype=torch.float32, device=self.device).unsqueeze(1)
        d = torch.tensor(d, dtype=torch.float32, device=self.device).unsqueeze(1)

        q = self.policy(s).gather(1, a)

        with torch.no_grad():
            next_q = self.target(ns).max(1)[0].unsqueeze(1)
            target = r + self.gamma * next_q * (1 - d)

        loss = F.smooth_l1_loss(q, target)

        self.optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.policy.parameters(), 5)
        self.optimizer.step()

        if self.step % self.update_target_every == 0:
            self.target.load_state_dict(self.policy.state_dict())
            print(f"Target updated at step {self.step}")

    # Training loop
    def train(self, episodes=1000):
        for ep in range(1, episodes + 1):
            s, _ = self.env.reset()
            total_reward = 0

            for _ in range(20_000):
                a = self.act(s)
                ns, r, terminated, truncated, _ = self.env.step(a)

                self.buffer.add(s, a, r, ns, terminated)
                self.train_step()

                s = ns
                total_reward += r
                if terminated or truncated:
                    break

            print(f"Episode {ep} | Reward: {total_reward} | Epsilon {self.eps:.3f}")



# RUN TRAINING

agent = DQNAgent()
agent.train(episodes=1000)
# Out:
# Action space: 4
# Episode 1 | Reward: 1.0 | Epsilon 1.000
# Episode 2 | Reward: 0.0 | Epsilon 1.000
# Episode 3 | Reward: 1.0 | Epsilon 1.000
# Episode 4 | Reward: 2.0 | Epsilon 0.999
# Episode 5 | Reward: 0.0 | Epsilon 0.999
# Episode 6 | Reward: 0.0 | Epsilon 0.999
# Episode 7 | Reward: 2.0 | Epsilon 0.999
# Episode 8 | Reward: 0.0 | Epsilon 0.999
# Episode 9 | Reward: 0.0 | Epsilon 0.999
# Episode 10 | Reward: 1.0 | Epsilon 0.998
# Episode 11 | Reward: 0.0 | Epsilon 0.998
# Episode 12 | Reward: 1.0 | Epsilon 0.998
# Episode 13 | Reward: 4.0 | Epsilon 0.998
# Episode 14 | Reward: 0.0 | Epsilon 0.998
# Episode 15 | Reward: 0.0 | Epsilon 0.997
# Episode 16 | Reward: 0.0 | Epsilon 0.997
# Episode 17 | Reward: 0.0 | Epsilon 0.997
# Episode 18 | Reward: 1.0 | Epsilon 0.997
# Episode 19 | Reward: 2.0 | Epsilon 0.997
# Episode 20 | Reward: 1.0 | Epsilon 0.997
# Episode 21 | Reward: 3.0 | Epsilon 0.996
# Episode 22 | Reward: 1.0 | Epsilon 0.996
# Episode 23 | Reward: 2.0 | Epsilon 0.996
# Episode 24 | Reward: 1.0 | Epsilon 0.996
# Episode 25 | Reward: 3.0 | Epsilon 0.996
# Episode 26 | Reward: 0.0 | Epsilon 0.995
# Episode 27 | Reward: 1.0 | Epsilon 0.995
# Episode 28 | Reward: 1.0 | Epsilon 0.995
# Episode 29 | Reward: 0.0 | Epsilon 0.995
# Episode 30 | Reward: 0.0 | Epsilon 0.995
# Episode 31 | Reward: 7.0 | Epsilon 0.994
# Episode 32 | Reward: 1.0 | Epsilon 0.994
# Episode 33 | Reward: 0.0 | Epsilon 0.994
# Episode 34 | Reward: 1.0 | Epsilon 0.994
# Episode 35 | Reward: 5.0 | Epsilon 0.994
# Episode 36 | Reward: 2.0 | Epsilon 0.993
# Episode 37 | Reward: 0.0 | Epsilon 0.993
# Episode 38 | Reward: 3.0 | Epsilon 0.993
# Episode 39 | Reward: 1.0 | Epsilon 0.993
# Episode 40 | Reward: 3.0 | Epsilon 0.993
# Episode 41 | Reward: 1.0 | Epsilon 0.992
# Episode 42 | Reward: 1.0 | Epsilon 0.992
# Episode 43 | Reward: 1.0 | Epsilon 0.992
# Episode 44 | Reward: 0.0 | Epsilon 0.992
# Episode 45 | Reward: 1.0 | Epsilon 0.992
# Episode 46 | Reward: 1.0 | Epsilon 0.992
# Episode 47 | Reward: 0.0 | Epsilon 0.991
# Episode 48 | Reward: 0.0 | Epsilon 0.991
# Episode 49 | Reward: 1.0 | Epsilon 0.991
# Episode 50 | Reward: 0.0 | Epsilon 0.991
# Episode 51 | Reward: 2.0 | Epsilon 0.991
# Episode 52 | Reward: 2.0 | Epsilon 0.991
# Episode 53 | Reward: 0.0 | Epsilon 0.990
# Episode 54 | Reward: 0.0 | Epsilon 0.990
# Target updated at step 10000
# Episode 55 | Reward: 3.0 | Epsilon 0.990
# Episode 56 | Reward: 1.0 | Epsilon 0.990
# Episode 57 | Reward: 0.0 | Epsilon 0.990
# Episode 58 | Reward: 0.0 | Epsilon 0.990
# Episode 59 | Reward: 0.0 | Epsilon 0.989
# Episode 60 | Reward: 4.0 | Epsilon 0.989
# Episode 61 | Reward: 0.0 | Epsilon 0.989
# Episode 62 | Reward: 3.0 | Epsilon 0.989
# Episode 63 | Reward: 0.0 | Epsilon 0.989
# Episode 64 | Reward: 2.0 | Epsilon 0.988
# Episode 65 | Reward: 2.0 | Epsilon 0.988
# Episode 66 | Reward: 2.0 | Epsilon 0.988
# Episode 67 | Reward: 2.0 | Epsilon 0.988
# Episode 68 | Reward: 2.0 | Epsilon 0.987
# Episode 69 | Reward: 4.0 | Epsilon 0.987
# Episode 70 | Reward: 3.0 | Epsilon 0.987
# Episode 71 | Reward: 1.0 | Epsilon 0.987
# Episode 72 | Reward: 0.0 | Epsilon 0.987
# Episode 73 | Reward: 2.0 | Epsilon 0.986
# Episode 74 | Reward: 1.0 | Epsilon 0.986
# Episode 75 | Reward: 2.0 | Epsilon 0.986
# Episode 76 | Reward: 0.0 | Epsilon 0.986
# Episode 77 | Reward: 2.0 | Epsilon 0.986
# Episode 78 | Reward: 0.0 | Epsilon 0.985
# Episode 79 | Reward: 3.0 | Epsilon 0.985
# Episode 80 | Reward: 1.0 | Epsilon 0.985
# Target updated at step 15000
# Episode 81 | Reward: 1.0 | Epsilon 0.985
# Episode 82 | Reward: 3.0 | Epsilon 0.985
# Episode 83 | Reward: 0.0 | Epsilon 0.984
# Episode 84 | Reward: 2.0 | Epsilon 0.984
# Episode 85 | Reward: 0.0 | Epsilon 0.984
# Episode 86 | Reward: 0.0 | Epsilon 0.984
# Episode 87 | Reward: 0.0 | Epsilon 0.984
# Episode 88 | Reward: 0.0 | Epsilon 0.984
# Episode 89 | Reward: 3.0 | Epsilon 0.983
# Episode 90 | Reward: 2.0 | Epsilon 0.983
# Episode 91 | Reward: 3.0 | Epsilon 0.983
# Episode 92 | Reward: 0.0 | Epsilon 0.983
# Episode 93 | Reward: 2.0 | Epsilon 0.983
# Episode 94 | Reward: 0.0 | Epsilon 0.982
# Episode 95 | Reward: 0.0 | Epsilon 0.982
# Episode 96 | Reward: 0.0 | Epsilon 0.982
# Episode 97 | Reward: 0.0 | Epsilon 0.982
# Episode 98 | Reward: 3.0 | Epsilon 0.982
# Episode 99 | Reward: 0.0 | Epsilon 0.982
# Episode 100 | Reward: 1.0 | Epsilon 0.981
# Episode 101 | Reward: 0.0 | Epsilon 0.981
# Episode 102 | Reward: 2.0 | Epsilon 0.981
# Episode 103 | Reward: 0.0 | Epsilon 0.981
# Episode 104 | Reward: 2.0 | Epsilon 0.981
# Episode 105 | Reward: 0.0 | Epsilon 0.981
# Episode 106 | Reward: 2.0 | Epsilon 0.980
# Episode 107 | Reward: 0.0 | Epsilon 0.980
# Episode 108 | Reward: 3.0 | Epsilon 0.980
# Target updated at step 20000
# Episode 109 | Reward: 0.0 | Epsilon 0.980
# Episode 110 | Reward: 4.0 | Epsilon 0.980
# Episode 111 | Reward: 1.0 | Epsilon 0.979
# Episode 112 | Reward: 5.0 | Epsilon 0.979
# Episode 113 | Reward: 1.0 | Epsilon 0.979
# Episode 114 | Reward: 0.0 | Epsilon 0.979
# Episode 115 | Reward: 2.0 | Epsilon 0.979
# Episode 116 | Reward: 0.0 | Epsilon 0.978
# Episode 117 | Reward: 2.0 | Epsilon 0.978
# Episode 118 | Reward: 1.0 | Epsilon 0.978
# Episode 119 | Reward: 0.0 | Epsilon 0.978
# Episode 120 | Reward: 1.0 | Epsilon 0.978
# Episode 121 | Reward: 1.0 | Epsilon 0.978
# Episode 122 | Reward: 1.0 | Epsilon 0.977
# Episode 123 | Reward: 1.0 | Epsilon 0.977
# Episode 124 | Reward: 0.0 | Epsilon 0.977
# Episode 125 | Reward: 2.0 | Epsilon 0.977
# Episode 126 | Reward: 1.0 | Epsilon 0.977
# Episode 127 | Reward: 2.0 | Epsilon 0.977
# Episode 128 | Reward: 2.0 | Epsilon 0.976
# Episode 129 | Reward: 4.0 | Epsilon 0.976
# Episode 130 | Reward: 3.0 | Epsilon 0.976
# Episode 131 | Reward: 0.0 | Epsilon 0.976
# Episode 132 | Reward: 3.0 | Epsilon 0.975
# Episode 133 | Reward: 1.0 | Epsilon 0.975
# Target updated at step 25000
# Episode 134 | Reward: 3.0 | Epsilon 0.975
# Episode 135 | Reward: 2.0 | Epsilon 0.975
# Episode 136 | Reward: 0.0 | Epsilon 0.975
# Episode 137 | Reward: 10.0 | Epsilon 0.974
# Episode 138 | Reward: 1.0 | Epsilon 0.974
# Episode 139 | Reward: 4.0 | Epsilon 0.974
# Episode 140 | Reward: 3.0 | Epsilon 0.973
# Episode 141 | Reward: 2.0 | Epsilon 0.973
# Episode 142 | Reward: 0.0 | Epsilon 0.973
# Episode 143 | Reward: 1.0 | Epsilon 0.973
# Episode 144 | Reward: 1.0 | Epsilon 0.973
# Episode 145 | Reward: 0.0 | Epsilon 0.973
# Episode 146 | Reward: 0.0 | Epsilon 0.972
# Episode 147 | Reward: 1.0 | Epsilon 0.972
# Episode 148 | Reward: 0.0 | Epsilon 0.972
# Episode 149 | Reward: 8.0 | Epsilon 0.972
# Episode 150 | Reward: 1.0 | Epsilon 0.972
# Episode 151 | Reward: 0.0 | Epsilon 0.971
# Episode 152 | Reward: 0.0 | Epsilon 0.971
# Episode 153 | Reward: 0.0 | Epsilon 0.971
# Episode 154 | Reward: 1.0 | Epsilon 0.971
# Episode 155 | Reward: 0.0 | Epsilon 0.971
# Episode 156 | Reward: 1.0 | Epsilon 0.971
# Episode 157 | Reward: 1.0 | Epsilon 0.970
# Episode 158 | Reward: 4.0 | Epsilon 0.970
# Episode 159 | Reward: 0.0 | Epsilon 0.970
# Target updated at step 30000
# Episode 160 | Reward: 0.0 | Epsilon 0.970
# Episode 161 | Reward: 1.0 | Epsilon 0.970
# Episode 162 | Reward: 0.0 | Epsilon 0.970
# Episode 163 | Reward: 2.0 | Epsilon 0.969
# Episode 164 | Reward: 0.0 | Epsilon 0.969
# Episode 165 | Reward: 1.0 | Epsilon 0.969
# Episode 166 | Reward: 1.0 | Epsilon 0.969
# Episode 167 | Reward: 0.0 | Epsilon 0.969
# Episode 168 | Reward: 1.0 | Epsilon 0.969
# Episode 169 | Reward: 1.0 | Epsilon 0.968
# Episode 170 | Reward: 0.0 | Epsilon 0.968
# Episode 171 | Reward: 4.0 | Epsilon 0.968
# Episode 172 | Reward: 1.0 | Epsilon 0.968
# Episode 173 | Reward: 3.0 | Epsilon 0.967
# Episode 174 | Reward: 2.0 | Epsilon 0.967
# Episode 175 | Reward: 2.0 | Epsilon 0.967
# Episode 176 | Reward: 0.0 | Epsilon 0.967
# Episode 177 | Reward: 4.0 | Epsilon 0.967
# Episode 178 | Reward: 0.0 | Epsilon 0.966
# Episode 179 | Reward: 3.0 | Epsilon 0.966
# Episode 180 | Reward: 3.0 | Epsilon 0.966
# Episode 181 | Reward: 1.0 | Epsilon 0.966
# Episode 182 | Reward: 2.0 | Epsilon 0.966
# Episode 183 | Reward: 3.0 | Epsilon 0.965
# Episode 184 | Reward: 3.0 | Epsilon 0.965
# Target updated at step 35000
# Episode 185 | Reward: 2.0 | Epsilon 0.965
# Episode 186 | Reward: 0.0 | Epsilon 0.965
# Episode 187 | Reward: 4.0 | Epsilon 0.964
# Episode 188 | Reward: 1.0 | Epsilon 0.964
# Episode 189 | Reward: 4.0 | Epsilon 0.964
# Episode 190 | Reward: 2.0 | Epsilon 0.964
# Episode 191 | Reward: 3.0 | Epsilon 0.963
# Episode 192 | Reward: 2.0 | Epsilon 0.963
# Episode 193 | Reward: 0.0 | Epsilon 0.963
# Episode 194 | Reward: 2.0 | Epsilon 0.963
# Episode 195 | Reward: 2.0 | Epsilon 0.963
# Episode 196 | Reward: 1.0 | Epsilon 0.962
# Episode 197 | Reward: 2.0 | Epsilon 0.962
# Episode 198 | Reward: 1.0 | Epsilon 0.962
# Episode 199 | Reward: 3.0 | Epsilon 0.962
# Episode 200 | Reward: 0.0 | Epsilon 0.962
# Episode 201 | Reward: 1.0 | Epsilon 0.962
# Episode 202 | Reward: 0.0 | Epsilon 0.961
# Episode 203 | Reward: 1.0 | Epsilon 0.961
# Episode 204 | Reward: 1.0 | Epsilon 0.961
# Episode 205 | Reward: 1.0 | Epsilon 0.961
# Episode 206 | Reward: 2.0 | Epsilon 0.961
# Episode 207 | Reward: 2.0 | Epsilon 0.960
# Episode 208 | Reward: 0.0 | Epsilon 0.960
# Episode 209 | Reward: 2.0 | Epsilon 0.960
# Target updated at step 40000
# Episode 210 | Reward: 1.0 | Epsilon 0.960
# Episode 211 | Reward: 0.0 | Epsilon 0.960
# Episode 212 | Reward: 0.0 | Epsilon 0.960
# Episode 213 | Reward: 1.0 | Epsilon 0.959
# Episode 214 | Reward: 0.0 | Epsilon 0.959
# Episode 215 | Reward: 3.0 | Epsilon 0.959
# Episode 216 | Reward: 0.0 | Epsilon 0.959
# Episode 217 | Reward: 1.0 | Epsilon 0.959
# Episode 218 | Reward: 0.0 | Epsilon 0.959
# Episode 219 | Reward: 0.0 | Epsilon 0.958
# Episode 220 | Reward: 1.0 | Epsilon 0.958
# Episode 221 | Reward: 0.0 | Epsilon 0.958
# Episode 222 | Reward: 0.0 | Epsilon 0.958
# Episode 223 | Reward: 1.0 | Epsilon 0.958
# Episode 224 | Reward: 3.0 | Epsilon 0.958
# Episode 225 | Reward: 1.0 | Epsilon 0.957
# Episode 226 | Reward: 1.0 | Epsilon 0.957
# Episode 227 | Reward: 3.0 | Epsilon 0.957
# Episode 228 | Reward: 0.0 | Epsilon 0.957
# Episode 229 | Reward: 1.0 | Epsilon 0.957
# Episode 230 | Reward: 0.0 | Epsilon 0.956
# Episode 231 | Reward: 1.0 | Epsilon 0.956
# Episode 232 | Reward: 1.0 | Epsilon 0.956
# Episode 233 | Reward: 3.0 | Epsilon 0.956
# Episode 234 | Reward: 2.0 | Epsilon 0.956
# Episode 235 | Reward: 0.0 | Epsilon 0.956
# Episode 236 | Reward: 1.0 | Epsilon 0.955
# Episode 237 | Reward: 4.0 | Epsilon 0.955
# Target updated at step 45000
# Episode 238 | Reward: 1.0 | Epsilon 0.955
# Episode 239 | Reward: 1.0 | Epsilon 0.955
# Episode 240 | Reward: 1.0 | Epsilon 0.955
# Episode 241 | Reward: 0.0 | Epsilon 0.954
# Episode 242 | Reward: 2.0 | Epsilon 0.954
# Episode 243 | Reward: 0.0 | Epsilon 0.954
# Episode 244 | Reward: 1.0 | Epsilon 0.954
# Episode 245 | Reward: 1.0 | Epsilon 0.954
# Episode 246 | Reward: 0.0 | Epsilon 0.954
# Episode 247 | Reward: 0.0 | Epsilon 0.953
# Episode 248 | Reward: 4.0 | Epsilon 0.953
# Episode 249 | Reward: 1.0 | Epsilon 0.953
# Episode 250 | Reward: 1.0 | Epsilon 0.953
# Episode 251 | Reward: 0.0 | Epsilon 0.953
# Episode 252 | Reward: 1.0 | Epsilon 0.952
# Episode 253 | Reward: 0.0 | Epsilon 0.952
# Episode 254 | Reward: 0.0 | Epsilon 0.952
# Episode 255 | Reward: 0.0 | Epsilon 0.952
# Episode 256 | Reward: 0.0 | Epsilon 0.952
# Episode 257 | Reward: 0.0 | Epsilon 0.952
# Episode 258 | Reward: 2.0 | Epsilon 0.952
# Episode 259 | Reward: 1.0 | Epsilon 0.951
# Episode 260 | Reward: 0.0 | Epsilon 0.951
# Episode 261 | Reward: 2.0 | Epsilon 0.951
# Episode 262 | Reward: 2.0 | Epsilon 0.951
# Episode 263 | Reward: 0.0 | Epsilon 0.951
# Episode 264 | Reward: 3.0 | Epsilon 0.950
# Episode 265 | Reward: 3.0 | Epsilon 0.950
# Target updated at step 50000
# Episode 266 | Reward: 2.0 | Epsilon 0.950
# Episode 267 | Reward: 1.0 | Epsilon 0.950
# Episode 268 | Reward: 0.0 | Epsilon 0.950
# Episode 269 | Reward: 0.0 | Epsilon 0.949
# Episode 270 | Reward: 0.0 | Epsilon 0.949
# Episode 271 | Reward: 0.0 | Epsilon 0.949
# Episode 272 | Reward: 2.0 | Epsilon 0.949
# Episode 273 | Reward: 1.0 | Epsilon 0.949
# Episode 274 | Reward: 2.0 | Epsilon 0.949
# Episode 275 | Reward: 0.0 | Epsilon 0.948
# Episode 276 | Reward: 2.0 | Epsilon 0.948
# Episode 277 | Reward: 1.0 | Epsilon 0.948
# Episode 278 | Reward: 0.0 | Epsilon 0.948
# Episode 279 | Reward: 0.0 | Epsilon 0.948
# Episode 280 | Reward: 0.0 | Epsilon 0.948
# Episode 281 | Reward: 1.0 | Epsilon 0.948
# Episode 282 | Reward: 1.0 | Epsilon 0.947
# Episode 283 | Reward: 0.0 | Epsilon 0.947
# Episode 284 | Reward: 2.0 | Epsilon 0.947
# Episode 285 | Reward: 0.0 | Epsilon 0.947
# Episode 286 | Reward: 0.0 | Epsilon 0.947
# Episode 287 | Reward: 0.0 | Epsilon 0.947
# Episode 288 | Reward: 0.0 | Epsilon 0.946
# Episode 289 | Reward: 0.0 | Epsilon 0.946
# Episode 290 | Reward: 2.0 | Epsilon 0.946
# Episode 291 | Reward: 1.0 | Epsilon 0.946
# Episode 292 | Reward: 0.0 | Epsilon 0.946
# Episode 293 | Reward: 0.0 | Epsilon 0.946
# Episode 294 | Reward: 0.0 | Epsilon 0.946
# Episode 295 | Reward: 1.0 | Epsilon 0.945
# Episode 296 | Reward: 2.0 | Epsilon 0.945
# Target updated at step 55000
# Episode 297 | Reward: 0.0 | Epsilon 0.945
# Episode 298 | Reward: 2.0 | Epsilon 0.945
# Episode 299 | Reward: 0.0 | Epsilon 0.945
# Episode 300 | Reward: 4.0 | Epsilon 0.944
# Episode 301 | Reward: 2.0 | Epsilon 0.944
# Episode 302 | Reward: 1.0 | Epsilon 0.944
# Episode 303 | Reward: 1.0 | Epsilon 0.944
# Episode 304 | Reward: 2.0 | Epsilon 0.943
# Episode 305 | Reward: 3.0 | Epsilon 0.943
# Episode 306 | Reward: 3.0 | Epsilon 0.943
# Episode 307 | Reward: 2.0 | Epsilon 0.943
# Episode 308 | Reward: 1.0 | Epsilon 0.943
# Episode 309 | Reward: 0.0 | Epsilon 0.942
# Episode 310 | Reward: 1.0 | Epsilon 0.942
# Episode 311 | Reward: 0.0 | Epsilon 0.942
# Episode 312 | Reward: 0.0 | Epsilon 0.942
# Episode 313 | Reward: 2.0 | Epsilon 0.942
# Episode 314 | Reward: 2.0 | Epsilon 0.942
# Episode 315 | Reward: 1.0 | Epsilon 0.941
# Episode 316 | Reward: 0.0 | Epsilon 0.941
# Episode 317 | Reward: 0.0 | Epsilon 0.941
# Episode 318 | Reward: 1.0 | Epsilon 0.941
# Episode 319 | Reward: 3.0 | Epsilon 0.941
# Episode 320 | Reward: 2.0 | Epsilon 0.940
# Episode 321 | Reward: 1.0 | Epsilon 0.940
# Episode 322 | Reward: 0.0 | Epsilon 0.940
# Target updated at step 60000
# Episode 323 | Reward: 3.0 | Epsilon 0.940
# Episode 324 | Reward: 2.0 | Epsilon 0.940
# Episode 325 | Reward: 3.0 | Epsilon 0.939
# Episode 326 | Reward: 3.0 | Epsilon 0.939
# Episode 327 | Reward: 0.0 | Epsilon 0.939
# Episode 328 | Reward: 1.0 | Epsilon 0.939
# Episode 329 | Reward: 0.0 | Epsilon 0.939
# Episode 330 | Reward: 1.0 | Epsilon 0.939
# Episode 331 | Reward: 6.0 | Epsilon 0.938
# Episode 332 | Reward: 1.0 | Epsilon 0.938
# Episode 333 | Reward: 2.0 | Epsilon 0.938
# Episode 334 | Reward: 0.0 | Epsilon 0.938
# Episode 335 | Reward: 3.0 | Epsilon 0.937
# Episode 336 | Reward: 1.0 | Epsilon 0.937
# Episode 337 | Reward: 1.0 | Epsilon 0.937
# Episode 338 | Reward: 0.0 | Epsilon 0.937
# Episode 339 | Reward: 3.0 | Epsilon 0.937
# Episode 340 | Reward: 1.0 | Epsilon 0.937
# Episode 341 | Reward: 0.0 | Epsilon 0.936
# Episode 342 | Reward: 0.0 | Epsilon 0.936
# Episode 343 | Reward: 1.0 | Epsilon 0.936
# Episode 344 | Reward: 2.0 | Epsilon 0.936
# Episode 345 | Reward: 0.0 | Epsilon 0.936
# Episode 346 | Reward: 1.0 | Epsilon 0.936
# Episode 347 | Reward: 0.0 | Epsilon 0.935
# Episode 348 | Reward: 0.0 | Epsilon 0.935
# Episode 349 | Reward: 1.0 | Epsilon 0.935
# Target updated at step 65000
# Episode 350 | Reward: 1.0 | Epsilon 0.935
# Episode 351 | Reward: 0.0 | Epsilon 0.935
# Episode 352 | Reward: 3.0 | Epsilon 0.935
# Episode 353 | Reward: 0.0 | Epsilon 0.934
# Episode 354 | Reward: 2.0 | Epsilon 0.934
# Episode 355 | Reward: 3.0 | Epsilon 0.934
# Episode 356 | Reward: 8.0 | Epsilon 0.934
# Episode 357 | Reward: 1.0 | Epsilon 0.933
# Episode 358 | Reward: 1.0 | Epsilon 0.933
# Episode 359 | Reward: 7.0 | Epsilon 0.933
# Episode 360 | Reward: 1.0 | Epsilon 0.933
# Episode 361 | Reward: 2.0 | Epsilon 0.933
# Episode 362 | Reward: 0.0 | Epsilon 0.932
# Episode 363 | Reward: 2.0 | Epsilon 0.932
# Episode 364 | Reward: 1.0 | Epsilon 0.932
# Episode 365 | Reward: 2.0 | Epsilon 0.932
# Episode 366 | Reward: 2.0 | Epsilon 0.932
# Episode 367 | Reward: 0.0 | Epsilon 0.931
# Episode 368 | Reward: 1.0 | Epsilon 0.931
# Episode 369 | Reward: 3.0 | Epsilon 0.931
# Episode 370 | Reward: 0.0 | Epsilon 0.931
# Episode 371 | Reward: 1.0 | Epsilon 0.931
# Episode 372 | Reward: 1.0 | Epsilon 0.931
# Episode 373 | Reward: 0.0 | Epsilon 0.930
# Episode 374 | Reward: 1.0 | Epsilon 0.930
# Target updated at step 70000
# Episode 375 | Reward: 2.0 | Epsilon 0.930
# Episode 376 | Reward: 4.0 | Epsilon 0.930
# Episode 377 | Reward: 0.0 | Epsilon 0.930
# Episode 378 | Reward: 1.0 | Epsilon 0.929
# Episode 379 | Reward: 2.0 | Epsilon 0.929
# Episode 380 | Reward: 1.0 | Epsilon 0.929
# Episode 381 | Reward: 1.0 | Epsilon 0.929
# Episode 382 | Reward: 5.0 | Epsilon 0.928
# Episode 383 | Reward: 1.0 | Epsilon 0.928
# Episode 384 | Reward: 3.0 | Epsilon 0.928
# Episode 385 | Reward: 0.0 | Epsilon 0.928
# Episode 386 | Reward: 0.0 | Epsilon 0.928
# Episode 387 | Reward: 0.0 | Epsilon 0.928
# Episode 388 | Reward: 2.0 | Epsilon 0.927
# Episode 389 | Reward: 0.0 | Epsilon 0.927
# Episode 390 | Reward: 0.0 | Epsilon 0.927
# Episode 391 | Reward: 0.0 | Epsilon 0.927
# Episode 392 | Reward: 1.0 | Epsilon 0.927
# Episode 393 | Reward: 1.0 | Epsilon 0.927
# Episode 394 | Reward: 3.0 | Epsilon 0.926
# Episode 395 | Reward: 0.0 | Epsilon 0.926
# Episode 396 | Reward: 2.0 | Epsilon 0.926
# Episode 397 | Reward: 3.0 | Epsilon 0.926
# Episode 398 | Reward: 0.0 | Epsilon 0.926
# Episode 399 | Reward: 1.0 | Epsilon 0.925
# Episode 400 | Reward: 1.0 | Epsilon 0.925
# Episode 401 | Reward: 0.0 | Epsilon 0.925
# Target updated at step 75000
# Episode 402 | Reward: 2.0 | Epsilon 0.925
# Episode 403 | Reward: 1.0 | Epsilon 0.925
# Episode 404 | Reward: 0.0 | Epsilon 0.925
# Episode 405 | Reward: 2.0 | Epsilon 0.924
# Episode 406 | Reward: 0.0 | Epsilon 0.924
# Episode 407 | Reward: 1.0 | Epsilon 0.924
# Episode 408 | Reward: 5.0 | Epsilon 0.924
# Episode 409 | Reward: 7.0 | Epsilon 0.923
# Episode 410 | Reward: 1.0 | Epsilon 0.923
# Episode 411 | Reward: 3.0 | Epsilon 0.923
# Episode 412 | Reward: 1.0 | Epsilon 0.923
# Episode 413 | Reward: 2.0 | Epsilon 0.922
# Episode 414 | Reward: 1.0 | Epsilon 0.922
# Episode 415 | Reward: 2.0 | Epsilon 0.922
# Episode 416 | Reward: 2.0 | Epsilon 0.922
# Episode 417 | Reward: 1.0 | Epsilon 0.922
# Episode 418 | Reward: 2.0 | Epsilon 0.921
# Episode 419 | Reward: 0.0 | Epsilon 0.921
# Episode 420 | Reward: 0.0 | Epsilon 0.921
# Episode 421 | Reward: 0.0 | Epsilon 0.921
# Episode 422 | Reward: 0.0 | Epsilon 0.921
# Episode 423 | Reward: 3.0 | Epsilon 0.921
# Episode 424 | Reward: 2.0 | Epsilon 0.920
# Episode 425 | Reward: 4.0 | Epsilon 0.920
# Target updated at step 80000
# Episode 426 | Reward: 2.0 | Epsilon 0.920
# Episode 427 | Reward: 0.0 | Epsilon 0.920
# Episode 428 | Reward: 2.0 | Epsilon 0.920
# Episode 429 | Reward: 2.0 | Epsilon 0.919
# Episode 430 | Reward: 2.0 | Epsilon 0.919
# Episode 431 | Reward: 4.0 | Epsilon 0.919
# Episode 432 | Reward: 0.0 | Epsilon 0.919
# Episode 433 | Reward: 0.0 | Epsilon 0.919
# Episode 434 | Reward: 1.0 | Epsilon 0.918
# Episode 435 | Reward: 0.0 | Epsilon 0.918
# Episode 436 | Reward: 1.0 | Epsilon 0.918
# Episode 437 | Reward: 2.0 | Epsilon 0.918
# Episode 438 | Reward: 0.0 | Epsilon 0.918
# Episode 439 | Reward: 2.0 | Epsilon 0.917
# Episode 440 | Reward: 2.0 | Epsilon 0.917
# Episode 441 | Reward: 6.0 | Epsilon 0.917
# Episode 442 | Reward: 6.0 | Epsilon 0.917
# Episode 443 | Reward: 0.0 | Epsilon 0.916
# Episode 444 | Reward: 0.0 | Epsilon 0.916
# Episode 445 | Reward: 1.0 | Epsilon 0.916
# Episode 446 | Reward: 5.0 | Epsilon 0.916
# Episode 447 | Reward: 1.0 | Epsilon 0.916
# Episode 448 | Reward: 2.0 | Epsilon 0.915
# Episode 449 | Reward: 0.0 | Epsilon 0.915
# Episode 450 | Reward: 0.0 | Epsilon 0.915
# Target updated at step 85000
# Episode 451 | Reward: 0.0 | Epsilon 0.915
# Episode 452 | Reward: 2.0 | Epsilon 0.915
# Episode 453 | Reward: 0.0 | Epsilon 0.915
# Episode 454 | Reward: 2.0 | Epsilon 0.914
# Episode 455 | Reward: 2.0 | Epsilon 0.914
# Episode 456 | Reward: 2.0 | Epsilon 0.914
# Episode 457 | Reward: 3.0 | Epsilon 0.914
# Episode 458 | Reward: 0.0 | Epsilon 0.913
# Episode 459 | Reward: 3.0 | Epsilon 0.913
# Episode 460 | Reward: 3.0 | Epsilon 0.913
# Episode 461 | Reward: 1.0 | Epsilon 0.913
# Episode 462 | Reward: 0.0 | Epsilon 0.913
# Episode 463 | Reward: 0.0 | Epsilon 0.913
# Episode 464 | Reward: 0.0 | Epsilon 0.912
# Episode 465 | Reward: 1.0 | Epsilon 0.912
# Episode 466 | Reward: 0.0 | Epsilon 0.912
# Episode 467 | Reward: 0.0 | Epsilon 0.912
# Episode 468 | Reward: 5.0 | Epsilon 0.912
# Episode 469 | Reward: 1.0 | Epsilon 0.911
# Episode 470 | Reward: 0.0 | Epsilon 0.911
# Episode 471 | Reward: 0.0 | Epsilon 0.911
# Episode 472 | Reward: 3.0 | Epsilon 0.911
# Episode 473 | Reward: 2.0 | Epsilon 0.911
# Episode 474 | Reward: 1.0 | Epsilon 0.910
# Episode 475 | Reward: 0.0 | Epsilon 0.910
# Episode 476 | Reward: 2.0 | Epsilon 0.910
# Target updated at step 90000
# Episode 477 | Reward: 1.0 | Epsilon 0.910
# Episode 478 | Reward: 4.0 | Epsilon 0.910
# Episode 479 | Reward: 1.0 | Epsilon 0.909
# Episode 480 | Reward: 1.0 | Epsilon 0.909
# Episode 481 | Reward: 3.0 | Epsilon 0.909
# Episode 482 | Reward: 4.0 | Epsilon 0.909
# Episode 483 | Reward: 0.0 | Epsilon 0.909
# Episode 484 | Reward: 1.0 | Epsilon 0.908
# Episode 485 | Reward: 5.0 | Epsilon 0.908
# Episode 486 | Reward: 0.0 | Epsilon 0.908
# Episode 487 | Reward: 1.0 | Epsilon 0.908
# Episode 488 | Reward: 0.0 | Epsilon 0.908
# Episode 489 | Reward: 3.0 | Epsilon 0.907
# Episode 490 | Reward: 4.0 | Epsilon 0.907
# Episode 491 | Reward: 3.0 | Epsilon 0.907
# Episode 492 | Reward: 2.0 | Epsilon 0.907
# Episode 493 | Reward: 1.0 | Epsilon 0.906
# Episode 494 | Reward: 0.0 | Epsilon 0.906
# Episode 495 | Reward: 2.0 | Epsilon 0.906
# Episode 496 | Reward: 1.0 | Epsilon 0.906
# Episode 497 | Reward: 0.0 | Epsilon 0.906
# Episode 498 | Reward: 0.0 | Epsilon 0.906
# Episode 499 | Reward: 1.0 | Epsilon 0.905
# Episode 500 | Reward: 1.0 | Epsilon 0.905
# Episode 501 | Reward: 1.0 | Epsilon 0.905
# Target updated at step 95000
# Episode 502 | Reward: 0.0 | Epsilon 0.905
# Episode 503 | Reward: 2.0 | Epsilon 0.905
# Episode 504 | Reward: 2.0 | Epsilon 0.905
# Episode 505 | Reward: 2.0 | Epsilon 0.904
# Episode 506 | Reward: 1.0 | Epsilon 0.904
# Episode 507 | Reward: 0.0 | Epsilon 0.904
# Episode 508 | Reward: 0.0 | Epsilon 0.904
# Episode 509 | Reward: 1.0 | Epsilon 0.904
# Episode 510 | Reward: 4.0 | Epsilon 0.903
# Episode 511 | Reward: 0.0 | Epsilon 0.903
# Episode 512 | Reward: 3.0 | Epsilon 0.903
# Episode 513 | Reward: 0.0 | Epsilon 0.903
# Episode 514 | Reward: 0.0 | Epsilon 0.903
# Episode 515 | Reward: 0.0 | Epsilon 0.903
# Episode 516 | Reward: 1.0 | Epsilon 0.902
# Episode 517 | Reward: 0.0 | Epsilon 0.902
# Episode 518 | Reward: 1.0 | Epsilon 0.902
# Episode 519 | Reward: 1.0 | Epsilon 0.902
# Episode 520 | Reward: 1.0 | Epsilon 0.902
# Episode 521 | Reward: 0.0 | Epsilon 0.902
# Episode 522 | Reward: 0.0 | Epsilon 0.901
# Episode 523 | Reward: 4.0 | Epsilon 0.901
# Episode 524 | Reward: 2.0 | Epsilon 0.901
# Episode 525 | Reward: 2.0 | Epsilon 0.901
# Episode 526 | Reward: 0.0 | Epsilon 0.901
# Episode 527 | Reward: 1.0 | Epsilon 0.900
# Episode 528 | Reward: 1.0 | Epsilon 0.900
# Episode 529 | Reward: 0.0 | Epsilon 0.900
# Target updated at step 100000
# Episode 530 | Reward: 1.0 | Epsilon 0.900
# Episode 531 | Reward: 6.0 | Epsilon 0.900
# Episode 532 | Reward: 3.0 | Epsilon 0.899
# Episode 533 | Reward: 4.0 | Epsilon 0.899
# Episode 534 | Reward: 1.0 | Epsilon 0.899
# Episode 535 | Reward: 1.0 | Epsilon 0.899
# Episode 536 | Reward: 1.0 | Epsilon 0.899
# Episode 537 | Reward: 5.0 | Epsilon 0.898
# Episode 538 | Reward: 6.0 | Epsilon 0.898
# Episode 539 | Reward: 1.0 | Epsilon 0.898
# Episode 540 | Reward: 1.0 | Epsilon 0.897
# Episode 541 | Reward: 3.0 | Epsilon 0.897
# Episode 542 | Reward: 0.0 | Epsilon 0.897
# Episode 543 | Reward: 0.0 | Epsilon 0.897
# Episode 544 | Reward: 2.0 | Epsilon 0.897
# Episode 545 | Reward: 1.0 | Epsilon 0.897
# Episode 546 | Reward: 1.0 | Epsilon 0.896
# Episode 547 | Reward: 1.0 | Epsilon 0.896
# Episode 548 | Reward: 1.0 | Epsilon 0.896
# Episode 549 | Reward: 1.0 | Epsilon 0.896
# Episode 550 | Reward: 1.0 | Epsilon 0.896
# Episode 551 | Reward: 2.0 | Epsilon 0.895
# Episode 552 | Reward: 0.0 | Epsilon 0.895
# Episode 553 | Reward: 1.0 | Epsilon 0.895
# Target updated at step 105000
# Episode 554 | Reward: 0.0 | Epsilon 0.895
# Episode 555 | Reward: 0.0 | Epsilon 0.895
# Episode 556 | Reward: 3.0 | Epsilon 0.895
# Episode 557 | Reward: 0.0 | Epsilon 0.895
# Episode 558 | Reward: 1.0 | Epsilon 0.894
# Episode 559 | Reward: 1.0 | Epsilon 0.894
# Episode 560 | Reward: 1.0 | Epsilon 0.894
# Episode 561 | Reward: 1.0 | Epsilon 0.894
# Episode 562 | Reward: 2.0 | Epsilon 0.894
# Episode 563 | Reward: 2.0 | Epsilon 0.893
# Episode 564 | Reward: 2.0 | Epsilon 0.893
# Episode 565 | Reward: 3.0 | Epsilon 0.893
# Episode 566 | Reward: 1.0 | Epsilon 0.893
# Episode 567 | Reward: 1.0 | Epsilon 0.893
# Episode 568 | Reward: 1.0 | Epsilon 0.892
# Episode 569 | Reward: 1.0 | Epsilon 0.892
# Episode 570 | Reward: 1.0 | Epsilon 0.892
# Episode 571 | Reward: 2.0 | Epsilon 0.892
# Episode 572 | Reward: 1.0 | Epsilon 0.892
# Episode 573 | Reward: 5.0 | Epsilon 0.891
# Episode 574 | Reward: 3.0 | Epsilon 0.891
# Episode 575 | Reward: 0.0 | Epsilon 0.891
# Episode 576 | Reward: 0.0 | Epsilon 0.891
# Episode 577 | Reward: 1.0 | Epsilon 0.891
# Episode 578 | Reward: 0.0 | Epsilon 0.890
# Episode 579 | Reward: 0.0 | Epsilon 0.890
# Episode 580 | Reward: 0.0 | Epsilon 0.890
# Target updated at step 110000
# Episode 581 | Reward: 3.0 | Epsilon 0.890
# Episode 582 | Reward: 5.0 | Epsilon 0.889
# Episode 583 | Reward: 2.0 | Epsilon 0.889
# Episode 584 | Reward: 3.0 | Epsilon 0.889
# Episode 585 | Reward: 1.0 | Epsilon 0.889
# Episode 586 | Reward: 0.0 | Epsilon 0.889
# Episode 587 | Reward: 0.0 | Epsilon 0.889
# Episode 588 | Reward: 2.0 | Epsilon 0.888
# Episode 589 | Reward: 1.0 | Epsilon 0.888
# Episode 590 | Reward: 4.0 | Epsilon 0.888
# Episode 591 | Reward: 2.0 | Epsilon 0.888
# Episode 592 | Reward: 1.0 | Epsilon 0.887
# Episode 593 | Reward: 0.0 | Epsilon 0.887
# Episode 594 | Reward: 3.0 | Epsilon 0.887
# Episode 595 | Reward: 3.0 | Epsilon 0.887
# Episode 596 | Reward: 1.0 | Epsilon 0.887
# Episode 597 | Reward: 1.0 | Epsilon 0.886
# Episode 598 | Reward: 0.0 | Epsilon 0.886
# Episode 599 | Reward: 3.0 | Epsilon 0.886
# Episode 600 | Reward: 5.0 | Epsilon 0.886
# Episode 601 | Reward: 1.0 | Epsilon 0.886
# Episode 602 | Reward: 2.0 | Epsilon 0.885
# Episode 603 | Reward: 1.0 | Epsilon 0.885
# Target updated at step 115000
# Episode 604 | Reward: 2.0 | Epsilon 0.885
# Episode 605 | Reward: 1.0 | Epsilon 0.885
# Episode 606 | Reward: 3.0 | Epsilon 0.885
# Episode 607 | Reward: 0.0 | Epsilon 0.884
# Episode 608 | Reward: 1.0 | Epsilon 0.884
# Episode 609 | Reward: 1.0 | Epsilon 0.884
# Episode 610 | Reward: 2.0 | Epsilon 0.884
# Episode 611 | Reward: 3.0 | Epsilon 0.884
# Episode 612 | Reward: 5.0 | Epsilon 0.883
# Episode 613 | Reward: 1.0 | Epsilon 0.883
# Episode 614 | Reward: 6.0 | Epsilon 0.883
# Episode 615 | Reward: 2.0 | Epsilon 0.883
# Episode 616 | Reward: 1.0 | Epsilon 0.882
# Episode 617 | Reward: 0.0 | Epsilon 0.882
# Episode 618 | Reward: 0.0 | Epsilon 0.882
# Episode 619 | Reward: 3.0 | Epsilon 0.882
# Episode 620 | Reward: 3.0 | Epsilon 0.882
# Episode 621 | Reward: 1.0 | Epsilon 0.881
# Episode 622 | Reward: 1.0 | Epsilon 0.881
# Episode 623 | Reward: 0.0 | Epsilon 0.881
# Episode 624 | Reward: 1.0 | Epsilon 0.881
# Episode 625 | Reward: 8.0 | Epsilon 0.880
# Episode 626 | Reward: 0.0 | Epsilon 0.880
# Episode 627 | Reward: 0.0 | Epsilon 0.880
# Target updated at step 120000
# Episode 628 | Reward: 4.0 | Epsilon 0.880
# Episode 629 | Reward: 4.0 | Epsilon 0.880
# Episode 630 | Reward: 1.0 | Epsilon 0.879
# Episode 631 | Reward: 1.0 | Epsilon 0.879
# Episode 632 | Reward: 4.0 | Epsilon 0.879
# Episode 633 | Reward: 1.0 | Epsilon 0.879
# Episode 634 | Reward: 1.0 | Epsilon 0.879
# Episode 635 | Reward: 0.0 | Epsilon 0.879
# Episode 636 | Reward: 0.0 | Epsilon 0.878
# Episode 637 | Reward: 1.0 | Epsilon 0.878
# Episode 638 | Reward: 1.0 | Epsilon 0.878
# Episode 639 | Reward: 0.0 | Epsilon 0.878
# Episode 640 | Reward: 2.0 | Epsilon 0.878
# Episode 641 | Reward: 1.0 | Epsilon 0.878
# Episode 642 | Reward: 0.0 | Epsilon 0.877
# Episode 643 | Reward: 0.0 | Epsilon 0.877
# Episode 644 | Reward: 1.0 | Epsilon 0.877
# Episode 645 | Reward: 3.0 | Epsilon 0.877
# Episode 646 | Reward: 3.0 | Epsilon 0.877
# Episode 647 | Reward: 1.0 | Epsilon 0.876
# Episode 648 | Reward: 2.0 | Epsilon 0.876
# Episode 649 | Reward: 2.0 | Epsilon 0.876
# Episode 650 | Reward: 2.0 | Epsilon 0.876
# Episode 651 | Reward: 3.0 | Epsilon 0.876
# Episode 652 | Reward: 0.0 | Epsilon 0.875
# Episode 653 | Reward: 2.0 | Epsilon 0.875
# Target updated at step 125000
# Episode 654 | Reward: 3.0 | Epsilon 0.875
# Episode 655 | Reward: 1.0 | Epsilon 0.875
# Episode 656 | Reward: 2.0 | Epsilon 0.875
# Episode 657 | Reward: 1.0 | Epsilon 0.874
# Episode 658 | Reward: 0.0 | Epsilon 0.874
# Episode 659 | Reward: 5.0 | Epsilon 0.874
# Episode 660 | Reward: 1.0 | Epsilon 0.874
# Episode 661 | Reward: 2.0 | Epsilon 0.873
# Episode 662 | Reward: 1.0 | Epsilon 0.873
# Episode 663 | Reward: 1.0 | Epsilon 0.873
# Episode 664 | Reward: 0.0 | Epsilon 0.873
# Episode 665 | Reward: 2.0 | Epsilon 0.873
# Episode 666 | Reward: 3.0 | Epsilon 0.873
# Episode 667 | Reward: 1.0 | Epsilon 0.872
# Episode 668 | Reward: 2.0 | Epsilon 0.872
# Episode 669 | Reward: 7.0 | Epsilon 0.872
# Episode 670 | Reward: 0.0 | Epsilon 0.872
# Episode 671 | Reward: 2.0 | Epsilon 0.871
# Episode 672 | Reward: 1.0 | Epsilon 0.871
# Episode 673 | Reward: 5.0 | Epsilon 0.871
# Episode 674 | Reward: 2.0 | Epsilon 0.871
# Episode 675 | Reward: 1.0 | Epsilon 0.871
# Episode 676 | Reward: 4.0 | Epsilon 0.870
# Episode 677 | Reward: 1.0 | Epsilon 0.870
# Target updated at step 130000
# Episode 678 | Reward: 2.0 | Epsilon 0.870
# Episode 679 | Reward: 3.0 | Epsilon 0.870
# Episode 680 | Reward: 4.0 | Epsilon 0.869
# Episode 681 | Reward: 0.0 | Epsilon 0.869
# Episode 682 | Reward: 7.0 | Epsilon 0.869
# Episode 683 | Reward: 2.0 | Epsilon 0.868
# Episode 684 | Reward: 2.0 | Epsilon 0.868
# Episode 685 | Reward: 1.0 | Epsilon 0.868
# Episode 686 | Reward: 4.0 | Epsilon 0.868
# Episode 687 | Reward: 2.0 | Epsilon 0.868
# Episode 688 | Reward: 3.0 | Epsilon 0.867
# Episode 689 | Reward: 0.0 | Epsilon 0.867
# Episode 690 | Reward: 3.0 | Epsilon 0.867
# Episode 691 | Reward: 0.0 | Epsilon 0.867
# Episode 692 | Reward: 3.0 | Epsilon 0.867
# Episode 693 | Reward: 2.0 | Epsilon 0.866
# Episode 694 | Reward: 3.0 | Epsilon 0.866
# Episode 695 | Reward: 0.0 | Epsilon 0.866
# Episode 696 | Reward: 1.0 | Epsilon 0.866
# Episode 697 | Reward: 1.0 | Epsilon 0.866
# Episode 698 | Reward: 2.0 | Epsilon 0.865
# Episode 699 | Reward: 0.0 | Epsilon 0.865
# Episode 700 | Reward: 1.0 | Epsilon 0.865
# Target updated at step 135000
# Episode 701 | Reward: 2.0 | Epsilon 0.865
# Episode 702 | Reward: 1.0 | Epsilon 0.865
# Episode 703 | Reward: 0.0 | Epsilon 0.864
# Episode 704 | Reward: 2.0 | Epsilon 0.864
# Episode 705 | Reward: 6.0 | Epsilon 0.864
# Episode 706 | Reward: 5.0 | Epsilon 0.864
# Episode 707 | Reward: 1.0 | Epsilon 0.863
# Episode 708 | Reward: 2.0 | Epsilon 0.863
# Episode 709 | Reward: 3.0 | Epsilon 0.863
# Episode 710 | Reward: 2.0 | Epsilon 0.863
# Episode 711 | Reward: 3.0 | Epsilon 0.862
# Episode 712 | Reward: 1.0 | Epsilon 0.862
# Episode 713 | Reward: 1.0 | Epsilon 0.862
# Episode 714 | Reward: 4.0 | Epsilon 0.862
# Episode 715 | Reward: 3.0 | Epsilon 0.862
# Episode 716 | Reward: 0.0 | Epsilon 0.861
# Episode 717 | Reward: 4.0 | Epsilon 0.861
# Episode 718 | Reward: 3.0 | Epsilon 0.861
# Episode 719 | Reward: 2.0 | Epsilon 0.861
# Episode 720 | Reward: 0.0 | Epsilon 0.860
# Episode 721 | Reward: 3.0 | Epsilon 0.860
# Episode 722 | Reward: 1.0 | Epsilon 0.860
# Target updated at step 140000
# Episode 723 | Reward: 3.0 | Epsilon 0.860
# Episode 724 | Reward: 4.0 | Epsilon 0.859
# Episode 725 | Reward: 2.0 | Epsilon 0.859
# Episode 726 | Reward: 0.0 | Epsilon 0.859
# Episode 727 | Reward: 1.0 | Epsilon 0.859
# Episode 728 | Reward: 0.0 | Epsilon 0.859
# Episode 729 | Reward: 2.0 | Epsilon 0.859
# Episode 730 | Reward: 3.0 | Epsilon 0.858
# Episode 731 | Reward: 2.0 | Epsilon 0.858
# Episode 732 | Reward: 1.0 | Epsilon 0.858
# Episode 733 | Reward: 4.0 | Epsilon 0.858
# Episode 734 | Reward: 1.0 | Epsilon 0.857
# Episode 735 | Reward: 1.0 | Epsilon 0.857
# Episode 736 | Reward: 13.0 | Epsilon 0.857
# Episode 737 | Reward: 5.0 | Epsilon 0.856
# Episode 738 | Reward: 3.0 | Epsilon 0.856
# Episode 739 | Reward: 0.0 | Epsilon 0.856
# Episode 740 | Reward: 3.0 | Epsilon 0.856
# Episode 741 | Reward: 3.0 | Epsilon 0.856
# Episode 742 | Reward: 0.0 | Epsilon 0.855
# Episode 743 | Reward: 2.0 | Epsilon 0.855
# Target updated at step 145000
# Episode 744 | Reward: 3.0 | Epsilon 0.855
# Episode 745 | Reward: 4.0 | Epsilon 0.855
# Episode 746 | Reward: 1.0 | Epsilon 0.854
# Episode 747 | Reward: 1.0 | Epsilon 0.854
# Episode 748 | Reward: 3.0 | Epsilon 0.854
# Episode 749 | Reward: 4.0 | Epsilon 0.854
# Episode 750 | Reward: 2.0 | Epsilon 0.854
# Episode 751 | Reward: 3.0 | Epsilon 0.853
# Episode 752 | Reward: 2.0 | Epsilon 0.853
# Episode 753 | Reward: 2.0 | Epsilon 0.853
# Episode 754 | Reward: 2.0 | Epsilon 0.853
# Episode 755 | Reward: 5.0 | Epsilon 0.852
# Episode 756 | Reward: 1.0 | Epsilon 0.852
# Episode 757 | Reward: 4.0 | Epsilon 0.852
# Episode 758 | Reward: 0.0 | Epsilon 0.852
# Episode 759 | Reward: 1.0 | Epsilon 0.852
# Episode 760 | Reward: 5.0 | Epsilon 0.851
# Episode 761 | Reward: 1.0 | Epsilon 0.851
# Episode 762 | Reward: 2.0 | Epsilon 0.851
# Episode 763 | Reward: 5.0 | Epsilon 0.850
# Episode 764 | Reward: 3.0 | Epsilon 0.850
# Episode 765 | Reward: 1.0 | Epsilon 0.850
# Target updated at step 150000
# Episode 766 | Reward: 3.0 | Epsilon 0.850
# Episode 767 | Reward: 2.0 | Epsilon 0.850
# Episode 768 | Reward: 3.0 | Epsilon 0.849
# Episode 769 | Reward: 1.0 | Epsilon 0.849
# Episode 770 | Reward: 8.0 | Epsilon 0.849
# Episode 771 | Reward: 1.0 | Epsilon 0.849
# Episode 772 | Reward: 3.0 | Epsilon 0.848
# Episode 773 | Reward: 3.0 | Epsilon 0.848
# Episode 774 | Reward: 2.0 | Epsilon 0.848
# Episode 775 | Reward: 2.0 | Epsilon 0.848
# Episode 776 | Reward: 2.0 | Epsilon 0.847
# Episode 777 | Reward: 4.0 | Epsilon 0.847
# Episode 778 | Reward: 7.0 | Epsilon 0.847
# Episode 779 | Reward: 2.0 | Epsilon 0.847
# Episode 780 | Reward: 3.0 | Epsilon 0.846
# Episode 781 | Reward: 5.0 | Epsilon 0.846
# Episode 782 | Reward: 1.0 | Epsilon 0.846
# Episode 783 | Reward: 4.0 | Epsilon 0.845
# Episode 784 | Reward: 2.0 | Epsilon 0.845
# Target updated at step 155000
# Episode 785 | Reward: 7.0 | Epsilon 0.845
# Episode 786 | Reward: 3.0 | Epsilon 0.845
# Episode 787 | Reward: 5.0 | Epsilon 0.844
# Episode 788 | Reward: 0.0 | Epsilon 0.844
# Episode 789 | Reward: 1.0 | Epsilon 0.844
# Episode 790 | Reward: 1.0 | Epsilon 0.844
# Episode 791 | Reward: 0.0 | Epsilon 0.844
# Episode 792 | Reward: 5.0 | Epsilon 0.843
# Episode 793 | Reward: 3.0 | Epsilon 0.843
# Episode 794 | Reward: 2.0 | Epsilon 0.843
# Episode 795 | Reward: 5.0 | Epsilon 0.842
# Episode 796 | Reward: 0.0 | Epsilon 0.842
# Episode 797 | Reward: 1.0 | Epsilon 0.842
# Episode 798 | Reward: 8.0 | Epsilon 0.842
# Episode 799 | Reward: 1.0 | Epsilon 0.842
# Episode 800 | Reward: 0.0 | Epsilon 0.841
# Episode 801 | Reward: 1.0 | Epsilon 0.841
# Episode 802 | Reward: 2.0 | Epsilon 0.841
# Episode 803 | Reward: 4.0 | Epsilon 0.841
# Episode 804 | Reward: 8.0 | Epsilon 0.840
# Episode 805 | Reward: 2.0 | Epsilon 0.840
# Target updated at step 160000
# Episode 806 | Reward: 4.0 | Epsilon 0.840
# Episode 807 | Reward: 3.0 | Epsilon 0.840
# Episode 808 | Reward: 3.0 | Epsilon 0.839
# Episode 809 | Reward: 1.0 | Epsilon 0.839
# Episode 810 | Reward: 1.0 | Epsilon 0.839
# Episode 811 | Reward: 3.0 | Epsilon 0.839
# Episode 812 | Reward: 8.0 | Epsilon 0.838
# Episode 813 | Reward: 1.0 | Epsilon 0.838
# Episode 814 | Reward: 8.0 | Epsilon 0.838
# Episode 815 | Reward: 3.0 | Epsilon 0.838
# Episode 816 | Reward: 2.0 | Epsilon 0.837
# Episode 817 | Reward: 4.0 | Epsilon 0.837
# Episode 818 | Reward: 1.0 | Epsilon 0.837
# Episode 819 | Reward: 0.0 | Epsilon 0.837
# Episode 820 | Reward: 4.0 | Epsilon 0.836
# Episode 821 | Reward: 3.0 | Epsilon 0.836
# Episode 822 | Reward: 5.0 | Epsilon 0.836
# Episode 823 | Reward: 1.0 | Epsilon 0.836
# Episode 824 | Reward: 0.0 | Epsilon 0.836
# Episode 825 | Reward: 4.0 | Epsilon 0.835
# Target updated at step 165000
# Episode 826 | Reward: 3.0 | Epsilon 0.835
# Episode 827 | Reward: 2.0 | Epsilon 0.835
# Episode 828 | Reward: 3.0 | Epsilon 0.834
# Episode 829 | Reward: 5.0 | Epsilon 0.834
# Episode 830 | Reward: 2.0 | Epsilon 0.834
# Episode 831 | Reward: 0.0 | Epsilon 0.834
# Episode 832 | Reward: 0.0 | Epsilon 0.834
# Episode 833 | Reward: 1.0 | Epsilon 0.833
# Episode 834 | Reward: 10.0 | Epsilon 0.833
# Episode 835 | Reward: 2.0 | Epsilon 0.833
# Episode 836 | Reward: 5.0 | Epsilon 0.832
# Episode 837 | Reward: 3.0 | Epsilon 0.832
# Episode 838 | Reward: 5.0 | Epsilon 0.832
# Episode 839 | Reward: 0.0 | Epsilon 0.832
# Episode 840 | Reward: 2.0 | Epsilon 0.831
# Episode 841 | Reward: 1.0 | Epsilon 0.831
# Episode 842 | Reward: 3.0 | Epsilon 0.831
# Episode 843 | Reward: 4.0 | Epsilon 0.831
# Episode 844 | Reward: 1.0 | Epsilon 0.831
# Episode 845 | Reward: 1.0 | Epsilon 0.830
# Episode 846 | Reward: 1.0 | Epsilon 0.830
# Target updated at step 170000
# Episode 847 | Reward: 4.0 | Epsilon 0.830
# Episode 848 | Reward: 1.0 | Epsilon 0.830
# Episode 849 | Reward: 3.0 | Epsilon 0.830
# Episode 850 | Reward: 3.0 | Epsilon 0.829
# Episode 851 | Reward: 1.0 | Epsilon 0.829
# Episode 852 | Reward: 3.0 | Epsilon 0.829
# Episode 853 | Reward: 2.0 | Epsilon 0.829
# Episode 854 | Reward: 4.0 | Epsilon 0.828
# Episode 855 | Reward: 1.0 | Epsilon 0.828
# Episode 856 | Reward: 1.0 | Epsilon 0.828
# Episode 857 | Reward: 1.0 | Epsilon 0.828
# Episode 858 | Reward: 2.0 | Epsilon 0.828
# Episode 859 | Reward: 3.0 | Epsilon 0.827
# Episode 860 | Reward: 1.0 | Epsilon 0.827
# Episode 861 | Reward: 0.0 | Epsilon 0.827
# Episode 862 | Reward: 5.0 | Epsilon 0.827
# Episode 863 | Reward: 0.0 | Epsilon 0.827
# Episode 864 | Reward: 3.0 | Epsilon 0.826
# Episode 865 | Reward: 5.0 | Epsilon 0.826
# Episode 866 | Reward: 0.0 | Epsilon 0.826
# Episode 867 | Reward: 2.0 | Epsilon 0.826
# Episode 868 | Reward: 3.0 | Epsilon 0.825
# Episode 869 | Reward: 1.0 | Epsilon 0.825
# Episode 870 | Reward: 1.0 | Epsilon 0.825
# Target updated at step 175000
# Episode 871 | Reward: 4.0 | Epsilon 0.825
# Episode 872 | Reward: 1.0 | Epsilon 0.825
# Episode 873 | Reward: 5.0 | Epsilon 0.824
# Episode 874 | Reward: 0.0 | Epsilon 0.824
# Episode 875 | Reward: 2.0 | Epsilon 0.824
# Episode 876 | Reward: 1.0 | Epsilon 0.824
# Episode 877 | Reward: 2.0 | Epsilon 0.824
# Episode 878 | Reward: 4.0 | Epsilon 0.823
# Episode 879 | Reward: 0.0 | Epsilon 0.823
# Episode 880 | Reward: 2.0 | Epsilon 0.823
# Episode 881 | Reward: 1.0 | Epsilon 0.823
# Episode 882 | Reward: 2.0 | Epsilon 0.823
# Episode 883 | Reward: 3.0 | Epsilon 0.822
# Episode 884 | Reward: 4.0 | Epsilon 0.822
# Episode 885 | Reward: 1.0 | Epsilon 0.822
# Episode 886 | Reward: 2.0 | Epsilon 0.822
# Episode 887 | Reward: 2.0 | Epsilon 0.822
# Episode 888 | Reward: 1.0 | Epsilon 0.821
# Episode 889 | Reward: 6.0 | Epsilon 0.821
# Episode 890 | Reward: 6.0 | Epsilon 0.821
# Episode 891 | Reward: 2.0 | Epsilon 0.820
# Episode 892 | Reward: 6.0 | Epsilon 0.820
# Target updated at step 180000
# Episode 893 | Reward: 5.0 | Epsilon 0.820
# Episode 894 | Reward: 1.0 | Epsilon 0.819
# Episode 895 | Reward: 5.0 | Epsilon 0.819
# Episode 896 | Reward: 2.0 | Epsilon 0.819
# Episode 897 | Reward: 0.0 | Epsilon 0.819
# Episode 898 | Reward: 2.0 | Epsilon 0.819
# Episode 899 | Reward: 0.0 | Epsilon 0.818
# Episode 900 | Reward: 2.0 | Epsilon 0.818
# Episode 901 | Reward: 1.0 | Epsilon 0.818
# Episode 902 | Reward: 3.0 | Epsilon 0.818
# Episode 903 | Reward: 1.0 | Epsilon 0.818
# Episode 904 | Reward: 5.0 | Epsilon 0.817
# Episode 905 | Reward: 0.0 | Epsilon 0.817
# Episode 906 | Reward: 1.0 | Epsilon 0.817
# Episode 907 | Reward: 2.0 | Epsilon 0.817
# Episode 908 | Reward: 0.0 | Epsilon 0.817
# Episode 909 | Reward: 7.0 | Epsilon 0.816
# Episode 910 | Reward: 6.0 | Epsilon 0.816
# Episode 911 | Reward: 2.0 | Epsilon 0.816
# Episode 912 | Reward: 2.0 | Epsilon 0.816
# Episode 913 | Reward: 3.0 | Epsilon 0.815
# Target updated at step 185000
# Episode 914 | Reward: 4.0 | Epsilon 0.815
# Episode 915 | Reward: 0.0 | Epsilon 0.815
# Episode 916 | Reward: 5.0 | Epsilon 0.815
# Episode 917 | Reward: 5.0 | Epsilon 0.814
# Episode 918 | Reward: 1.0 | Epsilon 0.814
# Episode 919 | Reward: 3.0 | Epsilon 0.814
# Episode 920 | Reward: 0.0 | Epsilon 0.814
# Episode 921 | Reward: 4.0 | Epsilon 0.813
# Episode 922 | Reward: 5.0 | Epsilon 0.813
# Episode 923 | Reward: 1.0 | Epsilon 0.813
# Episode 924 | Reward: 0.0 | Epsilon 0.813
# Episode 925 | Reward: 1.0 | Epsilon 0.813
# Episode 926 | Reward: 0.0 | Epsilon 0.812
# Episode 927 | Reward: 2.0 | Epsilon 0.812
# Episode 928 | Reward: 3.0 | Epsilon 0.812
# Episode 929 | Reward: 1.0 | Epsilon 0.812
# Episode 930 | Reward: 4.0 | Epsilon 0.812
# Episode 931 | Reward: 4.0 | Epsilon 0.811
# Episode 932 | Reward: 3.0 | Epsilon 0.811
# Episode 933 | Reward: 0.0 | Epsilon 0.811
# Episode 934 | Reward: 2.0 | Epsilon 0.811
# Episode 935 | Reward: 0.0 | Epsilon 0.811
# Episode 936 | Reward: 3.0 | Epsilon 0.810
# Episode 937 | Reward: 1.0 | Epsilon 0.810
# Target updated at step 190000
# Episode 938 | Reward: 2.0 | Epsilon 0.810
# Episode 939 | Reward: 7.0 | Epsilon 0.810
# Episode 940 | Reward: 2.0 | Epsilon 0.809
# Episode 941 | Reward: 1.0 | Epsilon 0.809
# Episode 942 | Reward: 1.0 | Epsilon 0.809
# Episode 943 | Reward: 6.0 | Epsilon 0.809
# Episode 944 | Reward: 2.0 | Epsilon 0.808
# Episode 945 | Reward: 3.0 | Epsilon 0.808
# Episode 946 | Reward: 2.0 | Epsilon 0.808
# Episode 947 | Reward: 2.0 | Epsilon 0.808
# Episode 948 | Reward: 1.0 | Epsilon 0.808
# Episode 949 | Reward: 6.0 | Epsilon 0.807
# Episode 950 | Reward: 2.0 | Epsilon 0.807
# Episode 951 | Reward: 1.0 | Epsilon 0.807
# Episode 952 | Reward: 0.0 | Epsilon 0.807
# Episode 953 | Reward: 2.0 | Epsilon 0.807
# Episode 954 | Reward: 3.0 | Epsilon 0.806
# Episode 955 | Reward: 2.0 | Epsilon 0.806
# Episode 956 | Reward: 5.0 | Epsilon 0.806
# Episode 957 | Reward: 5.0 | Epsilon 0.805
# Episode 958 | Reward: 1.0 | Epsilon 0.805
# Episode 959 | Reward: 1.0 | Epsilon 0.805
# Target updated at step 195000
# Episode 960 | Reward: 3.0 | Epsilon 0.805
# Episode 961 | Reward: 5.0 | Epsilon 0.804
# Episode 962 | Reward: 1.0 | Epsilon 0.804
# Episode 963 | Reward: 1.0 | Epsilon 0.804
# Episode 964 | Reward: 3.0 | Epsilon 0.804
# Episode 965 | Reward: 4.0 | Epsilon 0.804
# Episode 966 | Reward: 0.0 | Epsilon 0.803
# Episode 967 | Reward: 3.0 | Epsilon 0.803
# Episode 968 | Reward: 5.0 | Epsilon 0.803
# Episode 969 | Reward: 1.0 | Epsilon 0.803
# Episode 970 | Reward: 5.0 | Epsilon 0.802
# Episode 971 | Reward: 6.0 | Epsilon 0.802
# Episode 972 | Reward: 2.0 | Epsilon 0.802
# Episode 973 | Reward: 0.0 | Epsilon 0.802
# Episode 974 | Reward: 3.0 | Epsilon 0.801
# Episode 975 | Reward: 3.0 | Epsilon 0.801
# Episode 976 | Reward: 6.0 | Epsilon 0.801
# Episode 977 | Reward: 5.0 | Epsilon 0.801
# Episode 978 | Reward: 3.0 | Epsilon 0.800
# Episode 979 | Reward: 3.0 | Epsilon 0.800
# Target updated at step 200000
# Episode 980 | Reward: 1.0 | Epsilon 0.800
# Episode 981 | Reward: 1.0 | Epsilon 0.800
# Episode 982 | Reward: 1.0 | Epsilon 0.800
# Episode 983 | Reward: 3.0 | Epsilon 0.799
# Episode 984 | Reward: 3.0 | Epsilon 0.799
# Episode 985 | Reward: 1.0 | Epsilon 0.799
# Episode 986 | Reward: 3.0 | Epsilon 0.799
# Episode 987 | Reward: 4.0 | Epsilon 0.798
# Episode 988 | Reward: 0.0 | Epsilon 0.798
# Episode 989 | Reward: 1.0 | Epsilon 0.798
# Episode 990 | Reward: 2.0 | Epsilon 0.798
# Episode 991 | Reward: 0.0 | Epsilon 0.798
# Episode 992 | Reward: 0.0 | Epsilon 0.798
# Episode 993 | Reward: 3.0 | Epsilon 0.797
# Episode 994 | Reward: 2.0 | Epsilon 0.797
# Episode 995 | Reward: 2.0 | Epsilon 0.797
# Episode 996 | Reward: 8.0 | Epsilon 0.797
# Episode 997 | Reward: 4.0 | Epsilon 0.796
# Episode 998 | Reward: 3.0 | Epsilon 0.796
# Episode 999 | Reward: 7.0 | Epsilon 0.796
# Episode 1000 | Reward: 2.0 | Epsilon 0.795

# %%
torch.save(agent.policy.state_dict(), "Breakout_dqn.pth")

# %%
import re
import matplotlib.pyplot as plt

# Load file
log_path = "/content/breakout_dqn.txt"
with open(log_path, "r") as f:
    lines = f.readlines()

episodes = []
rewards = []


pattern = r"Episode\s+(\d+)\s*\|\s*Reward:\s*(-?\d+\.?\d*)"

for line in lines:
    match = re.search(pattern, line)
    if match:
        ep = int(match.group(1))
        rew = float(match.group(2))
        episodes.append(ep)
        rewards.append(rew)

print("Parsed episodes:", len(episodes))

# Plot
plt.figure(figsize=(14,6))
plt.plot(episodes, rewards, alpha=0.4, label="Reward (raw)")

# Moving average smoothing
import numpy as np
window = 20
if len(rewards) >= window:
    smooth = np.convolve(rewards, np.ones(window)/window, mode='valid')
    plt.plot(episodes[window-1:], smooth, color='red', linewidth=2, label=f"Moving Avg ({window})")

plt.title("DQN Training Reward Over Time (Breakout)")
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Parsed episodes: 1000

# %%
import gymnasium as gym
import ale_py
import numpy as np
from collections import deque
from gymnasium.wrappers import RecordVideo
import cv2

gym.register_envs(ale_py)


def preprocess(obs):

    gray = cv2.cvtColor(obs, cv2.COLOR_RGB2GRAY)
    resized = cv2.resize(gray, (84, 84), interpolation=cv2.INTER_AREA)
    return resized

# FrameStack

class LazyFrames:
    def __init__(self, frames):
        self._frames = frames
    def __array__(self, dtype=None):
        arr = np.stack(self._frames, axis=0)
        return arr.astype(dtype) if dtype else arr

class FrameStack:
    def __init__(self, env, k=4):
        self.env = env
        self.k = k
        self.frames = deque(maxlen=k)

    def reset(self):
        obs, info = self.env.reset()
        obs = preprocess(obs)
        obs = np.expand_dims(obs, 0)
        for _ in range(self.k):
            self.frames.append(obs)
        return LazyFrames(list(self.frames)), info

    def step(self, action):
        obs, rew, terminated, truncated, info = self.env.step(action)
        obs = preprocess(obs)
        obs = np.expand_dims(obs, 0)
        self.frames.append(obs)
        return LazyFrames(list(self.frames)), rew, terminated, truncated, info

    def close(self):
        if hasattr(self.env, "close"):
            self.env.close()


# WORKING BREAKOUT VIDEO ENVIRONMENT

def make_eval_env():
    env = gym.make("ALE/Breakout-v5", render_mode="rgb_array")


    env = RecordVideo(
        env,
        video_folder="/content/breakout_eval_dqn/",
        episode_trigger=lambda ep: True
    )


    env = FrameStack(env, k=4)

    return env

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

policy = DQN(4).to(device)
policy.load_state_dict(torch.load("/content/Breakout_dqn.pth", map_location=device))
policy.eval()

env = make_eval_env()
obs, _ = env.reset()
done = False
total_reward = 0

while not done:
    s = np.array(obs).squeeze(1)
    s = torch.tensor(s, dtype=torch.float32, device=device).unsqueeze(0)

    with torch.no_grad():
        action = torch.argmax(policy(s)).item()

    obs, reward, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
    total_reward += reward

print("Episode reward:", total_reward)

env.close()
# Out:
# /usr/local/lib/python3.12/dist-packages/gymnasium/wrappers/rendering.py:293: UserWarning: WARN: Overwriting existing videos at /content/breakout_eval_dqn folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Episode reward: 4.0
