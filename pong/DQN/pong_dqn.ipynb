# %%
# !python3 --version
# Out:
# Python 3.10.12

# %%
# !sudo update-alternatives --config python3
# Out:
# There are 2 choices for the alternative python3 (providing /usr/bin/python3).
#
#   Selection    Path                 Priority   Status
# ------------------------------------------------------------
# * 0            /usr/bin/python3.12   2         auto mode
#   1            /usr/bin/python3.10   1         manual mode
#   2            /usr/bin/python3.12   2         manual mode
#
# Press <enter> to keep the current choice[*], or type selection number: 1
# update-alternatives: using /usr/bin/python3.10 to provide /usr/bin/python3 (python3) in manual mode

# %%
# !python3 -m pip install --upgrade pip
# !python3 -m pip install "gymnasium[atari]" ale-py autorom
# Out:
# /usr/bin/python3: No module named pip
# /usr/bin/python3: No module named pip

# %%
# !which python3
# !python3 --version
# Out:
# /usr/bin/python3
# Python 3.10.12

# %%
# !wget https://bootstrap.pypa.io/get-pip.py
# !python3 get-pip.py
# Out:
# --2025-12-01 02:04:36--  https://bootstrap.pypa.io/get-pip.py
# Resolving bootstrap.pypa.io (bootstrap.pypa.io)... 151.101.0.175, 151.101.64.175, 151.101.128.175, ...
# Connecting to bootstrap.pypa.io (bootstrap.pypa.io)|151.101.0.175|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2182415 (2.1M) [text/x-python]
# Saving to: ‘get-pip.py’
#
# get-pip.py          100%[===================>]   2.08M  --.-KB/s    in 0.03s
#
# 2025-12-01 02:04:36 (75.1 MB/s) - ‘get-pip.py’ saved [2182415/2182415]
#
# Collecting pip
#   Downloading pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Collecting setuptools
#   Downloading setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting wheel
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Downloading pip-25.3-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 20.1 MB/s  0:00:00
# Downloading setuptools-80.9.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 26.0 MB/s  0:00:00
# Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
# Installing collected packages: wheel, setuptools, pip
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pip]
# Successfully installed pip-25.3 setuptools-80.9.0 wheel-0.45.1

# %%
# !python3 -m pip --version
# Out:
# pip 25.3 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)

# %%
# !python3 -m pip install "gymnasium[atari]==0.29.1"
# !python3 -m pip install "ale-py==0.8.1"
# !python3 -m pip install autorom
# Out:
# Collecting gymnasium==0.29.1 (from gymnasium[atari]==0.29.1)
#   Using cached gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Collecting numpy>=1.21.0 (from gymnasium==0.29.1->gymnasium[atari]==0.29.1)
#   Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting cloudpickle>=1.2.0 (from gymnasium==0.29.1->gymnasium[atari]==0.29.1)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-extensions>=4.3.0 (from gymnasium==0.29.1->gymnasium[atari]==0.29.1)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting farama-notifications>=0.0.1 (from gymnasium==0.29.1->gymnasium[atari]==0.29.1)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Collecting shimmy<1.0,>=0.1.0 (from shimmy[atari]<1.0,>=0.1.0; extra == "atari"->gymnasium[atari]==0.29.1)
#   Using cached Shimmy-0.2.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting ale-py~=0.8.1 (from shimmy[atari]<1.0,>=0.1.0; extra == "atari"->gymnasium[atari]==0.29.1)
#   Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Collecting importlib-resources (from ale-py~=0.8.1->shimmy[atari]<1.0,>=0.1.0; extra == "atari"->gymnasium[atari]==0.29.1)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 12.1 MB/s  0:00:00
# Downloading Shimmy-0.2.1-py3-none-any.whl (25 kB)
# Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 21.0 MB/s  0:00:00
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 42.4 MB/s  0:00:00
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Installing collected packages: farama-notifications, typing-extensions, numpy, importlib-resources, cloudpickle, gymnasium, ale-py, shimmy
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [shimmy]
# Successfully installed ale-py-0.8.1 cloudpickle-3.1.2 farama-notifications-0.0.4 gymnasium-0.29.1 importlib-resources-6.5.2 numpy-2.2.6 shimmy-0.2.1 typing-extensions-4.15.0
# Requirement already satisfied: ale-py==0.8.1 in /usr/local/lib/python3.10/dist-packages (0.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ale-py==0.8.1) (2.2.6)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py==0.8.1) (6.5.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from ale-py==0.8.1) (4.15.0)
# Collecting autorom
#   Using cached AutoROM-0.6.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting click (from autorom)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting requests (from autorom)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting charset_normalizer<4,>=2 (from requests->autorom)
#   Downloading charset_normalizer-3.4.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests->autorom)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->autorom)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests->autorom)
#   Downloading certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Using cached AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (153 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading certifi-2025.11.12-py3-none-any.whl (159 kB)
# Installing collected packages: urllib3, idna, click, charset_normalizer, certifi, requests, autorom
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [autorom]
# Successfully installed autorom-0.6.1 certifi-2025.11.12 charset_normalizer-3.4.4 click-8.3.1 idna-3.11 requests-2.32.5 urllib3-2.5.0

# %%
# !python3 -m AutoROM --accept-license
# Out:
# /usr/bin/python3: No module named AutoROM.__main__; 'AutoROM' is a package and cannot be directly executed

# %%
# !python3 -m pip install "gymnasium[atari]" ale-py AutoROM AutoROM.accept-rom-license

# !python3 -m AutoROM.accept_rom_license --accept-license
# Out:
# Requirement already satisfied: ale-py in /usr/local/lib/python3.10/dist-packages (0.8.1)
# Requirement already satisfied: AutoROM in /usr/local/lib/python3.10/dist-packages (0.6.1)
# Collecting AutoROM.accept-rom-license
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: gymnasium[atari] in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (2.2.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (0.0.4)
# Requirement already satisfied: shimmy<1.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from shimmy[atari]<1.0,>=0.1.0; extra == "atari"->gymnasium[atari]) (0.2.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py) (6.5.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from AutoROM) (8.3.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from AutoROM) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->AutoROM) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->AutoROM) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->AutoROM) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->AutoROM) (2025.11.12)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=autorom_accept_rom_license-0.6.1-py3-none-any.whl size=446709 sha256=6e51a8783d8e02df06c9523f676601a9d726eb27cfefded059fea51cc38221bc
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: AutoROM.accept-rom-license
# Successfully installed AutoROM.accept-rom-license-0.6.1
# /usr/bin/python3: No module named AutoROM.accept_rom_license

# %%
import gymnasium as gym
import ale_py

gym.register_envs(ale_py)
print("Atari envs registered!")

gym.pprint_registry()
# Out:
# Atari envs registered!
# ===== classic_control =====
# Acrobot-v1                  CartPole-v0                 CartPole-v1
# MountainCar-v0              MountainCarContinuous-v0    Pendulum-v1
# ===== phys2d =====
# phys2d/CartPole-v0          phys2d/CartPole-v1          phys2d/Pendulum-v0
# ===== box2d =====
# BipedalWalker-v3            BipedalWalkerHardcore-v3    CarRacing-v3
# LunarLander-v3              LunarLanderContinuous-v3
# ===== toy_text =====
# Blackjack-v1                CliffWalking-v1             CliffWalkingSlippery-v1
# FrozenLake-v1               FrozenLake8x8-v1            Taxi-v3
# ===== tabular =====
# tabular/Blackjack-v0        tabular/CliffWalking-v0
# ===== None =====
# Ant-v2                      Ant-v3                      GymV21Environment-v0
# GymV26Environment-v0        HalfCheetah-v2              HalfCheetah-v3
# Hopper-v2                   Hopper-v3                   Humanoid-v2
# Humanoid-v3                 HumanoidStandup-v2          InvertedDoublePendulum-v2
# InvertedPendulum-v2         Pusher-v2                   Reacher-v2
# Swimmer-v2                  Swimmer-v3                  Walker2d-v2
# Walker2d-v3
# ===== mujoco =====
# Ant-v4                      Ant-v5                      HalfCheetah-v4
# HalfCheetah-v5              Hopper-v4                   Hopper-v5
# Humanoid-v4                 Humanoid-v5                 HumanoidStandup-v4
# HumanoidStandup-v5          InvertedDoublePendulum-v4   InvertedDoublePendulum-v5
# InvertedPendulum-v4         InvertedPendulum-v5         Pusher-v4
# Pusher-v5                   Reacher-v4                  Reacher-v5
# Swimmer-v4                  Swimmer-v5                  Walker2d-v4
# Walker2d-v5
# ===== env =====
# Adventure-v0                Adventure-v4                AdventureNoFrameskip-v0
# AdventureNoFrameskip-v4     AirRaid-v0                  AirRaid-v4
# AirRaidNoFrameskip-v0       AirRaidNoFrameskip-v4       Alien-v0
# Alien-v4                    AlienNoFrameskip-v0         AlienNoFrameskip-v4
# Amidar-v0                   Amidar-v4                   AmidarNoFrameskip-v0
# AmidarNoFrameskip-v4        Assault-v0                  Assault-v4
# AssaultNoFrameskip-v0       AssaultNoFrameskip-v4       Asterix-v0
# Asterix-v4                  AsterixNoFrameskip-v0       AsterixNoFrameskip-v4
# Asteroids-v0                Asteroids-v4                AsteroidsNoFrameskip-v0
# AsteroidsNoFrameskip-v4     Atlantis-v0                 Atlantis-v4
# AtlantisNoFrameskip-v0      AtlantisNoFrameskip-v4      BankHeist-v0
# BankHeist-v4                BankHeistNoFrameskip-v0     BankHeistNoFrameskip-v4
# BattleZone-v0               BattleZone-v4               BattleZoneNoFrameskip-v0
# BattleZoneNoFrameskip-v4    BeamRider-v0                BeamRider-v4
# BeamRiderNoFrameskip-v0     BeamRiderNoFrameskip-v4     Berzerk-v0
# Berzerk-v4                  BerzerkNoFrameskip-v0       BerzerkNoFrameskip-v4
# Bowling-v0                  Bowling-v4                  BowlingNoFrameskip-v0
# BowlingNoFrameskip-v4       Boxing-v0                   Boxing-v4
# BoxingNoFrameskip-v0        BoxingNoFrameskip-v4        Breakout-v0
# Breakout-v4                 BreakoutNoFrameskip-v0      BreakoutNoFrameskip-v4
# Carnival-v0                 Carnival-v4                 CarnivalNoFrameskip-v0
# CarnivalNoFrameskip-v4      Centipede-v0                Centipede-v4
# CentipedeNoFrameskip-v0     CentipedeNoFrameskip-v4     ChopperCommand-v0
# ChopperCommand-v4           ChopperCommandNoFrameskip-v0 ChopperCommandNoFrameskip-v4
# CrazyClimber-v0             CrazyClimber-v4             CrazyClimberNoFrameskip-v0
# CrazyClimberNoFrameskip-v4  Defender-v0                 Defender-v4
# DefenderNoFrameskip-v0      DefenderNoFrameskip-v4      DemonAttack-v0
# DemonAttack-v4              DemonAttackNoFrameskip-v0   DemonAttackNoFrameskip-v4
# DoubleDunk-v0               DoubleDunk-v4               DoubleDunkNoFrameskip-v0
# DoubleDunkNoFrameskip-v4    ElevatorAction-v0           ElevatorAction-v4
# ElevatorActionNoFrameskip-v0 ElevatorActionNoFrameskip-v4 Enduro-v0
# Enduro-v4                   EnduroNoFrameskip-v0        EnduroNoFrameskip-v4
# FishingDerby-v0             FishingDerby-v4             FishingDerbyNoFrameskip-v0
# FishingDerbyNoFrameskip-v4  Freeway-v0                  Freeway-v4
# FreewayNoFrameskip-v0       FreewayNoFrameskip-v4       Frostbite-v0
# Frostbite-v4                FrostbiteNoFrameskip-v0     FrostbiteNoFrameskip-v4
# Gopher-v0                   Gopher-v4                   GopherNoFrameskip-v0
# GopherNoFrameskip-v4        Gravitar-v0                 Gravitar-v4
# GravitarNoFrameskip-v0      GravitarNoFrameskip-v4      Hero-v0
# Hero-v4                     HeroNoFrameskip-v0          HeroNoFrameskip-v4
# IceHockey-v0                IceHockey-v4                IceHockeyNoFrameskip-v0
# IceHockeyNoFrameskip-v4     Jamesbond-v0                Jamesbond-v4
# JamesbondNoFrameskip-v0     JamesbondNoFrameskip-v4     JourneyEscape-v0
# JourneyEscape-v4            JourneyEscapeNoFrameskip-v0 JourneyEscapeNoFrameskip-v4
# Kangaroo-v0                 Kangaroo-v4                 KangarooNoFrameskip-v0
# KangarooNoFrameskip-v4      Krull-v0                    Krull-v4
# KrullNoFrameskip-v0         KrullNoFrameskip-v4         KungFuMaster-v0
# KungFuMaster-v4             KungFuMasterNoFrameskip-v0  KungFuMasterNoFrameskip-v4
# MontezumaRevenge-v0         MontezumaRevenge-v4         MontezumaRevengeNoFrameskip-v0
# MontezumaRevengeNoFrameskip-v4 MsPacman-v0                 MsPacman-v4
# MsPacmanNoFrameskip-v0      MsPacmanNoFrameskip-v4      NameThisGame-v0
# NameThisGame-v4             NameThisGameNoFrameskip-v0  NameThisGameNoFrameskip-v4
# Phoenix-v0                  Phoenix-v4                  PhoenixNoFrameskip-v0
# PhoenixNoFrameskip-v4       Pitfall-v0                  Pitfall-v4
# PitfallNoFrameskip-v0       PitfallNoFrameskip-v4       Pong-v0
# Pong-v4                     PongNoFrameskip-v0          PongNoFrameskip-v4
# Pooyan-v0                   Pooyan-v4                   PooyanNoFrameskip-v0
# PooyanNoFrameskip-v4        PrivateEye-v0               PrivateEye-v4
# PrivateEyeNoFrameskip-v0    PrivateEyeNoFrameskip-v4    Qbert-v0
# Qbert-v4                    QbertNoFrameskip-v0         QbertNoFrameskip-v4
# Riverraid-v0                Riverraid-v4                RiverraidNoFrameskip-v0
# RiverraidNoFrameskip-v4     RoadRunner-v0               RoadRunner-v4
# RoadRunnerNoFrameskip-v0    RoadRunnerNoFrameskip-v4    Robotank-v0
# Robotank-v4                 RobotankNoFrameskip-v0      RobotankNoFrameskip-v4
# Seaquest-v0                 Seaquest-v4                 SeaquestNoFrameskip-v0
# SeaquestNoFrameskip-v4      Skiing-v0                   Skiing-v4
# SkiingNoFrameskip-v0        SkiingNoFrameskip-v4        Solaris-v0
# Solaris-v4                  SolarisNoFrameskip-v0       SolarisNoFrameskip-v4
# SpaceInvaders-v0            SpaceInvaders-v4            SpaceInvadersNoFrameskip-v0
# SpaceInvadersNoFrameskip-v4 StarGunner-v0               StarGunner-v4
# StarGunnerNoFrameskip-v0    StarGunnerNoFrameskip-v4    Tennis-v0
# Tennis-v4                   TennisNoFrameskip-v0        TennisNoFrameskip-v4
# TimePilot-v0                TimePilot-v4                TimePilotNoFrameskip-v0
# TimePilotNoFrameskip-v4     Tutankham-v0                Tutankham-v4
# TutankhamNoFrameskip-v0     TutankhamNoFrameskip-v4     UpNDown-v0
# UpNDown-v4                  UpNDownNoFrameskip-v0       UpNDownNoFrameskip-v4
# Venture-v0                  Venture-v4                  VentureNoFrameskip-v0
# VentureNoFrameskip-v4       VideoPinball-v0             VideoPinball-v4
# VideoPinballNoFrameskip-v0  VideoPinballNoFrameskip-v4  WizardOfWor-v0
# WizardOfWor-v4              WizardOfWorNoFrameskip-v0   WizardOfWorNoFrameskip-v4
# YarsRevenge-v0              YarsRevenge-v4              YarsRevengeNoFrameskip-v0
# YarsRevengeNoFrameskip-v4   Zaxxon-v0                   Zaxxon-v4
# ZaxxonNoFrameskip-v0        ZaxxonNoFrameskip-v4
# ===== ALE =====
# ALE/Adventure-v5            ALE/AirRaid-v5              ALE/Alien-v5
# ALE/Amidar-v5               ALE/Assault-v5              ALE/Asterix-v5
# ALE/Asteroids-v5            ALE/Atlantis-v5             ALE/Atlantis2-v5
# ALE/Backgammon-v5           ALE/BankHeist-v5            ALE/BasicMath-v5
# ALE/BattleZone-v5           ALE/BeamRider-v5            ALE/Berzerk-v5
# ALE/Blackjack-v5            ALE/Bowling-v5              ALE/Boxing-v5
# ALE/Breakout-v5             ALE/Carnival-v5             ALE/Casino-v5
# ALE/Centipede-v5            ALE/ChopperCommand-v5       ALE/CrazyClimber-v5
# ALE/Crossbow-v5             ALE/Darkchambers-v5         ALE/Defender-v5
# ALE/DemonAttack-v5          ALE/DonkeyKong-v5           ALE/DoubleDunk-v5
# ALE/Earthworld-v5           ALE/ElevatorAction-v5       ALE/Enduro-v5
# ALE/Entombed-v5             ALE/Et-v5                   ALE/FishingDerby-v5
# ALE/FlagCapture-v5          ALE/Freeway-v5              ALE/Frogger-v5
# ALE/Frostbite-v5            ALE/Galaxian-v5             ALE/Gopher-v5
# ALE/Gravitar-v5             ALE/Hangman-v5              ALE/HauntedHouse-v5
# ALE/Hero-v5                 ALE/HumanCannonball-v5      ALE/IceHockey-v5
# ALE/Jamesbond-v5            ALE/JourneyEscape-v5        ALE/Kaboom-v5
# ALE/Kangaroo-v5             ALE/KeystoneKapers-v5       ALE/KingKong-v5
# ALE/Klax-v5                 ALE/Koolaid-v5              ALE/Krull-v5
# ALE/KungFuMaster-v5         ALE/LaserGates-v5           ALE/LostLuggage-v5
# ALE/MarioBros-v5            ALE/MiniatureGolf-v5        ALE/MontezumaRevenge-v5
# ALE/MrDo-v5                 ALE/MsPacman-v5             ALE/NameThisGame-v5
# ALE/Othello-v5              ALE/Pacman-v5               ALE/Phoenix-v5
# ALE/Pitfall-v5              ALE/Pitfall2-v5             ALE/Pong-v5
# ALE/Pooyan-v5               ALE/PrivateEye-v5           ALE/Qbert-v5
# ALE/Riverraid-v5            ALE/RoadRunner-v5           ALE/Robotank-v5
# ALE/Seaquest-v5             ALE/SirLancelot-v5          ALE/Skiing-v5
# ALE/Solaris-v5              ALE/SpaceInvaders-v5        ALE/SpaceWar-v5
# ALE/StarGunner-v5           ALE/Superman-v5             ALE/Surround-v5
# ALE/Tennis-v5               ALE/Tetris-v5               ALE/TicTacToe3D-v5
# ALE/TimePilot-v5            ALE/Trondead-v5             ALE/Turmoil-v5
# ALE/Tutankham-v5            ALE/UpNDown-v5              ALE/Venture-v5
# ALE/VideoCheckers-v5        ALE/VideoChess-v5           ALE/VideoCube-v5
# ALE/VideoPinball-v5         ALE/WizardOfWor-v5          ALE/WordZapper-v5
# ALE/YarsRevenge-v5          ALE/Zaxxon-v5

# %%
import gymnasium as gym
import ale_py
import numpy as np
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from collections import deque

gym.register_envs(ale_py)


# Frame Stack

class LazyFrames:
    def __init__(self, frames):
        self._frames = frames

    def __array__(self, dtype=None):
        out = np.concatenate(self._frames, axis=0)
        if dtype:
            out = out.astype(dtype)
        return out

class FrameStack:
    def __init__(self, env, k=4):
        self.env = env
        self.k = k
        self.frames = deque(maxlen=k)

    def reset(self):
        obs, info = self.env.reset()
        processed = np.expand_dims(obs, 0)
        for _ in range(self.k):
            self.frames.append(processed)
        return LazyFrames(list(self.frames)), info

    def step(self, action):
        obs, reward, terminated, truncated, info = self.env.step(action)
        obs = np.expand_dims(obs, 0)
        self.frames.append(obs)
        return LazyFrames(list(self.frames)), reward, terminated, truncated, info


# Atari Env

def make_env():
    env = gym.make("PongNoFrameskip-v4", frameskip=1)

    env = gym.wrappers.AtariPreprocessing(
        env,
        grayscale_obs=True,
        frame_skip=4,
        screen_size=84
    )

    env = FrameStack(env, k=4)
    return env


# CNN

class DQN(nn.Module):
    def __init__(self, action_dim):
        super().__init__()
        self.conv1 = nn.Conv2d(4, 16, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=4, stride=2)
        self.fc = nn.Linear(32 * 9 * 9, 256)
        self.out = nn.Linear(256, action_dim)

    def forward(self, x):
        x = x / 255.0
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = torch.flatten(x, 1)
        x = F.relu(self.fc(x))
        return self.out(x)



#Replay Buffer (uint8)

class ReplayBuffer:
    def __init__(self, size=50_000):
        self.buffer = deque(maxlen=size)

    def add(self, s, a, r, ns, d):
        self.buffer.append((s, a, r, ns, d))

    def sample(self, batch):
        s, a, r, ns, d = zip(*random.sample(self.buffer, batch))
        return (
            np.array([np.array(x) for x in s], dtype=np.uint8),
            np.array(a),
            np.array(r),
            np.array([np.array(x) for x in ns], dtype=np.uint8),
            np.array(d),
        )

    def __len__(self):
        return len(self.buffer)


#DQN Agent

class Agent:
    def __init__(self):
        self.env = make_env()
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        self.n_actions = 6
        self.policy = DQN(self.n_actions).to(self.device)
        self.target = DQN(self.n_actions).to(self.device)
        self.target.load_state_dict(self.policy.state_dict())

        self.optimizer = optim.Adam(self.policy.parameters(), lr=1e-4)
        self.buffer = ReplayBuffer()

        self.gamma = 0.99
        self.batch = 16
        self.update_target_every = 1500
        self.train_start = 5_000

        self.eps = 1.0
        self.eps_min = 0.05
        self.eps_decay = 300_000
        self.step = 0

    def act(self, state):
        self.step += 1
        self.eps = max(self.eps_min, 1 - self.step / self.eps_decay)

        if random.random() < self.eps:
            return random.randint(0, self.n_actions - 1)

        s = torch.tensor(np.array(state), dtype=torch.float32, device=self.device).unsqueeze(0)
        with torch.no_grad():
            return torch.argmax(self.policy(s)).item()

    def train_step(self):
      if len(self.buffer) < self.train_start:
          return

      s, a, r, ns, d = self.buffer.sample(self.batch)

      s = torch.tensor(s, dtype=torch.float32, device=self.device)
      ns = torch.tensor(ns, dtype=torch.float32, device=self.device)
      a = torch.tensor(a, device=self.device).unsqueeze(1)
      r = torch.tensor(r, dtype=torch.float32, device=self.device).unsqueeze(1)


      d = torch.tensor(d, dtype=torch.float32, device=self.device).unsqueeze(1)

      q = self.policy(s).gather(1, a)

      with torch.no_grad():
          next_q = self.target(ns).max(1)[0].unsqueeze(1)
          not_done = 1.0 - d
          target = r + self.gamma * next_q * not_done

      loss = F.smooth_l1_loss(q, target)

      self.optimizer.zero_grad()
      loss.backward()
      torch.nn.utils.clip_grad_norm_(self.policy.parameters(), 5)
      self.optimizer.step()

      if self.step % self.update_target_every == 0:
        self.target.load_state_dict(self.policy.state_dict())
        print("Target updated at step", self.step)


    def train(self, episodes=200):
        for ep in range(1, episodes + 1):
            s, _ = self.env.reset()
            total_reward = 0

            for _ in range(5000):
                a = self.act(s)
                ns, r, terminated, truncated, _ = self.env.step(a)

                self.buffer.add(s, a, r, ns, terminated)
                self.train_step()

                s = ns
                total_reward += r
                if terminated or truncated:
                    break

            print(f"Episode {ep} | Reward: {total_reward} | Epsilon {self.eps:.3f}")


agent = Agent()
agent.train(episodes=1000)
# Out:
# Episode 1 | Reward: -18.0 | Epsilon 0.996
# Episode 2 | Reward: -20.0 | Epsilon 0.993
# Episode 3 | Reward: -21.0 | Epsilon 0.990
# Episode 4 | Reward: -20.0 | Epsilon 0.987
# Episode 5 | Reward: -21.0 | Epsilon 0.985
# Episode 6 | Reward: -20.0 | Epsilon 0.981
# Target updated at step 6000
# Episode 7 | Reward: -21.0 | Epsilon 0.978
# Target updated at step 7500
# Episode 8 | Reward: -20.0 | Epsilon 0.975
# Episode 9 | Reward: -21.0 | Epsilon 0.972
# Target updated at step 9000
# Episode 10 | Reward: -21.0 | Epsilon 0.968
# Episode 11 | Reward: -21.0 | Epsilon 0.966
# Target updated at step 10500
# Episode 12 | Reward: -20.0 | Epsilon 0.963
# Target updated at step 12000
# Episode 13 | Reward: -21.0 | Epsilon 0.960
# Episode 14 | Reward: -21.0 | Epsilon 0.957
# Target updated at step 13500
# Episode 15 | Reward: -21.0 | Epsilon 0.954
# Episode 16 | Reward: -19.0 | Epsilon 0.951
# Target updated at step 15000
# Episode 17 | Reward: -21.0 | Epsilon 0.948
# Target updated at step 16500
# Episode 18 | Reward: -21.0 | Epsilon 0.945
# Episode 19 | Reward: -21.0 | Epsilon 0.941
# Target updated at step 18000
# Episode 20 | Reward: -21.0 | Epsilon 0.938
# Target updated at step 19500
# Target updated at step 273000
# Episode 230 | Reward: -16.0 | Epsilon 0.085
# Target updated at step 274500
# Target updated at step 276000
# Episode 231 | Reward: -18.0 | Epsilon 0.078
# Target updated at step 277500
# Episode 232 | Reward: -18.0 | Epsilon 0.072
# Target updated at step 279000
# Target updated at step 280500
# Episode 233 | Reward: -10.0 | Epsilon 0.062
# Target updated at step 282000
# Target updated at step 283500
# Episode 234 | Reward: -14.0 | Epsilon 0.054
# Target updated at step 285000
# Episode 235 | Reward: -14.0 | Epsilon 0.050
# Target updated at step 286500
# Target updated at step 288000
# Episode 236 | Reward: -7.0 | Epsilon 0.050
# Target updated at step 289500
# Episode 237 | Reward: -18.0 | Epsilon 0.050
# Target updated at step 291000
# Target updated at step 292500
# Episode 238 | Reward: -12.0 | Epsilon 0.050
# Target updated at step 294000
# Target updated at step 295500
# Episode 239 | Reward: -11.0 | Epsilon 0.050
# Target updated at step 297000
# Target updated at step 298500
# Episode 240 | Reward: -14.0 | Epsilon 0.050
# Target updated at step 300000
# Episode 241 | Reward: -12.0 | Epsilon 0.050
# Target updated at step 301500
# Target updated at step 303000
# Episode 242 | Reward: -18.0 | Epsilon 0.050
# Target updated at step 304500
# Episode 243 | Reward: -18.0 | Epsilon 0.050
# Target updated at step 306000
# Episode 244 | Reward: -17.0 | Epsilon 0.050
# Target updated at step 307500
# Episode 245 | Reward: -15.0 | Epsilon 0.050
# Target updated at step 309000
# Target updated at step 310500
# Episode 246 | Reward: -18.0 | Epsilon 0.050
# Target updated at step 312000
# Episode 247 | Reward: -11.0 | Epsilon 0.050
# Target updated at step 313500
# Target updated at step 315000
# Episode 248 | Reward: -17.0 | Epsilon 0.050
# Target updated at step 316500
# Episode 249 | Reward: -18.0 | Epsilon 0.050
# Target updated at step 318000
# Episode 250 | Reward: -17.0 | Epsilon 0.050
# Target updated at step 319500
# Target updated at step 321000
# Episode 251 | Reward: -17.0 | Epsilon 0.050
# Target updated at step 322500
# Episode 252 | Reward: -18.0 | Epsilon 0.050
# Target updated at step 324000
# Target updated at step 325500
# Episode 253 | Reward: -17.0 | Epsilon 0.050
# Target updated at step 327000
# Episode 254 | Reward: -18.0 | Epsilon 0.050
# Target updated at step 328500
# Episode 255 | Reward: -18.0 | Epsilon 0.050
# Target updated at step 330000
# Target updated at step 331500
# Episode 256 | Reward: -14.0 | Epsilon 0.050
# Target updated at step 333000
# Episode 257 | Reward: -20.0 | Epsilon 0.050
# Target updated at step 334500
# Target updated at step 336000
# Episode 258 | Reward: -21.0 | Epsilon 0.050
# Target updated at step 337500
# Episode 259 | Reward: -19.0 | Epsilon 0.050
# Target updated at step 339000
# Episode 260 | Reward: -20.0 | Epsilon 0.050
# Target updated at step 340500
# Episode 261 | Reward: -18.0 | Epsilon 0.050
# Target updated at step 342000
# Target updated at step 343500
# Episode 262 | Reward: -14.0 | Epsilon 0.050
# Target updated at step 345000
# Episode 263 | Reward: -13.0 | Epsilon 0.050
# Target updated at step 346500
# Episode 264 | Reward: -17.0 | Epsilon 0.050
# Target updated at step 348000
# Target updated at step 349500
# Episode 265 | Reward: -14.0 | Epsilon 0.050
# Target updated at step 351000
# Target updated at step 352500
# Episode 266 | Reward: -15.0 | Epsilon 0.050
# Target updated at step 354000
# Episode 267 | Reward: -18.0 | Epsilon 0.050
# Target updated at step 355500
# Target updated at step 357000
# Episode 268 | Reward: -14.0 | Epsilon 0.050
# Target updated at step 358500
# Target updated at step 360000
# Episode 269 | Reward: -11.0 | Epsilon 0.050
# Target updated at step 361500
# Episode 270 | Reward: -19.0 | Epsilon 0.050
# Target updated at step 363000
# Target updated at step 364500
# Episode 271 | Reward: -16.0 | Epsilon 0.050
# Target updated at step 366000
# Episode 272 | Reward: -19.0 | Epsilon 0.050
# Target updated at step 367500
# Episode 273 | Reward: -16.0 | Epsilon 0.050
# Target updated at step 369000
# Target updated at step 370500
# Episode 274 | Reward: -15.0 | Epsilon 0.050
# Target updated at step 372000
# Episode 275 | Reward: -21.0 | Epsilon 0.050
# Target updated at step 373500
# Episode 276 | Reward: -14.0 | Epsilon 0.050
# Target updated at step 375000
# Target updated at step 376500
# Episode 277 | Reward: -9.0 | Epsilon 0.050
# Target updated at step 378000
# Target updated at step 379500
# Episode 278 | Reward: -13.0 | Epsilon 0.050
# Target updated at step 381000
# Episode 279 | Reward: -18.0 | Epsilon 0.050
# Target updated at step 382500
# Target updated at step 384000
# Episode 280 | Reward: -14.0 | Epsilon 0.050
# Target updated at step 385500
# Target updated at step 387000
# Episode 281 | Reward: -8.0 | Epsilon 0.050
# Target updated at step 388500
# Target updated at step 390000
# Episode 282 | Reward: -16.0 | Epsilon 0.050
# Target updated at step 391500
# Target updated at step 393000
# Episode 283 | Reward: -11.0 | Epsilon 0.050
# Target updated at step 394500
# Episode 284 | Reward: -10.0 | Epsilon 0.050
# Target updated at step 396000
# Target updated at step 397500
# Episode 285 | Reward: -14.0 | Epsilon 0.050
# Target updated at step 399000
# Episode 286 | Reward: -12.0 | Epsilon 0.050
# Target updated at step 400500
# Target updated at step 402000
# Episode 287 | Reward: -14.0 | Epsilon 0.050
# Target updated at step 403500
# Target updated at step 405000
# Episode 288 | Reward: -8.0 | Epsilon 0.050
# Target updated at step 406500
# Target updated at step 408000
# Episode 289 | Reward: -16.0 | Epsilon 0.050
# Target updated at step 409500
# Episode 290 | Reward: -14.0 | Epsilon 0.050
# Target updated at step 411000
# Target updated at step 412500
# Target updated at step 414000
# Episode 291 | Reward: -11.0 | Epsilon 0.050
# Target updated at step 415500
# Episode 292 | Reward: -19.0 | Epsilon 0.050
# Target updated at step 417000
# Target updated at step 418500
# Episode 293 | Reward: -17.0 | Epsilon 0.050
# Target updated at step 420000
# Episode 294 | Reward: -14.0 | Epsilon 0.050
# Target updated at step 421500
# Target updated at step 423000
# Episode 295 | Reward: -14.0 | Epsilon 0.050
# Target updated at step 424500
# Episode 296 | Reward: -19.0 | Epsilon 0.050
# Target updated at step 426000
# Target updated at step 427500
# Episode 297 | Reward: -13.0 | Epsilon 0.050
# Target updated at step 429000
# Episode 298 | Reward: -16.0 | Epsilon 0.050
# Target updated at step 430500
# Target updated at step 432000
# Episode 299 | Reward: -13.0 | Epsilon 0.050
# Target updated at step 433500
# Target updated at step 435000
# Episode 300 | Reward: -12.0 | Epsilon 0.050
# Target updated at step 436500
# Episode 301 | Reward: -15.0 | Epsilon 0.050
# Target updated at step 438000
# Target updated at step 439500
# Episode 302 | Reward: -6.0 | Epsilon 0.050
# Target updated at step 441000
# Episode 303 | Reward: -16.0 | Epsilon 0.050
# Target updated at step 442500
# Target updated at step 444000
# Episode 304 | Reward: -16.0 | Epsilon 0.050
# Target updated at step 445500
# Target updated at step 447000
# Episode 305 | Reward: -12.0 | Epsilon 0.050
# Target updated at step 448500
# Target updated at step 450000
# Episode 306 | Reward: -4.0 | Epsilon 0.050
# Target updated at step 451500
# Target updated at step 453000
# Episode 307 | Reward: -12.0 | Epsilon 0.050
# Target updated at step 454500
# Episode 308 | Reward: -17.0 | Epsilon 0.050
# Target updated at step 456000
# Target updated at step 457500
# Episode 309 | Reward: -10.0 | Epsilon 0.050
# Target updated at step 459000
# Episode 310 | Reward: -12.0 | Epsilon 0.050
# Target updated at step 460500
# Target updated at step 462000
# Episode 311 | Reward: -11.0 | Epsilon 0.050
# Target updated at step 463500
# Target updated at step 465000
# Episode 312 | Reward: -11.0 | Epsilon 0.050
# Target updated at step 466500
# Target updated at step 468000
# Target updated at step 469500
# Episode 313 | Reward: -9.0 | Epsilon 0.050
# Target updated at step 471000
# Episode 314 | Reward: -9.0 | Epsilon 0.050
# Target updated at step 472500
# Target updated at step 474000
# Episode 315 | Reward: -15.0 | Epsilon 0.050
# Target updated at step 475500
# Target updated at step 477000
# Episode 316 | Reward: -13.0 | Epsilon 0.050
# Target updated at step 478500
# Target updated at step 480000
# Episode 317 | Reward: -7.0 | Epsilon 0.050
# Target updated at step 481500
# Target updated at step 483000
# Episode 318 | Reward: -10.0 | Epsilon 0.050
# Target updated at step 484500
# Target updated at step 486000
# Episode 319 | Reward: -10.0 | Epsilon 0.050
# Target updated at step 487500
# Target updated at step 489000
# Episode 320 | Reward: -8.0 | Epsilon 0.050
# Target updated at step 490500
# Target updated at step 492000
# Episode 321 | Reward: -13.0 | Epsilon 0.050
# Target updated at step 493500
# Target updated at step 495000
# Episode 322 | Reward: -5.0 | Epsilon 0.050
# Target updated at step 496500
# Target updated at step 498000
# Episode 323 | Reward: 1.0 | Epsilon 0.050
# Target updated at step 499500
# Target updated at step 501000
# Episode 324 | Reward: -7.0 | Epsilon 0.050
# Target updated at step 502500
# Target updated at step 504000
# Episode 325 | Reward: -11.0 | Epsilon 0.050
# Target updated at step 505500
# Target updated at step 507000
# Episode 326 | Reward: -5.0 | Epsilon 0.050
# Target updated at step 508500
# Target updated at step 510000
# Episode 327 | Reward: 8.0 | Epsilon 0.050
# Target updated at step 511500
# Target updated at step 513000
# Episode 328 | Reward: -6.0 | Epsilon 0.050
# Target updated at step 514500
# Target updated at step 516000
# Target updated at step 517500
# Episode 329 | Reward: 1.0 | Epsilon 0.050
# Target updated at step 519000
# Episode 330 | Reward: -11.0 | Epsilon 0.050
# Target updated at step 520500
# Target updated at step 522000
# Episode 331 | Reward: 3.0 | Epsilon 0.050
# Target updated at step 523500
# Target updated at step 525000
# Episode 332 | Reward: -3.0 | Epsilon 0.050
# Target updated at step 526500
# Target updated at step 528000
# Episode 333 | Reward: -11.0 | Epsilon 0.050
# Target updated at step 529500
# Target updated at step 531000
# Episode 334 | Reward: -4.0 | Epsilon 0.050
# Target updated at step 532500
# Target updated at step 534000
# Episode 335 | Reward: -10.0 | Epsilon 0.050
# Target updated at step 535500
# Target updated at step 537000
# Episode 336 | Reward: 4.0 | Epsilon 0.050
# Target updated at step 538500
# Target updated at step 540000
# Episode 337 | Reward: 2.0 | Epsilon 0.050
# Target updated at step 541500
# Target updated at step 543000
# Episode 338 | Reward: -11.0 | Epsilon 0.050
# Target updated at step 544500
# Target updated at step 546000
# Episode 339 | Reward: -1.0 | Epsilon 0.050
# Target updated at step 547500
# Target updated at step 549000
# Episode 340 | Reward: -7.0 | Epsilon 0.050
# Target updated at step 550500
# Target updated at step 552000
# Episode 341 | Reward: -14.0 | Epsilon 0.050
# Target updated at step 553500
# Episode 342 | Reward: -3.0 | Epsilon 0.050
# Target updated at step 555000
# Target updated at step 556500
# Episode 343 | Reward: -8.0 | Epsilon 0.050
# Target updated at step 558000
# Target updated at step 559500
# Episode 344 | Reward: -9.0 | Epsilon 0.050
# Target updated at step 561000
# Target updated at step 562500
# Episode 345 | Reward: -5.0 | Epsilon 0.050
# Target updated at step 564000
# Episode 346 | Reward: -17.0 | Epsilon 0.050
# Target updated at step 565500
# Target updated at step 567000
# Episode 347 | Reward: -6.0 | Epsilon 0.050
# Target updated at step 568500
# Target updated at step 570000
# Episode 348 | Reward: -7.0 | Epsilon 0.050
# Target updated at step 571500
# Target updated at step 573000
# Episode 349 | Reward: -5.0 | Epsilon 0.050
# Target updated at step 574500
# Target updated at step 576000
# Episode 350 | Reward: -7.0 | Epsilon 0.050
# Target updated at step 577500
# Episode 351 | Reward: -13.0 | Epsilon 0.050
# Target updated at step 579000
# Target updated at step 580500
# Episode 352 | Reward: -2.0 | Epsilon 0.050
# Target updated at step 582000
# Target updated at step 583500
# Episode 353 | Reward: -8.0 | Epsilon 0.050
# Target updated at step 585000
# Target updated at step 586500
# Target updated at step 588000
# Episode 354 | Reward: -7.0 | Epsilon 0.050
# Target updated at step 589500
# Episode 355 | Reward: 2.0 | Epsilon 0.050
# Target updated at step 591000
# Target updated at step 592500
# Episode 356 | Reward: -4.0 | Epsilon 0.050
# Target updated at step 594000
# Target updated at step 595500
# Episode 357 | Reward: -9.0 | Epsilon 0.050
# Target updated at step 597000
# Target updated at step 598500
# Episode 358 | Reward: -8.0 | Epsilon 0.050
# Target updated at step 600000
# Target updated at step 601500
# Episode 359 | Reward: -7.0 | Epsilon 0.050
# Target updated at step 603000
# Target updated at step 604500
# Episode 360 | Reward: -4.0 | Epsilon 0.050
# Target updated at step 606000
# Target updated at step 607500
# Episode 361 | Reward: 2.0 | Epsilon 0.050
# Target updated at step 609000
# Target updated at step 610500
# Target updated at step 612000
# Episode 362 | Reward: -1.0 | Epsilon 0.050
# Target updated at step 613500
# Target updated at step 615000
# Episode 363 | Reward: 3.0 | Epsilon 0.050
# Target updated at step 616500
# Target updated at step 618000
# Episode 364 | Reward: -6.0 | Epsilon 0.050
# Target updated at step 619500
# Target updated at step 621000
# Episode 365 | Reward: -2.0 | Epsilon 0.050
# Target updated at step 622500
# Target updated at step 624000
# Target updated at step 625500
# Episode 366 | Reward: -1.0 | Epsilon 0.050
# Target updated at step 627000
# Target updated at step 628500
# Episode 367 | Reward: 2.0 | Epsilon 0.050
# Target updated at step 630000
# Target updated at step 631500
# Episode 368 | Reward: 2.0 | Epsilon 0.050
# Target updated at step 633000
# Target updated at step 634500
# Episode 369 | Reward: -9.0 | Epsilon 0.050
# Target updated at step 636000
# Target updated at step 637500
# Target updated at step 639000
# Episode 370 | Reward: -1.0 | Epsilon 0.050
# Target updated at step 640500
# Target updated at step 642000
# Episode 371 | Reward: 4.0 | Epsilon 0.050
# Target updated at step 643500
# Target updated at step 645000
# Episode 372 | Reward: -3.0 | Epsilon 0.050
# Target updated at step 646500
# Target updated at step 648000
# Episode 373 | Reward: -11.0 | Epsilon 0.050
# Target updated at step 649500
# Target updated at step 651000
# Episode 374 | Reward: -6.0 | Epsilon 0.050
# Target updated at step 652500
# Target updated at step 654000
# Episode 375 | Reward: 2.0 | Epsilon 0.050
# Target updated at step 655500
# Target updated at step 657000
# Target updated at step 658500
# Episode 376 | Reward: -5.0 | Epsilon 0.050
# Target updated at step 660000
# Target updated at step 661500
# Episode 377 | Reward: -3.0 | Epsilon 0.050
# Target updated at step 663000
# Target updated at step 664500
# Episode 378 | Reward: -7.0 | Epsilon 0.050
# Target updated at step 666000
# Target updated at step 667500
# Episode 379 | Reward: -8.0 | Epsilon 0.050
# Target updated at step 669000
# Target updated at step 670500
# Episode 380 | Reward: -5.0 | Epsilon 0.050
# Target updated at step 672000
# Target updated at step 673500
# Episode 381 | Reward: -2.0 | Epsilon 0.050
# Target updated at step 675000
# Target updated at step 676500
# Episode 382 | Reward: -4.0 | Epsilon 0.050
# Target updated at step 678000
# Target updated at step 679500
# Episode 383 | Reward: -7.0 | Epsilon 0.050
# Target updated at step 681000
# Target updated at step 682500
# Episode 384 | Reward: -7.0 | Epsilon 0.050
# Target updated at step 684000
# Target updated at step 685500
# Target updated at step 687000
# Episode 385 | Reward: -7.0 | Epsilon 0.050
# Target updated at step 688500
# Target updated at step 690000
# Episode 386 | Reward: 1.0 | Epsilon 0.050
# Target updated at step 691500
# Target updated at step 693000
# Episode 387 | Reward: 3.0 | Epsilon 0.050
# Target updated at step 694500
# Target updated at step 696000
# Target updated at step 697500
# Episode 388 | Reward: -1.0 | Epsilon 0.050
# Target updated at step 699000
# Target updated at step 700500
# Episode 389 | Reward: 1.0 | Epsilon 0.050
# Target updated at step 702000
# Target updated at step 703500
# Episode 390 | Reward: -5.0 | Epsilon 0.050
# Target updated at step 705000
# Target updated at step 706500
# Episode 391 | Reward: -7.0 | Epsilon 0.050
# Target updated at step 708000
# Target updated at step 709500
# Episode 392 | Reward: -2.0 | Epsilon 0.050
# Target updated at step 711000
# Target updated at step 712500
# Episode 393 | Reward: -6.0 | Epsilon 0.050
# Target updated at step 714000
# Target updated at step 715500
# Episode 394 | Reward: -6.0 | Epsilon 0.050
# Target updated at step 717000
# Target updated at step 718500
# Episode 395 | Reward: 1.0 | Epsilon 0.050
# Target updated at step 720000
# Target updated at step 721500
# Episode 396 | Reward: 5.0 | Epsilon 0.050
# Target updated at step 723000
# Target updated at step 724500
# Episode 397 | Reward: 7.0 | Epsilon 0.050
# Target updated at step 726000
# Target updated at step 727500
# Target updated at step 729000
# Episode 398 | Reward: -2.0 | Epsilon 0.050
# Target updated at step 730500
# Target updated at step 732000
# Episode 399 | Reward: 3.0 | Epsilon 0.050
# Target updated at step 733500
# Target updated at step 735000
# Episode 400 | Reward: 2.0 | Epsilon 0.050
# Target updated at step 736500
# Target updated at step 738000
# Target updated at step 739500
# Episode 401 | Reward: 6.0 | Epsilon 0.050
# Target updated at step 741000
# Target updated at step 742500
# Episode 402 | Reward: 2.0 | Epsilon 0.050
# Target updated at step 744000
# Episode 403 | Reward: 8.0 | Epsilon 0.050
# Target updated at step 745500
# Target updated at step 747000
# Target updated at step 748500
# Episode 404 | Reward: 1.0 | Epsilon 0.050
# Target updated at step 750000
# Target updated at step 751500
# Episode 405 | Reward: 4.0 | Epsilon 0.050
# Target updated at step 753000
# Target updated at step 754500
# Episode 406 | Reward: 2.0 | Epsilon 0.050
# Target updated at step 756000
# Target updated at step 757500
# Episode 407 | Reward: 6.0 | Epsilon 0.050
# Target updated at step 759000
# Target updated at step 760500
# Episode 408 | Reward: 4.0 | Epsilon 0.050
# Target updated at step 762000
# Target updated at step 763500
# Episode 409 | Reward: 10.0 | Epsilon 0.050
# Target updated at step 765000
# Target updated at step 766500
# Episode 410 | Reward: 4.0 | Epsilon 0.050
# Target updated at step 768000
# Target updated at step 769500
# Episode 411 | Reward: 8.0 | Epsilon 0.050
# Target updated at step 771000
# Target updated at step 772500
# Episode 412 | Reward: 2.0 | Epsilon 0.050
# Target updated at step 774000
# Target updated at step 775500
# Episode 413 | Reward: 5.0 | Epsilon 0.050
# Target updated at step 777000
# Target updated at step 778500
# Episode 414 | Reward: -1.0 | Epsilon 0.050
# Target updated at step 780000
# Target updated at step 781500
# Episode 415 | Reward: 7.0 | Epsilon 0.050
# Target updated at step 783000
# Target updated at step 784500
# Episode 416 | Reward: -1.0 | Epsilon 0.050
# Target updated at step 786000
# Target updated at step 787500
# Episode 417 | Reward: 11.0 | Epsilon 0.050
# Target updated at step 789000
# Target updated at step 790500
# Episode 418 | Reward: 9.0 | Epsilon 0.050
# Target updated at step 792000
# Target updated at step 793500
# Episode 419 | Reward: 2.0 | Epsilon 0.050
# Target updated at step 795000
# Episode 420 | Reward: -7.0 | Epsilon 0.050
# Target updated at step 796500
# Target updated at step 798000
# Episode 421 | Reward: 6.0 | Epsilon 0.050
# Target updated at step 799500
# Target updated at step 801000
# Episode 422 | Reward: 8.0 | Epsilon 0.050
# Target updated at step 802500
# Target updated at step 804000
# Episode 423 | Reward: 7.0 | Epsilon 0.050
# Target updated at step 805500
# Target updated at step 807000
# Episode 424 | Reward: 13.0 | Epsilon 0.050
# Target updated at step 808500
# Target updated at step 810000
# Episode 425 | Reward: 8.0 | Epsilon 0.050
# Target updated at step 811500
# Episode 426 | Reward: 15.0 | Epsilon 0.050
# Target updated at step 813000
# Target updated at step 814500
# Target updated at step 816000
# Episode 427 | Reward: 3.0 | Epsilon 0.050
# Target updated at step 817500
# Target updated at step 819000
# Episode 428 | Reward: -1.0 | Epsilon 0.050
# Target updated at step 820500
# Target updated at step 822000
# Episode 429 | Reward: 7.0 | Epsilon 0.050
# Target updated at step 823500
# Target updated at step 825000
# Episode 430 | Reward: 4.0 | Epsilon 0.050
# Target updated at step 826500
# Episode 431 | Reward: 9.0 | Epsilon 0.050
# Target updated at step 828000
# Target updated at step 829500
# Episode 432 | Reward: 15.0 | Epsilon 0.050
# Target updated at step 831000
# Episode 433 | Reward: 15.0 | Epsilon 0.050
# Target updated at step 832500
# Target updated at step 834000
# Episode 434 | Reward: 5.0 | Epsilon 0.050
# Target updated at step 835500
# Target updated at step 837000
# Target updated at step 838500
# Episode 435 | Reward: -4.0 | Epsilon 0.050
# Target updated at step 840000
# Target updated at step 841500
# Episode 436 | Reward: 7.0 | Epsilon 0.050
# Target updated at step 843000
# Target updated at step 844500
# Episode 437 | Reward: -6.0 | Epsilon 0.050
# Target updated at step 846000
# Episode 438 | Reward: 10.0 | Epsilon 0.050
# Target updated at step 847500
# Target updated at step 849000
# Episode 439 | Reward: 15.0 | Epsilon 0.050
# Target updated at step 850500
# Target updated at step 852000
# Episode 440 | Reward: 12.0 | Epsilon 0.050
# Target updated at step 853500
# Target updated at step 855000
# Episode 441 | Reward: 8.0 | Epsilon 0.050
# Target updated at step 856500
# Target updated at step 858000
# Episode 442 | Reward: 6.0 | Epsilon 0.050
# Target updated at step 859500
# Target updated at step 861000
# Episode 443 | Reward: 12.0 | Epsilon 0.050
# Target updated at step 862500
# Target updated at step 864000
# Episode 444 | Reward: 5.0 | Epsilon 0.050
# Target updated at step 865500
# Target updated at step 867000
# Episode 445 | Reward: 5.0 | Epsilon 0.050
# Target updated at step 868500
# Target updated at step 870000
# Episode 446 | Reward: 2.0 | Epsilon 0.050
# Target updated at step 871500
# Target updated at step 873000
# Target updated at step 874500
# Episode 447 | Reward: -1.0 | Epsilon 0.050
# Target updated at step 876000
# Episode 448 | Reward: 12.0 | Epsilon 0.050
# Target updated at step 877500
# Episode 449 | Reward: 16.0 | Epsilon 0.050
# Target updated at step 879000
# Target updated at step 880500
# Target updated at step 882000
# Episode 450 | Reward: 10.0 | Epsilon 0.050
# Target updated at step 883500
# Episode 451 | Reward: 15.0 | Epsilon 0.050
# Target updated at step 885000
# Target updated at step 886500
# Episode 452 | Reward: 7.0 | Epsilon 0.050
# Target updated at step 888000
# Target updated at step 889500
# Episode 453 | Reward: -4.0 | Epsilon 0.050
# Target updated at step 891000
# Target updated at step 892500
# Episode 454 | Reward: 16.0 | Epsilon 0.050
# Target updated at step 894000
# Target updated at step 895500
# Episode 455 | Reward: 5.0 | Epsilon 0.050
# Target updated at step 897000
# Target updated at step 898500
# Episode 456 | Reward: 8.0 | Epsilon 0.050
# Target updated at step 900000
# Target updated at step 901500
# Episode 457 | Reward: 11.0 | Epsilon 0.050
# Target updated at step 903000
# Target updated at step 904500
# Episode 458 | Reward: 11.0 | Epsilon 0.050
# Target updated at step 906000
# Target updated at step 907500
# Episode 459 | Reward: 2.0 | Epsilon 0.050
# Target updated at step 909000
# Target updated at step 910500
# Episode 460 | Reward: 7.0 | Epsilon 0.050
# Target updated at step 912000
# Episode 461 | Reward: 12.0 | Epsilon 0.050
# Target updated at step 913500
# Target updated at step 915000
# Episode 462 | Reward: 10.0 | Epsilon 0.050
# Target updated at step 916500
# Target updated at step 918000
# Episode 463 | Reward: 14.0 | Epsilon 0.050
# Target updated at step 919500
# Target updated at step 921000
# Episode 464 | Reward: 10.0 | Epsilon 0.050
# Target updated at step 922500
# Episode 465 | Reward: 13.0 | Epsilon 0.050
# Target updated at step 924000
# Target updated at step 925500
# Episode 466 | Reward: 14.0 | Epsilon 0.050
# Target updated at step 927000
# Episode 467 | Reward: 17.0 | Epsilon 0.050
# Target updated at step 928500
# Episode 468 | Reward: 20.0 | Epsilon 0.050
# Target updated at step 930000
# Target updated at step 931500
# Episode 469 | Reward: 12.0 | Epsilon 0.050
# Target updated at step 933000
# Target updated at step 934500
# Episode 470 | Reward: 11.0 | Epsilon 0.050
# Target updated at step 936000
# Episode 471 | Reward: 10.0 | Epsilon 0.050
# Target updated at step 937500
# Target updated at step 939000
# Episode 472 | Reward: 15.0 | Epsilon 0.050
# Target updated at step 940500
# Episode 473 | Reward: 16.0 | Epsilon 0.050
# Target updated at step 942000
# Target updated at step 943500
# Episode 474 | Reward: 17.0 | Epsilon 0.050
# Target updated at step 945000
# Episode 475 | Reward: 17.0 | Epsilon 0.050
# Target updated at step 946500
# Episode 476 | Reward: 17.0 | Epsilon 0.050
# Target updated at step 948000
# Target updated at step 949500
# Episode 477 | Reward: 7.0 | Epsilon 0.050
# Target updated at step 951000
# Episode 478 | Reward: 19.0 | Epsilon 0.050
# Target updated at step 952500
# Target updated at step 954000
# Episode 479 | Reward: 16.0 | Epsilon 0.050
# Target updated at step 955500
# Episode 480 | Reward: 18.0 | Epsilon 0.050
# Target updated at step 957000
# Episode 481 | Reward: 16.0 | Epsilon 0.050
# Target updated at step 958500
# Target updated at step 960000
# Episode 482 | Reward: 8.0 | Epsilon 0.050
# Target updated at step 961500
# Target updated at step 963000
# Episode 483 | Reward: 12.0 | Epsilon 0.050
# Target updated at step 964500
# Episode 484 | Reward: 14.0 | Epsilon 0.050
# Target updated at step 966000
# Target updated at step 967500
# Episode 485 | Reward: 18.0 | Epsilon 0.050
# Target updated at step 969000
# Episode 486 | Reward: 15.0 | Epsilon 0.050
# Target updated at step 970500
# Episode 487 | Reward: 16.0 | Epsilon 0.050
# Target updated at step 972000
# Target updated at step 973500
# Episode 488 | Reward: 17.0 | Epsilon 0.050
# Target updated at step 975000
# Episode 489 | Reward: 20.0 | Epsilon 0.050
# Target updated at step 976500
# Episode 490 | Reward: 11.0 | Epsilon 0.050
# Target updated at step 978000
# Target updated at step 979500
# Episode 491 | Reward: 19.0 | Epsilon 0.050
# Target updated at step 981000
# Episode 492 | Reward: 11.0 | Epsilon 0.050
# Target updated at step
| Reward: 19.0 | Epsilon 0.050
# Target updated at step 1966500
# Target updated at step 1968000
# Episode 996 | Reward: 19.0 | Epsilon 0.050
# Target updated at step 1969500
# Episode 997 | Reward: 18.0 | Epsilon 0.050
# Target updated at step 1971000
# Episode 998 | Reward: 18.0 | Epsilon 0.050
# Target updated at step 1972500
# Target updated at step 1974000
# Episode 999 | Reward: 13.0 | Epsilon 0.050
# Target updated at step 1975500
# Episode 1000 | Reward: 21.0 | Epsilon 0.050

# %%
torch.save(agent.policy.state_dict(), "pong_dqn.pth")

# %%
import re
import matplotlib.pyplot as plt

# Load file
log_path = "/content/dqn_pong.txt"
with open(log_path, "r") as f:
    lines = f.readlines()

episodes = []
rewards = []


pattern = r"Episode\s+(\d+)\s*\|\s*Reward:\s*(-?\d+\.?\d*)"

for line in lines:
    match = re.search(pattern, line)
    if match:
        ep = int(match.group(1))
        rew = float(match.group(2))
        episodes.append(ep)
        rewards.append(rew)

print("Parsed episodes:", len(episodes))

# Plot
plt.figure(figsize=(14,6))
plt.plot(episodes, rewards, alpha=0.4, label="Reward (raw)")

# Moving average smoothing
import numpy as np
window = 20
if len(rewards) >= window:
    smooth = np.convolve(rewards, np.ones(window)/window, mode='valid')
    plt.plot(episodes[window-1:], smooth, color='red', linewidth=2, label=f"Moving Avg ({window})")

plt.title("DQN Training Reward Over Time (Pong)")
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Parsed episodes: 1000

# %%
MODEL_PATH = "/content/pong_dqn.pth"

# %%
import gymnasium as gym
import ale_py
import numpy as np
from collections import deque
from gymnasium.wrappers import RecordVideo

gym.register_envs(ale_py)

class LazyFrames:
    def __init__(self, frames):
        self._frames = frames
    def __array__(self, dtype=None):
        out = np.concatenate(self._frames, axis=0)
        if dtype:
            out = out.astype(dtype)
        return out

class FrameStack:
    def __init__(self, env, k=4):
        self.env = env
        self.k = k
        self.frames = deque(maxlen=k)

    def reset(self):
        obs, info = self.env.reset()
        processed = np.expand_dims(obs, 0)
        for _ in range(self.k):
            self.frames.append(processed)
        return LazyFrames(list(self.frames)), info

    def step(self, action):
        obs, reward, terminated, truncated, info = self.env.step(action)
        obs = np.expand_dims(obs, 0)
        self.frames.append(obs)
        return LazyFrames(list(self.frames)), reward, terminated, truncated, info


    def close(self):
        if hasattr(self.env, "close"):
            self.env.close()



def make_eval_env():
    env = gym.make("PongNoFrameskip-v4", frameskip=1, render_mode="rgb_array")

    env = gym.wrappers.AtariPreprocessing(
        env,
        grayscale_obs=True,
        frame_skip=4,
        screen_size=84
    )


    env = gym.wrappers.RecordVideo(env, "/content/pong_eval/", episode_trigger=lambda e: True)


    env = FrameStack(env, k=4)

    return env

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

policy = DQN(action_dim=6).to(device)

MODEL_PATH = "/content/pong_dqn.pth"

policy.load_state_dict(torch.load(MODEL_PATH, map_location=device))
policy.eval()

print("Model loaded!")
# Out:
# Model loaded!

# %%
import numpy as np

env = make_eval_env()

obs, _ = env.reset()
done = False
total_reward = 0

while not done:
    s = torch.tensor(np.array(obs), dtype=torch.float32, device=device).unsqueeze(0)

    with torch.no_grad():
        action = torch.argmax(policy(s)).item()

    obs, reward, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
    total_reward += reward

print("Episode reward:", total_reward)
env.env.close()
# Out:
# /usr/local/lib/python3.12/dist-packages/gymnasium/wrappers/rendering.py:293: UserWarning: WARN: Overwriting existing videos at /content/pong_eval folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Episode reward: 20.0
