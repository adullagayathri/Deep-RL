# %%
# !sudo update-alternatives --config python3
# Out:
# There are 2 choices for the alternative python3 (providing /usr/bin/python3).
#
#   Selection    Path                 Priority   Status
# ------------------------------------------------------------
# * 0            /usr/bin/python3.12   2         auto mode
#   1            /usr/bin/python3.10   1         manual mode
#   2            /usr/bin/python3.12   2         manual mode
#
# Press <enter> to keep the current choice[*], or type selection number: 1
# update-alternatives: using /usr/bin/python3.10 to provide /usr/bin/python3 (python3) in manual mode

# %%
# !python3 -m pip install --upgrade pip
# !python3 -m pip install "gymnasium[atari]" ale-py autorom
# Out:
# /usr/bin/python3: No module named pip
# /usr/bin/python3: No module named pip

# %%
# !which python3
# !python3 --version
# Out:
# /usr/bin/python3
# Python 3.10.12

# %%
# !wget https://bootstrap.pypa.io/get-pip.py
# !python3 get-pip.py
# Out:
# --2025-12-03 04:56:19--  https://bootstrap.pypa.io/get-pip.py
# Resolving bootstrap.pypa.io (bootstrap.pypa.io)... 151.101.0.175, 151.101.64.175, 151.101.128.175, ...
# Connecting to bootstrap.pypa.io (bootstrap.pypa.io)|151.101.0.175|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2182415 (2.1M) [text/x-python]
# Saving to: ‘get-pip.py’
#
# get-pip.py          100%[===================>]   2.08M  --.-KB/s    in 0.06s
#
# 2025-12-03 04:56:19 (36.5 MB/s) - ‘get-pip.py’ saved [2182415/2182415]
#
# Collecting pip
#   Downloading pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Collecting setuptools
#   Downloading setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting wheel
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Downloading pip-25.3-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 38.6 MB/s  0:00:00
# Downloading setuptools-80.9.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 72.6 MB/s  0:00:00
# Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
# Installing collected packages: wheel, setuptools, pip
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pip]
# Successfully installed pip-25.3 setuptools-80.9.0 wheel-0.45.1

# %%
# !python3 -m pip --version
# Out:
# pip 25.3 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)

# %%
# !python3 -m pip install "gymnasium[atari]==0.29.1"
# !python3 -m pip install "ale-py==0.8.1"
# !python3 -m pip install autorom
# Out:
# Collecting gymnasium==0.29.1 (from gymnasium[atari]==0.29.1)
#   Downloading gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Collecting numpy>=1.21.0 (from gymnasium==0.29.1->gymnasium[atari]==0.29.1)
#   Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting cloudpickle>=1.2.0 (from gymnasium==0.29.1->gymnasium[atari]==0.29.1)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-extensions>=4.3.0 (from gymnasium==0.29.1->gymnasium[atari]==0.29.1)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting farama-notifications>=0.0.1 (from gymnasium==0.29.1->gymnasium[atari]==0.29.1)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Collecting shimmy<1.0,>=0.1.0 (from shimmy[atari]<1.0,>=0.1.0; extra == "atari"->gymnasium[atari]==0.29.1)
#   Downloading Shimmy-0.2.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting ale-py~=0.8.1 (from shimmy[atari]<1.0,>=0.1.0; extra == "atari"->gymnasium[atari]==0.29.1)
#   Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Collecting importlib-resources (from ale-py~=0.8.1->shimmy[atari]<1.0,>=0.1.0; extra == "atari"->gymnasium[atari]==0.29.1)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 8.0 MB/s  0:00:00
# Downloading Shimmy-0.2.1-py3-none-any.whl (25 kB)
# Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 13.4 MB/s  0:00:00
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 43.2 MB/s  0:00:00
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Installing collected packages: farama-notifications, typing-extensions, numpy, importlib-resources, cloudpickle, gymnasium, ale-py, shimmy
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [shimmy]
# Successfully installed ale-py-0.8.1 cloudpickle-3.1.2 farama-notifications-0.0.4 gymnasium-0.29.1 importlib-resources-6.5.2 numpy-2.2.6 shimmy-0.2.1 typing-extensions-4.15.0
# Requirement already satisfied: ale-py==0.8.1 in /usr/local/lib/python3.10/dist-packages (0.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ale-py==0.8.1) (2.2.6)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py==0.8.1) (6.5.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from ale-py==0.8.1) (4.15.0)
# Collecting autorom
#   Downloading AutoROM-0.6.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting click (from autorom)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting requests (from autorom)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting charset_normalizer<4,>=2 (from requests->autorom)
#   Downloading charset_normalizer-3.4.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests->autorom)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->autorom)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests->autorom)
#   Downloading certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (153 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading certifi-2025.11.12-py3-none-any.whl (159 kB)
# Installing collected packages: urllib3, idna, click, charset_normalizer, certifi, requests, autorom
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [autorom]
# Successfully installed autorom-0.6.1 certifi-2025.11.12 charset_normalizer-3.4.4 click-8.3.1 idna-3.11 requests-2.32.5 urllib3-2.5.0

# %%
# !python3 -m pip install "gymnasium[atari]" ale-py AutoROM AutoROM.accept-rom-license

# !python3 -m AutoROM.accept_rom_license --accept-license
# Out:
# Requirement already satisfied: ale-py in /usr/local/lib/python3.10/dist-packages (0.8.1)
# Requirement already satisfied: AutoROM in /usr/local/lib/python3.10/dist-packages (0.6.1)
# Collecting AutoROM.accept-rom-license
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: gymnasium[atari] in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (2.2.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (0.0.4)
# Requirement already satisfied: shimmy<1.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from shimmy[atari]<1.0,>=0.1.0; extra == "atari"->gymnasium[atari]) (0.2.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py) (6.5.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from AutoROM) (8.3.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from AutoROM) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->AutoROM) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->AutoROM) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->AutoROM) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->AutoROM) (2025.11.12)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=autorom_accept_rom_license-0.6.1-py3-none-any.whl size=446709 sha256=891d0a605427e084592f82eefa3bd6ebada30c3699e2e96c3c300ad65e278e34
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: AutoROM.accept-rom-license
# Successfully installed AutoROM.accept-rom-license-0.6.1
# /usr/bin/python3: No module named AutoROM.accept_rom_license

# %%
import gymnasium as gym
import ale_py

gym.register_envs(ale_py)
print("Atari envs registered!")

gym.pprint_registry()
# Out:
# Atari envs registered!
# ===== classic_control =====
# Acrobot-v1                  CartPole-v0                 CartPole-v1
# MountainCar-v0              MountainCarContinuous-v0    Pendulum-v1
# ===== phys2d =====
# phys2d/CartPole-v0          phys2d/CartPole-v1          phys2d/Pendulum-v0
# ===== box2d =====
# BipedalWalker-v3            BipedalWalkerHardcore-v3    CarRacing-v3
# LunarLander-v3              LunarLanderContinuous-v3
# ===== toy_text =====
# Blackjack-v1                CliffWalking-v1             CliffWalkingSlippery-v1
# FrozenLake-v1               FrozenLake8x8-v1            Taxi-v3
# ===== tabular =====
# tabular/Blackjack-v0        tabular/CliffWalking-v0
# ===== None =====
# Ant-v2                      Ant-v3                      GymV21Environment-v0
# GymV26Environment-v0        HalfCheetah-v2              HalfCheetah-v3
# Hopper-v2                   Hopper-v3                   Humanoid-v2
# Humanoid-v3                 HumanoidStandup-v2          InvertedDoublePendulum-v2
# InvertedPendulum-v2         Pusher-v2                   Reacher-v2
# Swimmer-v2                  Swimmer-v3                  Walker2d-v2
# Walker2d-v3
# ===== mujoco =====
# Ant-v4                      Ant-v5                      HalfCheetah-v4
# HalfCheetah-v5              Hopper-v4                   Hopper-v5
# Humanoid-v4                 Humanoid-v5                 HumanoidStandup-v4
# HumanoidStandup-v5          InvertedDoublePendulum-v4   InvertedDoublePendulum-v5
# InvertedPendulum-v4         InvertedPendulum-v5         Pusher-v4
# Pusher-v5                   Reacher-v4                  Reacher-v5
# Swimmer-v4                  Swimmer-v5                  Walker2d-v4
# Walker2d-v5
# ===== env =====
# Adventure-v0                Adventure-v4                AdventureNoFrameskip-v0
# AdventureNoFrameskip-v4     AirRaid-v0                  AirRaid-v4
# AirRaidNoFrameskip-v0       AirRaidNoFrameskip-v4       Alien-v0
# Alien-v4                    AlienNoFrameskip-v0         AlienNoFrameskip-v4
# Amidar-v0                   Amidar-v4                   AmidarNoFrameskip-v0
# AmidarNoFrameskip-v4        Assault-v0                  Assault-v4
# AssaultNoFrameskip-v0       AssaultNoFrameskip-v4       Asterix-v0
# Asterix-v4                  AsterixNoFrameskip-v0       AsterixNoFrameskip-v4
# Asteroids-v0                Asteroids-v4                AsteroidsNoFrameskip-v0
# AsteroidsNoFrameskip-v4     Atlantis-v0                 Atlantis-v4
# AtlantisNoFrameskip-v0      AtlantisNoFrameskip-v4      BankHeist-v0
# BankHeist-v4                BankHeistNoFrameskip-v0     BankHeistNoFrameskip-v4
# BattleZone-v0               BattleZone-v4               BattleZoneNoFrameskip-v0
# BattleZoneNoFrameskip-v4    BeamRider-v0                BeamRider-v4
# BeamRiderNoFrameskip-v0     BeamRiderNoFrameskip-v4     Berzerk-v0
# Berzerk-v4                  BerzerkNoFrameskip-v0       BerzerkNoFrameskip-v4
# Bowling-v0                  Bowling-v4                  BowlingNoFrameskip-v0
# BowlingNoFrameskip-v4       Boxing-v0                   Boxing-v4
# BoxingNoFrameskip-v0        BoxingNoFrameskip-v4        Breakout-v0
# Breakout-v4                 BreakoutNoFrameskip-v0      BreakoutNoFrameskip-v4
# Carnival-v0                 Carnival-v4                 CarnivalNoFrameskip-v0
# CarnivalNoFrameskip-v4      Centipede-v0                Centipede-v4
# CentipedeNoFrameskip-v0     CentipedeNoFrameskip-v4     ChopperCommand-v0
# ChopperCommand-v4           ChopperCommandNoFrameskip-v0 ChopperCommandNoFrameskip-v4
# CrazyClimber-v0             CrazyClimber-v4             CrazyClimberNoFrameskip-v0
# CrazyClimberNoFrameskip-v4  Defender-v0                 Defender-v4
# DefenderNoFrameskip-v0      DefenderNoFrameskip-v4      DemonAttack-v0
# DemonAttack-v4              DemonAttackNoFrameskip-v0   DemonAttackNoFrameskip-v4
# DoubleDunk-v0               DoubleDunk-v4               DoubleDunkNoFrameskip-v0
# DoubleDunkNoFrameskip-v4    ElevatorAction-v0           ElevatorAction-v4
# ElevatorActionNoFrameskip-v0 ElevatorActionNoFrameskip-v4 Enduro-v0
# Enduro-v4                   EnduroNoFrameskip-v0        EnduroNoFrameskip-v4
# FishingDerby-v0             FishingDerby-v4             FishingDerbyNoFrameskip-v0
# FishingDerbyNoFrameskip-v4  Freeway-v0                  Freeway-v4
# FreewayNoFrameskip-v0       FreewayNoFrameskip-v4       Frostbite-v0
# Frostbite-v4                FrostbiteNoFrameskip-v0     FrostbiteNoFrameskip-v4
# Gopher-v0                   Gopher-v4                   GopherNoFrameskip-v0
# GopherNoFrameskip-v4        Gravitar-v0                 Gravitar-v4
# GravitarNoFrameskip-v0      GravitarNoFrameskip-v4      Hero-v0
# Hero-v4                     HeroNoFrameskip-v0          HeroNoFrameskip-v4
# IceHockey-v0                IceHockey-v4                IceHockeyNoFrameskip-v0
# IceHockeyNoFrameskip-v4     Jamesbond-v0                Jamesbond-v4
# JamesbondNoFrameskip-v0     JamesbondNoFrameskip-v4     JourneyEscape-v0
# JourneyEscape-v4            JourneyEscapeNoFrameskip-v0 JourneyEscapeNoFrameskip-v4
# Kangaroo-v0                 Kangaroo-v4                 KangarooNoFrameskip-v0
# KangarooNoFrameskip-v4      Krull-v0                    Krull-v4
# KrullNoFrameskip-v0         KrullNoFrameskip-v4         KungFuMaster-v0
# KungFuMaster-v4             KungFuMasterNoFrameskip-v0  KungFuMasterNoFrameskip-v4
# MontezumaRevenge-v0         MontezumaRevenge-v4         MontezumaRevengeNoFrameskip-v0
# MontezumaRevengeNoFrameskip-v4 MsPacman-v0                 MsPacman-v4
# MsPacmanNoFrameskip-v0      MsPacmanNoFrameskip-v4      NameThisGame-v0
# NameThisGame-v4             NameThisGameNoFrameskip-v0  NameThisGameNoFrameskip-v4
# Phoenix-v0                  Phoenix-v4                  PhoenixNoFrameskip-v0
# PhoenixNoFrameskip-v4       Pitfall-v0                  Pitfall-v4
# PitfallNoFrameskip-v0       PitfallNoFrameskip-v4       Pong-v0
# Pong-v4                     PongNoFrameskip-v0          PongNoFrameskip-v4
# Pooyan-v0                   Pooyan-v4                   PooyanNoFrameskip-v0
# PooyanNoFrameskip-v4        PrivateEye-v0               PrivateEye-v4
# PrivateEyeNoFrameskip-v0    PrivateEyeNoFrameskip-v4    Qbert-v0
# Qbert-v4                    QbertNoFrameskip-v0         QbertNoFrameskip-v4
# Riverraid-v0                Riverraid-v4                RiverraidNoFrameskip-v0
# RiverraidNoFrameskip-v4     RoadRunner-v0               RoadRunner-v4
# RoadRunnerNoFrameskip-v0    RoadRunnerNoFrameskip-v4    Robotank-v0
# Robotank-v4                 RobotankNoFrameskip-v0      RobotankNoFrameskip-v4
# Seaquest-v0                 Seaquest-v4                 SeaquestNoFrameskip-v0
# SeaquestNoFrameskip-v4      Skiing-v0                   Skiing-v4
# SkiingNoFrameskip-v0        SkiingNoFrameskip-v4        Solaris-v0
# Solaris-v4                  SolarisNoFrameskip-v0       SolarisNoFrameskip-v4
# SpaceInvaders-v0            SpaceInvaders-v4            SpaceInvadersNoFrameskip-v0
# SpaceInvadersNoFrameskip-v4 StarGunner-v0               StarGunner-v4
# StarGunnerNoFrameskip-v0    StarGunnerNoFrameskip-v4    Tennis-v0
# Tennis-v4                   TennisNoFrameskip-v0        TennisNoFrameskip-v4
# TimePilot-v0                TimePilot-v4                TimePilotNoFrameskip-v0
# TimePilotNoFrameskip-v4     Tutankham-v0                Tutankham-v4
# TutankhamNoFrameskip-v0     TutankhamNoFrameskip-v4     UpNDown-v0
# UpNDown-v4                  UpNDownNoFrameskip-v0       UpNDownNoFrameskip-v4
# Venture-v0                  Venture-v4                  VentureNoFrameskip-v0
# VentureNoFrameskip-v4       VideoPinball-v0             VideoPinball-v4
# VideoPinballNoFrameskip-v0  VideoPinballNoFrameskip-v4  WizardOfWor-v0
# WizardOfWor-v4              WizardOfWorNoFrameskip-v0   WizardOfWorNoFrameskip-v4
# YarsRevenge-v0              YarsRevenge-v4              YarsRevengeNoFrameskip-v0
# YarsRevengeNoFrameskip-v4   Zaxxon-v0                   Zaxxon-v4
# ZaxxonNoFrameskip-v0        ZaxxonNoFrameskip-v4
# ===== ALE =====
# ALE/Adventure-v5            ALE/AirRaid-v5              ALE/Alien-v5
# ALE/Amidar-v5               ALE/Assault-v5              ALE/Asterix-v5
# ALE/Asteroids-v5            ALE/Atlantis-v5             ALE/Atlantis2-v5
# ALE/Backgammon-v5           ALE/BankHeist-v5            ALE/BasicMath-v5
# ALE/BattleZone-v5           ALE/BeamRider-v5            ALE/Berzerk-v5
# ALE/Blackjack-v5            ALE/Bowling-v5              ALE/Boxing-v5
# ALE/Breakout-v5             ALE/Carnival-v5             ALE/Casino-v5
# ALE/Centipede-v5            ALE/ChopperCommand-v5       ALE/CrazyClimber-v5
# ALE/Crossbow-v5             ALE/Darkchambers-v5         ALE/Defender-v5
# ALE/DemonAttack-v5          ALE/DonkeyKong-v5           ALE/DoubleDunk-v5
# ALE/Earthworld-v5           ALE/ElevatorAction-v5       ALE/Enduro-v5
# ALE/Entombed-v5             ALE/Et-v5                   ALE/FishingDerby-v5
# ALE/FlagCapture-v5          ALE/Freeway-v5              ALE/Frogger-v5
# ALE/Frostbite-v5            ALE/Galaxian-v5             ALE/Gopher-v5
# ALE/Gravitar-v5             ALE/Hangman-v5              ALE/HauntedHouse-v5
# ALE/Hero-v5                 ALE/HumanCannonball-v5      ALE/IceHockey-v5
# ALE/Jamesbond-v5            ALE/JourneyEscape-v5        ALE/Kaboom-v5
# ALE/Kangaroo-v5             ALE/KeystoneKapers-v5       ALE/KingKong-v5
# ALE/Klax-v5                 ALE/Koolaid-v5              ALE/Krull-v5
# ALE/KungFuMaster-v5         ALE/LaserGates-v5           ALE/LostLuggage-v5
# ALE/MarioBros-v5            ALE/MiniatureGolf-v5        ALE/MontezumaRevenge-v5
# ALE/MrDo-v5                 ALE/MsPacman-v5             ALE/NameThisGame-v5
# ALE/Othello-v5              ALE/Pacman-v5               ALE/Phoenix-v5
# ALE/Pitfall-v5              ALE/Pitfall2-v5             ALE/Pong-v5
# ALE/Pooyan-v5               ALE/PrivateEye-v5           ALE/Qbert-v5
# ALE/Riverraid-v5            ALE/RoadRunner-v5           ALE/Robotank-v5
# ALE/Seaquest-v5             ALE/SirLancelot-v5          ALE/Skiing-v5
# ALE/Solaris-v5              ALE/SpaceInvaders-v5        ALE/SpaceWar-v5
# ALE/StarGunner-v5           ALE/Superman-v5             ALE/Surround-v5
# ALE/Tennis-v5               ALE/Tetris-v5               ALE/TicTacToe3D-v5
# ALE/TimePilot-v5            ALE/Trondead-v5             ALE/Turmoil-v5
# ALE/Tutankham-v5            ALE/UpNDown-v5              ALE/Venture-v5
# ALE/VideoCheckers-v5        ALE/VideoChess-v5           ALE/VideoCube-v5
# ALE/VideoPinball-v5         ALE/WizardOfWor-v5          ALE/WordZapper-v5
# ALE/YarsRevenge-v5          ALE/Zaxxon-v5

# %%
import gymnasium as gym
import ale_py
import numpy as np
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from collections import deque

gym.register_envs(ale_py)


#FrameStack

class LazyFrames:
    def __init__(self, frames):
        self._frames = frames

    def __array__(self, dtype=None):
        out = np.concatenate(self._frames, axis=0)
        if dtype:
            out = out.astype(dtype)
        return out


class FrameStack:
    def __init__(self, env, k=4):
        self.env = env
        self.k = k
        self.frames = deque(maxlen=k)

    def reset(self):
        obs, info = self.env.reset()
        obs = np.expand_dims(obs, 0)
        for _ in range(self.k):
            self.frames.append(obs)
        return LazyFrames(list(self.frames)), info

    def step(self, action):
        obs, reward, terminated, truncated, info = self.env.step(action)
        obs = np.expand_dims(obs, 0)
        self.frames.append(obs)
        return LazyFrames(list(self.frames)), reward, terminated, truncated, info

    @property
    def action_space(self):
        return self.env.action_space

    @property
    def observation_space(self):
        return self.env.observation_space



# Atari Environment

def make_env():
    env = gym.make("ALE/SpaceInvaders-v5", frameskip=1)

    env = gym.wrappers.AtariPreprocessing(
        env,
        grayscale_obs=True,
        frame_skip=4,
        screen_size=84
    )

    env = FrameStack(env, k=4)
    return env



# CNN

class DQN(nn.Module):
    def __init__(self, action_dim):
        super().__init__()
        self.conv1 = nn.Conv2d(4, 16, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=4, stride=2)
        self.fc = nn.Linear(32 * 9 * 9, 256)
        self.out = nn.Linear(256, action_dim)

    def forward(self, x):
        x = x / 255.0
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = torch.flatten(x, 1)
        x = F.relu(self.fc(x))
        return self.out(x)



# Replay Buffer

class ReplayBuffer:
    def __init__(self, size=50_000):
        self.buffer = deque(maxlen=size)

    def add(self, s, a, r, ns, d):
        self.buffer.append((s, a, r, ns, d))

    def sample(self, batch):
        s, a, r, ns, d = zip(*random.sample(self.buffer, batch))
        return (
            np.array([np.array(x) for x in s], dtype=np.uint8),
            np.array(a),
            np.array(r),
            np.array([np.array(x) for x in ns], dtype=np.uint8),
            np.array(d),
        )

    def __len__(self):
        return len(self.buffer)



# DOUBLE DQN Agent for SpaceInvaders

class Agent:
    def __init__(self):
        self.env = make_env()
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


        self.n_actions = self.env.action_space.n
        print("Action space:", self.n_actions)


        self.policy = DQN(self.n_actions).to(self.device)
        self.target = DQN(self.n_actions).to(self.device)
        self.target.load_state_dict(self.policy.state_dict())

        self.optimizer = optim.Adam(self.policy.parameters(), lr=1e-4)
        self.buffer = ReplayBuffer()


        self.gamma = 0.99
        self.batch = 32
        self.update_target_every = 3000
        self.train_start = 10_000

        self.eps = 1.0
        self.eps_min = 0.05
        self.eps_decay = 400_000
        self.step = 0


    # ε-greedy action selection

    def act(self, state):
        self.step += 1
        self.eps = max(self.eps_min, 1 - self.step / self.eps_decay)

        if random.random() < self.eps:
            return random.randint(0, self.n_actions - 1)

        s = torch.tensor(np.array(state), dtype=torch.float32, device=self.device).unsqueeze(0)
        with torch.no_grad():
            return torch.argmax(self.policy(s)).item()


    # Training step

    def train_step(self):
        if len(self.buffer) < self.train_start:
            return

        s, a, r, ns, d = self.buffer.sample(self.batch)

        s = torch.tensor(s, dtype=torch.float32, device=self.device)
        ns = torch.tensor(ns, dtype=torch.float32, device=self.device)
        a = torch.tensor(a, device=self.device).unsqueeze(1)
        r = torch.tensor(r, dtype=torch.float32, device=self.device).unsqueeze(1)
        d = torch.tensor(d, dtype=torch.float32, device=self.device).unsqueeze(1)

        # Q(s, a)
        q = self.policy(s).gather(1, a)


        with torch.no_grad():
            best_actions = self.policy(ns).argmax(1).unsqueeze(1)
            next_q = self.target(ns).gather(1, best_actions)

            not_done = 1.0 - d
            target = r + self.gamma * next_q * not_done

        loss = F.smooth_l1_loss(q, target)

        self.optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.policy.parameters(), 5)
        self.optimizer.step()

        if self.step % self.update_target_every == 0:
            print("Target updated at step", self.step)
            self.target.load_state_dict(self.policy.state_dict())

    # Training Loop

    def train(self, episodes=500):
        for ep in range(1, episodes + 1):
            s, _ = self.env.reset()
            total_reward = 0

            for _ in range(10000):
                a = self.act(s)
                ns, r, terminated, truncated, _ = self.env.step(a)

                self.buffer.add(s, a, r, ns, terminated)
                self.train_step()

                s = ns
                total_reward += r

                if terminated or truncated:
                    break

            print(f"Episode {ep} | Reward: {total_reward} | Epsilon {self.eps:.3f}")



# RUN TRAINING

agent = Agent()
agent.train(episodes=1000)
# Out:
# Action space: 6
# Episode 1 | Reward: 210.0 | Epsilon 0.999
# Episode 2 | Reward: 105.0 | Epsilon 0.997
# Episode 3 | Reward: 410.0 | Epsilon 0.996
# Episode 4 | Reward: 210.0 | Epsilon 0.994
# Episode 5 | Reward: 210.0 | Epsilon 0.993
# Episode 6 | Reward: 80.0 | Epsilon 0.992
# Episode 7 | Reward: 65.0 | Epsilon 0.991
# Episode 8 | Reward: 65.0 | Epsilon 0.990
# Episode 9 | Reward: 120.0 | Epsilon 0.989
# Episode 10 | Reward: 110.0 | Epsilon 0.988
# Episode 11 | Reward: 410.0 | Epsilon 0.986
# Episode 12 | Reward: 180.0 | Epsilon 0.985
# Episode 13 | Reward: 120.0 | Epsilon 0.984
# Episode 14 | Reward: 30.0 | Epsilon 0.983
# Episode 15 | Reward: 185.0 | Epsilon 0.982
# Episode 16 | Reward: 110.0 | Epsilon 0.980
# Episode 17 | Reward: 80.0 | Epsilon 0.979
# Episode 18 | Reward: 150.0 | Epsilon 0.977
# Episode 19 | Reward: 150.0 | Epsilon 0.976
# Episode 20 | Reward: 75.0 | Epsilon 0.975
# Episode 21 | Reward: 110.0 | Epsilon 0.974
# Episode 22 | Reward: 120.0 | Epsilon 0.973
# Episode 23 | Reward: 180.0 | Epsilon 0.971
# Episode 24 | Reward: 135.0 | Epsilon 0.970
# Target updated at step 12000
# Episode 25 | Reward: 100.0 | Epsilon 0.969
# Episode 26 | Reward: 110.0 | Epsilon 0.968
# Episode 27 | Reward: 105.0 | Epsilon 0.967
# Episode 28 | Reward: 90.0 | Epsilon 0.966
# Episode 29 | Reward: 210.0 | Epsilon 0.964
# Target updated at step 15000
# Episode 30 | Reward: 230.0 | Epsilon 0.962
# Episode 31 | Reward: 105.0 | Epsilon 0.961
# Episode 32 | Reward: 15.0 | Epsilon 0.961
# Episode 33 | Reward: 155.0 | Epsilon 0.959
# Episode 34 | Reward: 180.0 | Epsilon 0.958
# Episode 35 | Reward: 160.0 | Epsilon 0.956
# Target updated at step 18000
# Episode 36 | Reward: 135.0 | Epsilon 0.955
# Episode 37 | Reward: 330.0 | Epsilon 0.953
# Episode 38 | Reward: 55.0 | Epsilon 0.952
# Episode 39 | Reward: 50.0 | Epsilon 0.951
# Episode 40 | Reward: 120.0 | Epsilon 0.950
# Episode 41 | Reward: 210.0 | Epsilon 0.949
# Target updated at step 21000
# Episode 42 | Reward: 210.0 | Epsilon 0.947
# Episode 43 | Reward: 255.0 | Epsilon 0.945
# Episode 44 | Reward: 65.0 | Epsilon 0.944
# Episode 45 | Reward: 125.0 | Epsilon 0.943
# Episode 46 | Reward: 100.0 | Epsilon 0.942
# Episode 47 | Reward: 90.0 | Epsilon 0.940
# Target updated at step 24000
# Episode 48 | Reward: 245.0 | Epsilon 0.939
# Episode 49 | Reward: 75.0 | Epsilon 0.938
# Episode 50 | Reward: 80.0 | Epsilon 0.937
# Episode 51 | Reward: 45.0 | Epsilon 0.936
# Episode 52 | Reward: 180.0 | Epsilon 0.935
# Episode 53 | Reward: 150.0 | Epsilon 0.934
# Episode 54 | Reward: 140.0 | Epsilon 0.933
# Target updated at step 27000
# Episode 55 | Reward: 190.0 | Epsilon 0.932
# Episode 56 | Reward: 110.0 | Epsilon 0.930
# Episode 57 | Reward: 65.0 | Epsilon 0.930
# Episode 58 | Reward: 100.0 | Epsilon 0.928
# Episode 59 | Reward: 275.0 | Epsilon 0.926
# Episode 60 | Reward: 135.0 | Epsilon 0.925
# Target updated at step 30000
# Episode 61 | Reward: 155.0 | Epsilon 0.924
# Episode 62 | Reward: 10.0 | Epsilon 0.923
# Episode 63 | Reward: 135.0 | Epsilon 0.922
# Episode 64 | Reward: 60.0 | Epsilon 0.921
# Episode 65 | Reward: 160.0 | Epsilon 0.919
# Episode 66 | Reward: 120.0 | Epsilon 0.918
# Target updated at step 33000
# Episode 67 | Reward: 35.0 | Epsilon 0.917
# Episode 68 | Reward: 245.0 | Epsilon 0.916
# Episode 69 | Reward: 210.0 | Epsilon 0.915
# Episode 70 | Reward: 110.0 | Epsilon 0.914
# Episode 71 | Reward: 30.0 | Epsilon 0.913
# Episode 72 | Reward: 180.0 | Epsilon 0.911
# Episode 73 | Reward: 105.0 | Epsilon 0.910
# Target updated at step 36000
# Episode 74 | Reward: 125.0 | Epsilon 0.909
# Episode 75 | Reward: 440.0 | Epsilon 0.906
# Episode 76 | Reward: 155.0 | Epsilon 0.905
# Episode 77 | Reward: 220.0 | Epsilon 0.904
# Episode 78 | Reward: 50.0 | Epsilon 0.903
# Target updated at step 39000
# Episode 79 | Reward: 350.0 | Epsilon 0.901
# Episode 80 | Reward: 210.0 | Epsilon 0.900
# Episode 81 | Reward: 150.0 | Epsilon 0.899
# Episode 82 | Reward: 65.0 | Epsilon 0.898
# Episode 83 | Reward: 675.0 | Epsilon 0.895
# Target updated at step 42000
# Episode 84 | Reward: 50.0 | Epsilon 0.895
# Episode 85 | Reward: 30.0 | Epsilon 0.894
# Episode 86 | Reward: 125.0 | Epsilon 0.893
# Episode 87 | Reward: 45.0 | Epsilon 0.892
# Episode 88 | Reward: 185.0 | Epsilon 0.890
# Episode 89 | Reward: 185.0 | Epsilon 0.889
# Episode 90 | Reward: 75.0 | Epsilon 0.888
# Target updated at step 45000
# Episode 91 | Reward: 155.0 | Epsilon 0.886
# Episode 92 | Reward: 130.0 | Epsilon 0.885
# Episode 93 | Reward: 285.0 | Epsilon 0.883
# Episode 94 | Reward: 155.0 | Epsilon 0.881
# Target updated at step 48000
# Episode 95 | Reward: 135.0 | Epsilon 0.880
# Episode 96 | Reward: 50.0 | Epsilon 0.879
# Episode 97 | Reward: 145.0 | Epsilon 0.877
# Episode 98 | Reward: 225.0 | Epsilon 0.876
# Episode 99 | Reward: 90.0 | Epsilon 0.875
# Target updated at step 51000
# Episode 100 | Reward: 360.0 | Epsilon 0.872
# Episode 101 | Reward: 140.0 | Epsilon 0.871
# Episode 102 | Reward: 210.0 | Epsilon 0.870
# Episode 103 | Reward: 185.0 | Epsilon 0.868
# Episode 104 | Reward: 155.0 | Epsilon 0.867
# Target updated at step 54000
# Episode 105 | Reward: 200.0 | Epsilon 0.865
# Episode 106 | Reward: 415.0 | Epsilon 0.863
# Episode 107 | Reward: 220.0 | Epsilon 0.861
# Episode 108 | Reward: 75.0 | Epsilon 0.860
# Episode 109 | Reward: 90.0 | Epsilon 0.859
# Episode 110 | Reward: 130.0 | Epsilon 0.858
# Target updated at step 57000
# Episode 111 | Reward: 155.0 | Epsilon 0.857
# Episode 112 | Reward: 210.0 | Epsilon 0.855
# Episode 113 | Reward: 30.0 | Epsilon 0.854
# Episode 114 | Reward: 135.0 | Epsilon 0.853
# Episode 115 | Reward: 160.0 | Epsilon 0.852
# Episode 116 | Reward: 125.0 | Epsilon 0.851
# Target updated at step 60000
# Episode 117 | Reward: 180.0 | Epsilon 0.849
# Episode 118 | Reward: 55.0 | Epsilon 0.849
# Episode 119 | Reward: 110.0 | Epsilon 0.848
# Episode 120 | Reward: 210.0 | Epsilon 0.846
# Episode 121 | Reward: 135.0 | Epsilon 0.845
# Episode 122 | Reward: 75.0 | Epsilon 0.844
# Episode 123 | Reward: 95.0 | Epsilon 0.843
# Target updated at step 63000
# Episode 124 | Reward: 35.0 | Epsilon 0.842
# Episode 125 | Reward: 45.0 | Epsilon 0.841
# Episode 126 | Reward: 65.0 | Epsilon 0.840
# Episode 127 | Reward: 65.0 | Epsilon 0.839
# Episode 128 | Reward: 215.0 | Epsilon 0.836
# Target updated at step 66000
# Episode 129 | Reward: 150.0 | Epsilon 0.835
# Episode 130 | Reward: 60.0 | Epsilon 0.834
# Episode 131 | Reward: 145.0 | Epsilon 0.833
# Episode 132 | Reward: 180.0 | Epsilon 0.831
# Episode 133 | Reward: 155.0 | Epsilon 0.830
# Episode 134 | Reward: 50.0 | Epsilon 0.829
# Episode 135 | Reward: 135.0 | Epsilon 0.828
# Target updated at step 69000
# Episode 136 | Reward: 225.0 | Epsilon 0.826
# Episode 137 | Reward: 170.0 | Epsilon 0.825
# Episode 138 | Reward: 110.0 | Epsilon 0.824
# Episode 139 | Reward: 545.0 | Epsilon 0.822
# Episode 140 | Reward: 165.0 | Epsilon 0.821
# Target updated at step 72000
# Episode 141 | Reward: 285.0 | Epsilon 0.819
# Episode 142 | Reward: 100.0 | Epsilon 0.818
# Episode 143 | Reward: 220.0 | Epsilon 0.815
# Episode 144 | Reward: 110.0 | Epsilon 0.814
# Episode 145 | Reward: 255.0 | Epsilon 0.813
# Target updated at step 75000
# Episode 146 | Reward: 50.0 | Epsilon 0.812
# Episode 147 | Reward: 120.0 | Epsilon 0.811
# Episode 148 | Reward: 410.0 | Epsilon 0.810
# Episode 149 | Reward: 270.0 | Epsilon 0.808
# Episode 150 | Reward: 150.0 | Epsilon 0.807
# Episode 151 | Reward: 155.0 | Epsilon 0.806
# Target updated at step 78000
# Episode 152 | Reward: 80.0 | Epsilon 0.805
# Episode 153 | Reward: 200.0 | Epsilon 0.803
# Episode 154 | Reward: 230.0 | Epsilon 0.802
# Episode 155 | Reward: 475.0 | Epsilon 0.800
# Episode 156 | Reward: 155.0 | Epsilon 0.798
# Episode 157 | Reward: 155.0 | Epsilon 0.798
# Target updated at step 81000
# Episode 158 | Reward: 110.0 | Epsilon 0.796
# Episode 159 | Reward: 145.0 | Epsilon 0.795
# Episode 160 | Reward: 160.0 | Epsilon 0.794
# Episode 161 | Reward: 125.0 | Epsilon 0.793
# Episode 162 | Reward: 55.0 | Epsilon 0.792
# Episode 163 | Reward: 285.0 | Epsilon 0.790
# Target updated at step 84000
# Episode 164 | Reward: 135.0 | Epsilon 0.789
# Episode 165 | Reward: 120.0 | Epsilon 0.788
# Episode 166 | Reward: 275.0 | Epsilon 0.786
# Episode 167 | Reward: 120.0 | Epsilon 0.785
# Episode 168 | Reward: 110.0 | Epsilon 0.784
# Episode 169 | Reward: 125.0 | Epsilon 0.783
# Target updated at step 87000
# Episode 170 | Reward: 80.0 | Epsilon 0.781
# Episode 171 | Reward: 155.0 | Epsilon 0.780
# Episode 172 | Reward: 155.0 | Epsilon 0.779
# Episode 173 | Reward: 35.0 | Epsilon 0.778
# Episode 174 | Reward: 155.0 | Epsilon 0.777
# Episode 175 | Reward: 35.0 | Epsilon 0.776
# Episode 176 | Reward: 105.0 | Epsilon 0.775
# Target updated at step 90000
# Episode 177 | Reward: 135.0 | Epsilon 0.774
# Episode 178 | Reward: 120.0 | Epsilon 0.773
# Episode 179 | Reward: 210.0 | Epsilon 0.771
# Episode 180 | Reward: 410.0 | Epsilon 0.769
# Episode 181 | Reward: 110.0 | Epsilon 0.768
# Target updated at step 93000
# Episode 182 | Reward: 110.0 | Epsilon 0.767
# Episode 183 | Reward: 210.0 | Epsilon 0.766
# Episode 184 | Reward: 180.0 | Epsilon 0.764
# Episode 185 | Reward: 230.0 | Epsilon 0.763
# Episode 186 | Reward: 80.0 | Epsilon 0.762
# Episode 187 | Reward: 305.0 | Epsilon 0.761
# Target updated at step 96000
# Episode 188 | Reward: 10.0 | Epsilon 0.760
# Episode 189 | Reward: 55.0 | Epsilon 0.759
# Episode 190 | Reward: 210.0 | Epsilon 0.758
# Episode 191 | Reward: 210.0 | Epsilon 0.757
# Episode 192 | Reward: 155.0 | Epsilon 0.755
# Episode 193 | Reward: 245.0 | Epsilon 0.754
# Target updated at step 99000
# Episode 194 | Reward: 155.0 | Epsilon 0.752
# Episode 195 | Reward: 155.0 | Epsilon 0.751
# Episode 196 | Reward: 85.0 | Epsilon 0.750
# Episode 197 | Reward: 115.0 | Epsilon 0.749
# Episode 198 | Reward: 125.0 | Epsilon 0.747
# Episode 199 | Reward: 155.0 | Epsilon 0.746
# Target updated at step 102000
# Episode 200 | Reward: 225.0 | Epsilon 0.745
# Episode 201 | Reward: 50.0 | Epsilon 0.744
# Episode 202 | Reward: 215.0 | Epsilon 0.743
# Episode 203 | Reward: 195.0 | Epsilon 0.741
# Episode 204 | Reward: 415.0 | Epsilon 0.739
# Episode 205 | Reward: 225.0 | Epsilon 0.738
# Target updated at step 105000
# Episode 206 | Reward: 310.0 | Epsilon 0.736
# Episode 207 | Reward: 120.0 | Epsilon 0.735
# Episode 208 | Reward: 130.0 | Epsilon 0.734
# Episode 209 | Reward: 110.0 | Epsilon 0.733
# Episode 210 | Reward: 160.0 | Epsilon 0.732
# Episode 211 | Reward: 70.0 | Epsilon 0.731
# Target updated at step 108000
# Episode 212 | Reward: 155.0 | Epsilon 0.730
# Episode 213 | Reward: 180.0 | Epsilon 0.728
# Episode 214 | Reward: 180.0 | Epsilon 0.727
# Episode 215 | Reward: 35.0 | Epsilon 0.727
# Episode 216 | Reward: 330.0 | Epsilon 0.724
# Episode 217 | Reward: 110.0 | Epsilon 0.723
# Target updated at step 111000
# Episode 218 | Reward: 180.0 | Epsilon 0.722
# Episode 219 | Reward: 225.0 | Epsilon 0.721
# Episode 220 | Reward: 110.0 | Epsilon 0.719
# Episode 221 | Reward: 265.0 | Epsilon 0.718
# Episode 222 | Reward: 85.0 | Epsilon 0.717
# Episode 223 | Reward: 160.0 | Epsilon 0.716
# Target updated at step 114000
# Episode 224 | Reward: 145.0 | Epsilon 0.714
# Episode 225 | Reward: 80.0 | Epsilon 0.713
# Episode 226 | Reward: 210.0 | Epsilon 0.712
# Episode 227 | Reward: 240.0 | Epsilon 0.710
# Episode 228 | Reward: 55.0 | Epsilon 0.709
# Episode 229 | Reward: 110.0 | Epsilon 0.708
# Target updated at step 117000
# Episode 230 | Reward: 75.0 | Epsilon 0.707
# Episode 231 | Reward: 175.0 | Epsilon 0.706
# Episode 232 | Reward: 210.0 | Epsilon 0.704
# Episode 233 | Reward: 135.0 | Epsilon 0.703
# Episode 234 | Reward: 375.0 | Epsilon 0.702
# Episode 235 | Reward: 120.0 | Epsilon 0.700
# Target updated at step 120000
# Episode 236 | Reward: 135.0 | Epsilon 0.699
# Episode 237 | Reward: 165.0 | Epsilon 0.698
# Episode 238 | Reward: 300.0 | Epsilon 0.695
# Episode 239 | Reward: 135.0 | Epsilon 0.694
# Episode 240 | Reward: 240.0 | Epsilon 0.693
# Target updated at step 123000
# Episode 241 | Reward: 530.0 | Epsilon 0.689
# Episode 242 | Reward: 185.0 | Epsilon 0.688
# Episode 243 | Reward: 210.0 | Epsilon 0.686
# Episode 244 | Reward: 185.0 | Epsilon 0.685
# Target updated at step 126000
# Episode 245 | Reward: 430.0 | Epsilon 0.683
# Episode 246 | Reward: 60.0 | Epsilon 0.683
# Episode 247 | Reward: 155.0 | Epsilon 0.681
# Episode 248 | Reward: 180.0 | Epsilon 0.680
# Episode 249 | Reward: 145.0 | Epsilon 0.678
# Target updated at step 129000
# Episode 250 | Reward: 145.0 | Epsilon 0.677
# Episode 251 | Reward: 150.0 | Epsilon 0.676
# Episode 252 | Reward: 115.0 | Epsilon 0.675
# Episode 253 | Reward: 135.0 | Epsilon 0.674
# Episode 254 | Reward: 275.0 | Epsilon 0.672
# Episode 255 | Reward: 135.0 | Epsilon 0.671
# Target updated at step 132000
# Episode 256 | Reward: 120.0 | Epsilon 0.670
# Episode 257 | Reward: 170.0 | Epsilon 0.668
# Episode 258 | Reward: 180.0 | Epsilon 0.667
# Episode 259 | Reward: 135.0 | Epsilon 0.666
# Episode 260 | Reward: 235.0 | Epsilon 0.664
# Target updated at step 135000
# Episode 261 | Reward: 215.0 | Epsilon 0.662
# Episode 262 | Reward: 85.0 | Epsilon 0.661
# Episode 263 | Reward: 155.0 | Epsilon 0.660
# Episode 264 | Reward: 105.0 | Epsilon 0.659
# Episode 265 | Reward: 415.0 | Epsilon 0.657
# Episode 266 | Reward: 210.0 | Epsilon 0.655
# Target updated at step 138000
# Episode 267 | Reward: 615.0 | Epsilon 0.653
# Episode 268 | Reward: 315.0 | Epsilon 0.651
# Episode 269 | Reward: 155.0 | Epsilon 0.650
# Episode 270 | Reward: 350.0 | Epsilon 0.648
# Target updated at step 141000
# Episode 271 | Reward: 220.0 | Epsilon 0.646
# Episode 272 | Reward: 400.0 | Epsilon 0.644
# Episode 273 | Reward: 55.0 | Epsilon 0.643
# Episode 274 | Reward: 235.0 | Epsilon 0.642
# Episode 275 | Reward: 275.0 | Epsilon 0.640
# Target updated at step 144000
# Episode 276 | Reward: 225.0 | Epsilon 0.639
# Episode 277 | Reward: 15.0 | Epsilon 0.638
# Episode 278 | Reward: 410.0 | Epsilon 0.636
# Episode 279 | Reward: 50.0 | Epsilon 0.636
# Episode 280 | Reward: 150.0 | Epsilon 0.634
# Episode 281 | Reward: 210.0 | Epsilon 0.633
# Target updated at step 147000
# Episode 282 | Reward: 140.0 | Epsilon 0.632
# Episode 283 | Reward: 225.0 | Epsilon 0.630
# Episode 284 | Reward: 120.0 | Epsilon 0.629
# Episode 285 | Reward: 55.0 | Epsilon 0.628
# Episode 286 | Reward: 285.0 | Epsilon 0.626
# Episode 287 | Reward: 115.0 | Epsilon 0.625
# Target updated at step 150000
# Episode 288 | Reward: 435.0 | Epsilon 0.624
# Episode 289 | Reward: 35.0 | Epsilon 0.623
# Episode 290 | Reward: 290.0 | Epsilon 0.621
# Episode 291 | Reward: 215.0 | Epsilon 0.619
# Target updated at step 153000
# Episode 292 | Reward: 500.0 | Epsilon 0.617
# Episode 293 | Reward: 315.0 | Epsilon 0.615
# Episode 294 | Reward: 255.0 | Epsilon 0.614
# Episode 295 | Reward: 135.0 | Epsilon 0.612
# Episode 296 | Reward: 45.0 | Epsilon 0.612
# Target updated at step 156000
# Episode 297 | Reward: 210.0 | Epsilon 0.610
# Episode 298 | Reward: 110.0 | Epsilon 0.609
# Episode 299 | Reward: 125.0 | Epsilon 0.608
# Episode 300 | Reward: 215.0 | Epsilon 0.607
# Episode 301 | Reward: 80.0 | Epsilon 0.606
# Episode 302 | Reward: 230.0 | Epsilon 0.604
# Episode 303 | Reward: 210.0 | Epsilon 0.603
# Target updated at step 159000
# Episode 304 | Reward: 125.0 | Epsilon 0.602
# Episode 305 | Reward: 65.0 | Epsilon 0.601
# Episode 306 | Reward: 140.0 | Epsilon 0.600
# Episode 307 | Reward: 105.0 | Epsilon 0.599
# Episode 308 | Reward: 165.0 | Epsilon 0.597
# Episode 309 | Reward: 235.0 | Epsilon 0.595
# Target updated at step 162000
# Episode 310 | Reward: 30.0 | Epsilon 0.595
# Episode 311 | Reward: 475.0 | Epsilon 0.593
# Episode 312 | Reward: 110.0 | Epsilon 0.592
# Episode 313 | Reward: 280.0 | Epsilon 0.590
# Episode 314 | Reward: 210.0 | Epsilon 0.588
# Target updated at step 165000
# Episode 315 | Reward: 260.0 | Epsilon 0.587
# Episode 316 | Reward: 110.0 | Epsilon 0.585
# Episode 317 | Reward: 125.0 | Epsilon 0.584
# Episode 318 | Reward: 315.0 | Epsilon 0.582
# Episode 319 | Reward: 135.0 | Epsilon 0.581
# Target updated at step 168000
# Episode 320 | Reward: 210.0 | Epsilon 0.580
# Episode 321 | Reward: 210.0 | Epsilon 0.578
# Episode 322 | Reward: 210.0 | Epsilon 0.576
# Episode 323 | Reward: 160.0 | Epsilon 0.575
# Episode 324 | Reward: 240.0 | Epsilon 0.574
# Episode 325 | Reward: 115.0 | Epsilon 0.573
# Target updated at step 171000
# Episode 326 | Reward: 155.0 | Epsilon 0.572
# Episode 327 | Reward: 225.0 | Epsilon 0.570
# Episode 328 | Reward: 260.0 | Epsilon 0.568
# Episode 329 | Reward: 160.0 | Epsilon 0.567
# Episode 330 | Reward: 260.0 | Epsilon 0.565
# Target updated at step 174000
# Episode 331 | Reward: 105.0 | Epsilon 0.564
# Episode 332 | Reward: 170.0 | Epsilon 0.563
# Episode 333 | Reward: 180.0 | Epsilon 0.561
# Episode 334 | Reward: 325.0 | Epsilon 0.559
# Episode 335 | Reward: 180.0 | Epsilon 0.558
# Target updated at step 177000
# Episode 336 | Reward: 160.0 | Epsilon 0.556
# Episode 337 | Reward: 210.0 | Epsilon 0.555
# Episode 338 | Reward: 110.0 | Epsilon 0.554
# Episode 339 | Reward: 105.0 | Epsilon 0.553
# Episode 340 | Reward: 320.0 | Epsilon 0.551
# Target updated at step 180000
# Episode 341 | Reward: 180.0 | Epsilon 0.550
# Episode 342 | Reward: 180.0 | Epsilon 0.548
# Episode 343 | Reward: 290.0 | Epsilon 0.547
# Episode 344 | Reward: 120.0 | Epsilon 0.545
# Episode 345 | Reward: 260.0 | Epsilon 0.544
# Episode 346 | Reward: 45.0 | Epsilon 0.543
# Target updated at step 183000
# Episode 347 | Reward: 215.0 | Epsilon 0.542
# Episode 348 | Reward: 270.0 | Epsilon 0.540
# Episode 349 | Reward: 110.0 | Epsilon 0.539
# Episode 350 | Reward: 210.0 | Epsilon 0.538
# Episode 351 | Reward: 295.0 | Epsilon 0.536
# Target updated at step 186000
# Episode 352 | Reward: 260.0 | Epsilon 0.534
# Episode 353 | Reward: 75.0 | Epsilon 0.533
# Episode 354 | Reward: 90.0 | Epsilon 0.532
# Episode 355 | Reward: 210.0 | Epsilon 0.530
# Episode 356 | Reward: 210.0 | Epsilon 0.529
# Target updated at step 189000
# Episode 357 | Reward: 135.0 | Epsilon 0.527
# Episode 358 | Reward: 455.0 | Epsilon 0.526
# Episode 359 | Reward: 275.0 | Epsilon 0.524
# Episode 360 | Reward: 210.0 | Epsilon 0.522
# Target updated at step 192000
# Episode 361 | Reward: 515.0 | Epsilon 0.519
# Episode 362 | Reward: 135.0 | Epsilon 0.518
# Episode 363 | Reward: 130.0 | Epsilon 0.517
# Episode 364 | Reward: 150.0 | Epsilon 0.516
# Episode 365 | Reward: 285.0 | Epsilon 0.515
# Episode 366 | Reward: 240.0 | Epsilon 0.513
# Target updated at step 195000
# Episode 367 | Reward: 255.0 | Epsilon 0.511
# Episode 368 | Reward: 225.0 | Epsilon 0.509
# Episode 369 | Reward: 390.0 | Epsilon 0.507
# Episode 370 | Reward: 120.0 | Epsilon 0.506
# Target updated at step 198000
# Episode 371 | Reward: 135.0 | Epsilon 0.505
# Episode 372 | Reward: 155.0 | Epsilon 0.504
# Episode 373 | Reward: 135.0 | Epsilon 0.502
# Episode 374 | Reward: 230.0 | Epsilon 0.500
# Target updated at step 201000
# Episode 375 | Reward: 620.0 | Epsilon 0.497
# Episode 376 | Reward: 210.0 | Epsilon 0.496
# Episode 377 | Reward: 105.0 | Epsilon 0.495
# Episode 378 | Reward: 105.0 | Epsilon 0.494
# Episode 379 | Reward: 345.0 | Epsilon 0.493
# Episode 380 | Reward: 285.0 | Epsilon 0.491
# Episode 381 | Reward: 135.0 | Epsilon 0.490
# Target updated at step 204000
# Episode 382 | Reward: 275.0 | Epsilon 0.488
# Episode 383 | Reward: 215.0 | Epsilon 0.487
# Episode 384 | Reward: 55.0 | Epsilon 0.486
# Episode 385 | Reward: 120.0 | Epsilon 0.485
# Episode 386 | Reward: 210.0 | Epsilon 0.483
# Target updated at step 207000
# Episode 387 | Reward: 345.0 | Epsilon 0.481
# Episode 388 | Reward: 140.0 | Epsilon 0.480
# Episode 389 | Reward: 210.0 | Epsilon 0.478
# Episode 390 | Reward: 420.0 | Epsilon 0.477
# Target updated at step 210000
# Episode 391 | Reward: 330.0 | Epsilon 0.475
# Episode 392 | Reward: 365.0 | Epsilon 0.474
# Episode 393 | Reward: 180.0 | Epsilon 0.472
# Episode 394 | Reward: 210.0 | Epsilon 0.471
# Episode 395 | Reward: 210.0 | Epsilon 0.469
# Episode 396 | Reward: 140.0 | Epsilon 0.468
# Target updated at step 213000
# Episode 397 | Reward: 140.0 | Epsilon 0.467
# Episode 398 | Reward: 100.0 | Epsilon 0.466
# Episode 399 | Reward: 105.0 | Epsilon 0.465
# Episode 400 | Reward: 210.0 | Epsilon 0.463
# Episode 401 | Reward: 180.0 | Epsilon 0.462
# Episode 402 | Reward: 225.0 | Epsilon 0.461
# Target updated at step 216000
# Episode 403 | Reward: 190.0 | Epsilon 0.459
# Episode 404 | Reward: 205.0 | Epsilon 0.458
# Episode 405 | Reward: 110.0 | Epsilon 0.457
# Episode 406 | Reward: 140.0 | Epsilon 0.455
# Episode 407 | Reward: 110.0 | Epsilon 0.454
# Target updated at step 219000
# Episode 408 | Reward: 330.0 | Epsilon 0.452
# Episode 409 | Reward: 195.0 | Epsilon 0.450
# Episode 410 | Reward: 105.0 | Epsilon 0.450
# Episode 411 | Reward: 75.0 | Epsilon 0.449
# Episode 412 | Reward: 210.0 | Epsilon 0.447
# Target updated at step 222000
# Episode 413 | Reward: 605.0 | Epsilon 0.445
# Episode 414 | Reward: 225.0 | Epsilon 0.443
# Episode 415 | Reward: 225.0 | Epsilon 0.442
# Episode 416 | Reward: 150.0 | Epsilon 0.440
# Episode 417 | Reward: 425.0 | Epsilon 0.438
# Target updated at step 225000
# Episode 418 | Reward: 215.0 | Epsilon 0.437
# Episode 419 | Reward: 115.0 | Epsilon 0.436
# Episode 420 | Reward: 135.0 | Epsilon 0.435
# Episode 421 | Reward: 225.0 | Epsilon 0.433
# Episode 422 | Reward: 200.0 | Epsilon 0.432
# Episode 423 | Reward: 115.0 | Epsilon 0.431
# Target updated at step 228000
# Episode 424 | Reward: 180.0 | Epsilon 0.429
# Episode 425 | Reward: 125.0 | Epsilon 0.428
# Episode 426 | Reward: 150.0 | Epsilon 0.427
# Episode 427 | Reward: 205.0 | Epsilon 0.426
# Episode 428 | Reward: 155.0 | Epsilon 0.425
# Episode 429 | Reward: 255.0 | Epsilon 0.423
# Target updated at step 231000
# Episode 430 | Reward: 570.0 | Epsilon 0.420
# Episode 431 | Reward: 155.0 | Epsilon 0.419
# Episode 432 | Reward: 375.0 | Epsilon 0.418
# Episode 433 | Reward: 310.0 | Epsilon 0.415
# Target updated at step 234000
# Episode 434 | Reward: 135.0 | Epsilon 0.414
# Episode 435 | Reward: 110.0 | Epsilon 0.413
# Episode 436 | Reward: 105.0 | Epsilon 0.412
# Episode 437 | Reward: 240.0 | Epsilon 0.410
# Episode 438 | Reward: 350.0 | Epsilon 0.409
# Episode 439 | Reward: 200.0 | Epsilon 0.408
# Target updated at step 237000
# Episode 440 | Reward: 280.0 | Epsilon 0.406
# Episode 441 | Reward: 435.0 | Epsilon 0.404
# Episode 442 | Reward: 395.0 | Epsilon 0.401
# Episode 443 | Reward: 80.0 | Epsilon 0.400
# Target updated at step 240000
# Episode 444 | Reward: 120.0 | Epsilon 0.399
# Episode 445 | Reward: 185.0 | Epsilon 0.398
# Episode 446 | Reward: 110.0 | Epsilon 0.397
# Episode 447 | Reward: 90.0 | Epsilon 0.396
# Episode 448 | Reward: 210.0 | Epsilon 0.394
# Episode 449 | Reward: 200.0 | Epsilon 0.393
# Target updated at step 243000
# Episode 450 | Reward: 210.0 | Epsilon 0.391
# Episode 451 | Reward: 170.0 | Epsilon 0.389
# Episode 452 | Reward: 120.0 | Epsilon 0.388
# Episode 453 | Reward: 210.0 | Epsilon 0.386
# Episode 454 | Reward: 110.0 | Epsilon 0.385
# Target updated at step 246000
# Episode 455 | Reward: 210.0 | Epsilon 0.384
# Episode 456 | Reward: 80.0 | Epsilon 0.383
# Episode 457 | Reward: 115.0 | Epsilon 0.382
# Episode 458 | Reward: 180.0 | Epsilon 0.380
# Episode 459 | Reward: 135.0 | Epsilon 0.379
# Episode 460 | Reward: 135.0 | Epsilon 0.378
# Target updated at step 249000
# Episode 461 | Reward: 55.0 | Epsilon 0.377
# Episode 462 | Reward: 475.0 | Epsilon 0.376
# Episode 463 | Reward: 155.0 | Epsilon 0.374
# Episode 464 | Reward: 110.0 | Epsilon 0.373
# Episode 465 | Reward: 265.0 | Epsilon 0.371
# Target updated at step 252000
# Episode 466 | Reward: 225.0 | Epsilon 0.370
# Episode 467 | Reward: 335.0 | Epsilon 0.368
# Episode 468 | Reward: 55.0 | Epsilon 0.368
# Episode 469 | Reward: 210.0 | Epsilon 0.366
# Episode 470 | Reward: 120.0 | Epsilon 0.365
# Episode 471 | Reward: 240.0 | Epsilon 0.363
# Target updated at step 255000
# Episode 472 | Reward: 155.0 | Epsilon 0.362
# Episode 473 | Reward: 105.0 | Epsilon 0.361
# Episode 474 | Reward: 65.0 | Epsilon 0.360
# Episode 475 | Reward: 255.0 | Epsilon 0.359
# Episode 476 | Reward: 190.0 | Epsilon 0.357
# Episode 477 | Reward: 525.0 | Epsilon 0.355
# Target updated at step 258000
# Episode 478 | Reward: 135.0 | Epsilon 0.354
# Episode 479 | Reward: 185.0 | Epsilon 0.352
# Episode 480 | Reward: 180.0 | Epsilon 0.351
# Episode 481 | Reward: 100.0 | Epsilon 0.350
# Episode 482 | Reward: 210.0 | Epsilon 0.348
# Target updated at step 261000
# Episode 483 | Reward: 140.0 | Epsilon 0.347
# Episode 484 | Reward: 135.0 | Epsilon 0.346
# Episode 485 | Reward: 135.0 | Epsilon 0.345
# Episode 486 | Reward: 205.0 | Epsilon 0.344
# Episode 487 | Reward: 330.0 | Epsilon 0.341
# Episode 488 | Reward: 195.0 | Epsilon 0.340
# Target updated at step 264000
# Episode 489 | Reward: 215.0 | Epsilon 0.339
# Episode 490 | Reward: 375.0 | Epsilon 0.337
# Episode 491 | Reward: 145.0 | Epsilon 0.336
# Episode 492 | Reward: 260.0 | Epsilon 0.334
# Target updated at step 267000
# Episode 493 | Reward: 210.0 | Epsilon 0.332
# Episode 494 | Reward: 210.0 | Epsilon 0.331
# Episode 495 | Reward: 355.0 | Epsilon 0.329
# Episode 496 | Reward: 210.0 | Epsilon 0.328
# Episode 497 | Reward: 215.0 | Epsilon 0.326
# Target updated at step 270000
# Episode 498 | Reward: 215.0 | Epsilon 0.324
# Episode 499 | Reward: 120.0 | Epsilon 0.324
# Episode 500 | Reward: 410.0 | Epsilon 0.321
# Episode 501 | Reward: 210.0 | Epsilon 0.320
# Episode 502 | Reward: 215.0 | Epsilon 0.318
# Target updated at step 273000
# Episode 503 | Reward: 210.0 | Epsilon 0.317
# Episode 504 | Reward: 225.0 | Epsilon 0.315
# Episode 505 | Reward: 145.0 | Epsilon 0.314
# Episode 506 | Reward: 105.0 | Epsilon 0.313
# Episode 507 | Reward: 210.0 | Epsilon 0.311
# Episode 508 | Reward: 150.0 | Epsilon 0.310
# Target updated at step 276000
# Episode 509 | Reward: 290.0 | Epsilon 0.308
# Episode 510 | Reward: 240.0 | Epsilon 0.306
# Episode 511 | Reward: 130.0 | Epsilon 0.305
# Episode 512 | Reward: 210.0 | Epsilon 0.304
# Episode 513 | Reward: 85.0 | Epsilon 0.303
# Target updated at step 279000
# Episode 514 | Reward: 210.0 | Epsilon 0.301
# Episode 515 | Reward: 500.0 | Epsilon 0.299
# Episode 516 | Reward: 240.0 | Epsilon 0.297
# Episode 517 | Reward: 310.0 | Epsilon 0.296
# Target updated at step 282000
# Episode 518 | Reward: 255.0 | Epsilon 0.294
# Episode 519 | Reward: 255.0 | Epsilon 0.293
# Episode 520 | Reward: 155.0 | Epsilon 0.291
# Episode 521 | Reward: 255.0 | Epsilon 0.290
# Episode 522 | Reward: 110.0 | Epsilon 0.289
# Target updated at step 285000
# Episode 523 | Reward: 335.0 | Epsilon 0.287
# Episode 524 | Reward: 165.0 | Epsilon 0.286
# Episode 525 | Reward: 105.0 | Epsilon 0.285
# Episode 526 | Reward: 325.0 | Epsilon 0.283
# Episode 527 | Reward: 80.0 | Epsilon 0.282
# Episode 528 | Reward: 210.0 | Epsilon 0.280
# Target updated at step 288000
# Episode 529 | Reward: 220.0 | Epsilon 0.279
# Episode 530 | Reward: 130.0 | Epsilon 0.278
# Episode 531 | Reward: 105.0 | Epsilon 0.277
# Episode 532 | Reward: 105.0 | Epsilon 0.276
# Episode 533 | Reward: 195.0 | Epsilon 0.275
# Episode 534 | Reward: 155.0 | Epsilon 0.273
# Target updated at step 291000
# Episode 535 | Reward: 135.0 | Epsilon 0.272
# Episode 536 | Reward: 135.0 | Epsilon 0.271
# Episode 537 | Reward: 290.0 | Epsilon 0.269
# Episode 538 | Reward: 320.0 | Epsilon 0.268
# Episode 539 | Reward: 300.0 | Epsilon 0.266
# Target updated at step 294000
# Episode 540 | Reward: 210.0 | Epsilon 0.265
# Episode 541 | Reward: 185.0 | Epsilon 0.263
# Episode 542 | Reward: 135.0 | Epsilon 0.262
# Episode 543 | Reward: 225.0 | Epsilon 0.261
# Episode 544 | Reward: 200.0 | Epsilon 0.259
# Episode 545 | Reward: 160.0 | Epsilon 0.258
# Target updated at step 297000
# Episode 546 | Reward: 120.0 | Epsilon 0.256
# Episode 547 | Reward: 230.0 | Epsilon 0.255
# Episode 548 | Reward: 205.0 | Epsilon 0.253
# Episode 549 | Reward: 185.0 | Epsilon 0.251
# Target updated at step 300000
# Episode 550 | Reward: 190.0 | Epsilon 0.250
# Episode 551 | Reward: 335.0 | Epsilon 0.248
# Episode 552 | Reward: 115.0 | Epsilon 0.247
# Episode 553 | Reward: 210.0 | Epsilon 0.245
# Episode 554 | Reward: 45.0 | Epsilon 0.245
# Episode 555 | Reward: 240.0 | Epsilon 0.243
# Target updated at step 303000
# Episode 556 | Reward: 105.0 | Epsilon 0.242
# Episode 557 | Reward: 170.0 | Epsilon 0.241
# Episode 558 | Reward: 255.0 | Epsilon 0.239
# Episode 559 | Reward: 235.0 | Epsilon 0.238
# Episode 560 | Reward: 220.0 | Epsilon 0.236
# Target updated at step 306000
# Episode 561 | Reward: 440.0 | Epsilon 0.234
# Episode 562 | Reward: 95.0 | Epsilon 0.234
# Episode 563 | Reward: 335.0 | Epsilon 0.232
# Episode 564 | Reward: 250.0 | Epsilon 0.230
# Episode 565 | Reward: 150.0 | Epsilon 0.229
# Episode 566 | Reward: 230.0 | Epsilon 0.228
# Target updated at step 309000
# Episode 567 | Reward: 185.0 | Epsilon 0.227
# Episode 568 | Reward: 565.0 | Epsilon 0.224
# Episode 569 | Reward: 185.0 | Epsilon 0.223
# Episode 570 | Reward: 165.0 | Epsilon 0.222
# Episode 571 | Reward: 195.0 | Epsilon 0.220
# Target updated at step 312000
# Episode 572 | Reward: 265.0 | Epsilon 0.218
# Episode 573 | Reward: 230.0 | Epsilon 0.217
# Episode 574 | Reward: 105.0 | Epsilon 0.216
# Episode 575 | Reward: 210.0 | Epsilon 0.214
# Target updated at step 315000
# Episode 576 | Reward: 365.0 | Epsilon 0.212
# Episode 577 | Reward: 180.0 | Epsilon 0.211
# Episode 578 | Reward: 395.0 | Epsilon 0.209
# Episode 579 | Reward: 210.0 | Epsilon 0.207
# Episode 580 | Reward: 90.0 | Epsilon 0.206
# Target updated at step 318000
# Episode 581 | Reward: 260.0 | Epsilon 0.205
# Episode 582 | Reward: 150.0 | Epsilon 0.204
# Episode 583 | Reward: 195.0 | Epsilon 0.202
# Episode 584 | Reward: 420.0 | Epsilon 0.200
# Episode 585 | Reward: 315.0 | Epsilon 0.199
# Episode 586 | Reward: 115.0 | Epsilon 0.198
# Target updated at step 321000
# Episode 587 | Reward: 445.0 | Epsilon 0.196
# Episode 588 | Reward: 120.0 | Epsilon 0.194
# Episode 589 | Reward: 575.0 | Epsilon 0.192
# Episode 590 | Reward: 210.0 | Epsilon 0.191
# Target updated at step 324000
# Episode 591 | Reward: 420.0 | Epsilon 0.188
# Episode 592 | Reward: 215.0 | Epsilon 0.186
# Episode 593 | Reward: 225.0 | Epsilon 0.185
# Episode 594 | Reward: 250.0 | Epsilon 0.183
# Target updated at step 327000
# Episode 595 | Reward: 575.0 | Epsilon 0.181
# Episode 596 | Reward: 240.0 | Epsilon 0.179
# Episode 597 | Reward: 670.0 | Epsilon 0.176
# Target updated at step 330000
# Episode 598 | Reward: 400.0 | Epsilon 0.174
# Episode 599 | Reward: 230.0 | Epsilon 0.172
# Episode 600 | Reward: 275.0 | Epsilon 0.171
# Episode 601 | Reward: 420.0 | Epsilon 0.169
# Target updated at step 333000
# Episode 602 | Reward: 135.0 | Epsilon 0.167
# Episode 603 | Reward: 160.0 | Epsilon 0.166
# Episode 604 | Reward: 215.0 | Epsilon 0.164
# Episode 605 | Reward: 295.0 | Epsilon 0.162
# Episode 606 | Reward: 65.0 | Epsilon 0.161
# Target updated at step 336000
# Episode 607 | Reward: 125.0 | Epsilon 0.160
# Episode 608 | Reward: 315.0 | Epsilon 0.158
# Episode 609 | Reward: 140.0 | Epsilon 0.156
# Episode 610 | Reward: 320.0 | Epsilon 0.154
# Target updated at step 339000
# Episode 611 | Reward: 385.0 | Epsilon 0.152
# Episode 612 | Reward: 315.0 | Epsilon 0.150
# Episode 613 | Reward: 140.0 | Epsilon 0.149
# Episode 614 | Reward: 135.0 | Epsilon 0.147
# Episode 615 | Reward: 125.0 | Epsilon 0.146
# Target updated at step 342000
# Episode 616 | Reward: 165.0 | Epsilon 0.145
# Episode 617 | Reward: 110.0 | Epsilon 0.144
# Episode 618 | Reward: 185.0 | Epsilon 0.142
# Episode 619 | Reward: 150.0 | Epsilon 0.140
# Episode 620 | Reward: 320.0 | Epsilon 0.138
# Target updated at step 345000
# Episode 621 | Reward: 135.0 | Epsilon 0.137
# Episode 622 | Reward: 250.0 | Epsilon 0.135
# Episode 623 | Reward: 330.0 | Epsilon 0.133
# Episode 624 | Reward: 235.0 | Epsilon 0.132
# Target updated at step 348000
# Episode 625 | Reward: 470.0 | Epsilon 0.130
# Episode 626 | Reward: 190.0 | Epsilon 0.128
# Episode 627 | Reward: 510.0 | Epsilon 0.126
# Episode 628 | Reward: 460.0 | Epsilon 0.124
# Episode 629 | Reward: 195.0 | Epsilon 0.123
# Target updated at step 351000
# Episode 630 | Reward: 180.0 | Epsilon 0.121
# Episode 631 | Reward: 240.0 | Epsilon 0.119
# Episode 632 | Reward: 385.0 | Epsilon 0.117
# Episode 633 | Reward: 260.0 | Epsilon 0.115
# Target updated at step 354000
# Episode 634 | Reward: 150.0 | Epsilon 0.114
# Episode 635 | Reward: 260.0 | Epsilon 0.112
# Episode 636 | Reward: 110.0 | Epsilon 0.111
# Episode 637 | Reward: 320.0 | Epsilon 0.110
# Episode 638 | Reward: 240.0 | Epsilon 0.108
# Target updated at step 357000
# Episode 639 | Reward: 220.0 | Epsilon 0.106
# Episode 640 | Reward: 385.0 | Epsilon 0.104
# Episode 641 | Reward: 310.0 | Epsilon 0.101
# Episode 642 | Reward: 30.0 | Epsilon 0.101
# Target updated at step 360000
# Episode 643 | Reward: 210.0 | Epsilon 0.099
# Episode 644 | Reward: 155.0 | Epsilon 0.098
# Episode 645 | Reward: 250.0 | Epsilon 0.096
# Episode 646 | Reward: 230.0 | Epsilon 0.094
# Episode 647 | Reward: 140.0 | Epsilon 0.093
# Target updated at step 363000
# Episode 648 | Reward: 270.0 | Epsilon 0.091
# Episode 649 | Reward: 130.0 | Epsilon 0.090
# Episode 650 | Reward: 185.0 | Epsilon 0.089
# Episode 651 | Reward: 220.0 | Epsilon 0.087
# Target updated at step 366000
# Episode 652 | Reward: 315.0 | Epsilon 0.085
# Episode 653 | Reward: 370.0 | Epsilon 0.083
# Episode 654 | Reward: 125.0 | Epsilon 0.082
# Episode 655 | Reward: 245.0 | Epsilon 0.081
# Episode 656 | Reward: 155.0 | Epsilon 0.080
# Episode 657 | Reward: 125.0 | Epsilon 0.079
# Episode 658 | Reward: 170.0 | Epsilon 0.078
# Target updated at step 369000
# Episode 659 | Reward: 310.0 | Epsilon 0.076
# Episode 660 | Reward: 330.0 | Epsilon 0.075
# Episode 661 | Reward: 210.0 | Epsilon 0.073
# Episode 662 | Reward: 355.0 | Epsilon 0.071
# Target updated at step 372000
# Episode 663 | Reward: 205.0 | Epsilon 0.069
# Episode 664 | Reward: 460.0 | Epsilon 0.067
# Episode 665 | Reward: 340.0 | Epsilon 0.066
# Episode 666 | Reward: 350.0 | Epsilon 0.064
# Target updated at step 375000
# Episode 667 | Reward: 170.0 | Epsilon 0.062
# Episode 668 | Reward: 340.0 | Epsilon 0.060
# Episode 669 | Reward: 400.0 | Epsilon 0.057
# Episode 670 | Reward: 340.0 | Epsilon 0.055
# Target updated at step 378000
# Episode 671 | Reward: 235.0 | Epsilon 0.054
# Episode 672 | Reward: 220.0 | Epsilon 0.052
# Episode 673 | Reward: 335.0 | Epsilon 0.050
# Episode 674 | Reward: 160.0 | Epsilon 0.050
# Episode 675 | Reward: 65.0 | Epsilon 0.050
# Target updated at step 381000
# Episode 676 | Reward: 310.0 | Epsilon 0.050
# Episode 677 | Reward: 235.0 | Epsilon 0.050
# Episode 678 | Reward: 350.0 | Epsilon 0.050
# Episode 679 | Reward: 425.0 | Epsilon 0.050
# Target updated at step 384000
# Episode 680 | Reward: 270.0 | Epsilon 0.050
# Episode 681 | Reward: 420.0 | Epsilon 0.050
# Episode 682 | Reward: 520.0 | Epsilon 0.050
# Episode 683 | Reward: 180.0 | Epsilon 0.050
# Episode 684 | Reward: 130.0 | Epsilon 0.050
# Target updated at step 387000
# Episode 685 | Reward: 120.0 | Epsilon 0.050
# Episode 686 | Reward: 105.0 | Epsilon 0.050
# Episode 687 | Reward: 175.0 | Epsilon 0.050
# Episode 688 | Reward: 440.0 | Epsilon 0.050
# Episode 689 | Reward: 285.0 | Epsilon 0.050
# Target updated at step 390000
# Episode 690 | Reward: 395.0 | Epsilon 0.050
# Episode 691 | Reward: 300.0 | Epsilon 0.050
# Episode 692 | Reward: 260.0 | Epsilon 0.050
# Episode 693 | Reward: 155.0 | Epsilon 0.050
# Episode 694 | Reward: 160.0 | Epsilon 0.050
# Target updated at step 393000
# Episode 695 | Reward: 105.0 | Epsilon 0.050
# Episode 696 | Reward: 185.0 | Epsilon 0.050
# Episode 697 | Reward: 200.0 | Epsilon 0.050
# Episode 698 | Reward: 250.0 | Epsilon 0.050
# Episode 699 | Reward: 400.0 | Epsilon 0.050
# Target updated at step 396000
# Episode 700 | Reward: 115.0 | Epsilon 0.050
# Episode 701 | Reward: 350.0 | Epsilon 0.050
# Episode 702 | Reward: 435.0 | Epsilon 0.050
# Episode 703 | Reward: 110.0 | Epsilon 0.050
# Target updated at step 399000
# Episode 704 | Reward: 220.0 | Epsilon 0.050
# Episode 705 | Reward: 210.0 | Epsilon 0.050
# Episode 706 | Reward: 640.0 | Epsilon 0.050
# Episode 707 | Reward: 205.0 | Epsilon 0.050
# Episode 708 | Reward: 235.0 | Epsilon 0.050
# Target updated at step 402000
# Episode 709 | Reward: 195.0 | Epsilon 0.050
# Episode 710 | Reward: 250.0 | Epsilon 0.050
# Episode 711 | Reward: 380.0 | Epsilon 0.050
# Episode 712 | Reward: 530.0 | Epsilon 0.050
# Target updated at step 405000
# Episode 713 | Reward: 330.0 | Epsilon 0.050
# Episode 714 | Reward: 105.0 | Epsilon 0.050
# Episode 715 | Reward: 255.0 | Epsilon 0.050
# Episode 716 | Reward: 185.0 | Epsilon 0.050
# Episode 717 | Reward: 280.0 | Epsilon 0.050
# Target updated at step 408000
# Episode 718 | Reward: 320.0 | Epsilon 0.050
# Episode 719 | Reward: 410.0 | Epsilon 0.050
# Episode 720 | Reward: 305.0 | Epsilon 0.050
# Episode 721 | Reward: 120.0 | Epsilon 0.050
# Episode 722 | Reward: 340.0 | Epsilon 0.050
# Target updated at step 411000
# Episode 723 | Reward: 365.0 | Epsilon 0.050
# Episode 724 | Reward: 495.0 | Epsilon 0.050
# Episode 725 | Reward: 240.0 | Epsilon 0.050
# Episode 726 | Reward: 445.0 | Epsilon 0.050
# Target updated at step 414000
# Episode 727 | Reward: 830.0 | Epsilon 0.050
# Episode 728 | Reward: 655.0 | Epsilon 0.050
# Episode 729 | Reward: 245.0 | Epsilon 0.050
# Target updated at step 417000
# Episode 730 | Reward: 340.0 | Epsilon 0.050
# Episode 731 | Reward: 195.0 | Epsilon 0.050
# Episode 732 | Reward: 455.0 | Epsilon 0.050
# Episode 733 | Reward: 210.0 | Epsilon 0.050
# Episode 734 | Reward: 450.0 | Epsilon 0.050
# Target updated at step 420000
# Episode 735 | Reward: 320.0 | Epsilon 0.050
# Episode 736 | Reward: 290.0 | Epsilon 0.050
# Episode 737 | Reward: 320.0 | Epsilon 0.050
# Episode 738 | Reward: 295.0 | Epsilon 0.050
# Target updated at step 423000
# Episode 739 | Reward: 290.0 | Epsilon 0.050
# Episode 740 | Reward: 165.0 | Epsilon 0.050
# Episode 741 | Reward: 275.0 | Epsilon 0.050
# Episode 742 | Reward: 215.0 | Epsilon 0.050
# Episode 743 | Reward: 245.0 | Epsilon 0.050
# Target updated at step 426000
# Episode 744 | Reward: 310.0 | Epsilon 0.050
# Episode 745 | Reward: 120.0 | Epsilon 0.050
# Episode 746 | Reward: 500.0 | Epsilon 0.050
# Episode 747 | Reward: 245.0 | Epsilon 0.050
# Episode 748 | Reward: 150.0 | Epsilon 0.050
# Target updated at step 429000
# Episode 749 | Reward: 380.0 | Epsilon 0.050
# Episode 750 | Reward: 330.0 | Epsilon 0.050
# Episode 751 | Reward: 510.0 | Epsilon 0.050
# Episode 752 | Reward: 180.0 | Epsilon 0.050
# Target updated at step 432000
# Episode 753 | Reward: 355.0 | Epsilon 0.050
# Episode 754 | Reward: 295.0 | Epsilon 0.050
# Episode 755 | Reward: 165.0 | Epsilon 0.050
# Episode 756 | Reward: 225.0 | Epsilon 0.050
# Episode 757 | Reward: 415.0 | Epsilon 0.050
# Target updated at step 435000
# Episode 758 | Reward: 225.0 | Epsilon 0.050
# Episode 759 | Reward: 280.0 | Epsilon 0.050
# Episode 760 | Reward: 805.0 | Epsilon 0.050
# Episode 761 | Reward: 340.0 | Epsilon 0.050
# Target updated at step 438000
# Episode 762 | Reward: 315.0 | Epsilon 0.050
# Episode 763 | Reward: 275.0 | Epsilon 0.050
# Episode 764 | Reward: 180.0 | Epsilon 0.050
# Episode 765 | Reward: 250.0 | Epsilon 0.050
# Episode 766 | Reward: 125.0 | Epsilon 0.050
# Target updated at step 441000
# Episode 767 | Reward: 270.0 | Epsilon 0.050
# Episode 768 | Reward: 405.0 | Epsilon 0.050
# Episode 769 | Reward: 240.0 | Epsilon 0.050
# Episode 770 | Reward: 295.0 | Epsilon 0.050
# Target updated at step 444000
# Episode 771 | Reward: 125.0 | Epsilon 0.050
# Episode 772 | Reward: 215.0 | Epsilon 0.050
# Episode 773 | Reward: 135.0 | Epsilon 0.050
# Episode 774 | Reward: 255.0 | Epsilon 0.050
# Episode 775 | Reward: 105.0 | Epsilon 0.050
# Episode 776 | Reward: 295.0 | Epsilon 0.050
# Target updated at step 447000
# Episode 777 | Reward: 350.0 | Epsilon 0.050
# Episode 778 | Reward: 410.0 | Epsilon 0.050
# Episode 779 | Reward: 515.0 | Epsilon 0.050
# Episode 780 | Reward: 210.0 | Epsilon 0.050
# Target updated at step 450000
# Episode 781 | Reward: 370.0 | Epsilon 0.050
# Episode 782 | Reward: 210.0 | Epsilon 0.050
# Episode 783 | Reward: 215.0 | Epsilon 0.050
# Episode 784 | Reward: 215.0 | Epsilon 0.050
# Episode 785 | Reward: 300.0 | Epsilon 0.050
# Target updated at step 453000
# Episode 786 | Reward: 515.0 | Epsilon 0.050
# Episode 787 | Reward: 220.0 | Epsilon 0.050
# Episode 788 | Reward: 230.0 | Epsilon 0.050
# Episode 789 | Reward: 345.0 | Epsilon 0.050
# Target updated at step 456000
# Episode 790 | Reward: 235.0 | Epsilon 0.050
# Episode 791 | Reward: 775.0 | Epsilon 0.050
# Episode 792 | Reward: 105.0 | Epsilon 0.050
# Episode 793 | Reward: 225.0 | Epsilon 0.050
# Target updated at step 459000
# Episode 794 | Reward: 130.0 | Epsilon 0.050
# Episode 795 | Reward: 120.0 | Epsilon 0.050
# Episode 796 | Reward: 285.0 | Epsilon 0.050
# Episode 797 | Reward: 435.0 | Epsilon 0.050
# Target updated at step 462000
# Episode 798 | Reward: 395.0 | Epsilon 0.050
# Episode 799 | Reward: 310.0 | Epsilon 0.050
# Episode 800 | Reward: 360.0 | Epsilon 0.050
# Episode 801 | Reward: 180.0 | Epsilon 0.050
# Episode 802 | Reward: 180.0 | Epsilon 0.050
# Episode 803 | Reward: 260.0 | Epsilon 0.050
# Target updated at step 465000
# Episode 804 | Reward: 215.0 | Epsilon 0.050
# Episode 805 | Reward: 225.0 | Epsilon 0.050
# Episode 806 | Reward: 315.0 | Epsilon 0.050
# Episode 807 | Reward: 345.0 | Epsilon 0.050
# Episode 808 | Reward: 195.0 | Epsilon 0.050
# Target updated at step 468000
# Episode 809 | Reward: 235.0 | Epsilon 0.050
# Episode 810 | Reward: 340.0 | Epsilon 0.050
# Episode 811 | Reward: 400.0 | Epsilon 0.050
# Episode 812 | Reward: 235.0 | Epsilon 0.050
# Target updated at step 471000
# Episode 813 | Reward: 335.0 | Epsilon 0.050
# Episode 814 | Reward: 440.0 | Epsilon 0.050
# Episode 815 | Reward: 205.0 | Epsilon 0.050
# Episode 816 | Reward: 230.0 | Epsilon 0.050
# Episode 817 | Reward: 555.0 | Epsilon 0.050
# Target updated at step 474000
# Episode 818 | Reward: 495.0 | Epsilon 0.050
# Episode 819 | Reward: 265.0 | Epsilon 0.050
# Episode 820 | Reward: 65.0 | Epsilon 0.050
# Episode 821 | Reward: 230.0 | Epsilon 0.050
# Target updated at step 477000
# Episode 822 | Reward: 330.0 | Epsilon 0.050
# Episode 823 | Reward: 230.0 | Epsilon 0.050
# Episode 824 | Reward: 385.0 | Epsilon 0.050
# Episode 825 | Reward: 255.0 | Epsilon 0.050
# Episode 826 | Reward: 165.0 | Epsilon 0.050
# Target updated at step 480000
# Episode 827 | Reward: 500.0 | Epsilon 0.050
# Episode 828 | Reward: 305.0 | Epsilon 0.050
# Episode 829 | Reward: 380.0 | Epsilon 0.050
# Episode 830 | Reward: 145.0 | Epsilon 0.050
# Episode 831 | Reward: 295.0 | Epsilon 0.050
# Target updated at step 483000
# Episode 832 | Reward: 550.0 | Epsilon 0.050
# Episode 833 | Reward: 210.0 | Epsilon 0.050
# Episode 834 | Reward: 375.0 | Epsilon 0.050
# Episode 835 | Reward: 450.0 | Epsilon 0.050
# Target updated at step 486000
# Episode 836 | Reward: 60.0 | Epsilon 0.050
# Episode 837 | Reward: 285.0 | Epsilon 0.050
# Episode 838 | Reward: 670.0 | Epsilon 0.050
# Episode 839 | Reward: 370.0 | Epsilon 0.050
# Episode 840 | Reward: 165.0 | Epsilon 0.050
# Target updated at step 489000
# Episode 841 | Reward: 355.0 | Epsilon 0.050
# Episode 842 | Reward: 205.0 | Epsilon 0.050
# Episode 843 | Reward: 340.0 | Epsilon 0.050
# Episode 844 | Reward: 360.0 | Epsilon 0.050
# Target updated at step 492000
# Episode 845 | Reward: 265.0 | Epsilon 0.050
# Episode 846 | Reward: 325.0 | Epsilon 0.050
# Episode 847 | Reward: 205.0 | Epsilon 0.050
# Episode 848 | Reward: 270.0 | Epsilon 0.050
# Episode 849 | Reward: 280.0 | Epsilon 0.050
# Target updated at step 495000
# Episode 850 | Reward: 500.0 | Epsilon 0.050
# Episode 851 | Reward: 390.0 | Epsilon 0.050
# Episode 852 | Reward: 430.0 | Epsilon 0.050
# Episode 853 | Reward: 115.0 | Epsilon 0.050
# Target updated at step 498000
# Episode 854 | Reward: 285.0 | Epsilon 0.050
# Episode 855 | Reward: 410.0 | Epsilon 0.050
# Episode 856 | Reward: 340.0 | Epsilon 0.050
# Episode 857 | Reward: 345.0 | Epsilon 0.050
# Episode 858 | Reward: 270.0 | Epsilon 0.050
# Target updated at step 501000
# Episode 859 | Reward: 555.0 | Epsilon 0.050
# Episode 860 | Reward: 525.0 | Epsilon 0.050
# Episode 861 | Reward: 220.0 | Epsilon 0.050
# Episode 862 | Reward: 345.0 | Epsilon 0.050
# Target updated at step 504000
# Episode 863 | Reward: 375.0 | Epsilon 0.050
# Episode 864 | Reward: 350.0 | Epsilon 0.050
# Episode 865 | Reward: 395.0 | Epsilon 0.050
# Episode 866 | Reward: 395.0 | Epsilon 0.050
# Target updated at step 507000
# Episode 867 | Reward: 345.0 | Epsilon 0.050
# Episode 868 | Reward: 265.0 | Epsilon 0.050
# Episode 869 | Reward: 375.0 | Epsilon 0.050
# Episode 870 | Reward: 215.0 | Epsilon 0.050
# Episode 871 | Reward: 405.0 | Epsilon 0.050
# Target updated at step 510000
# Episode 872 | Reward: 230.0 | Epsilon 0.050
# Episode 873 | Reward: 280.0 | Epsilon 0.050
# Episode 874 | Reward: 390.0 | Epsilon 0.050
# Episode 875 | Reward: 290.0 | Epsilon 0.050
# Episode 876 | Reward: 220.0 | Epsilon 0.050
# Target updated at step 513000
# Episode 877 | Reward: 210.0 | Epsilon 0.050
# Episode 878 | Reward: 590.0 | Epsilon 0.050
# Episode 879 | Reward: 355.0 | Epsilon 0.050
# Episode 880 | Reward: 420.0 | Epsilon 0.050
# Episode 881 | Reward: 255.0 | Epsilon 0.050
# Target updated at step 516000
# Episode 882 | Reward: 130.0 | Epsilon 0.050
# Episode 883 | Reward: 285.0 | Epsilon 0.050
# Episode 884 | Reward: 215.0 | Epsilon 0.050
# Episode 885 | Reward: 285.0 | Epsilon 0.050
# Episode 886 | Reward: 255.0 | Epsilon 0.050
# Target updated at step 519000
# Episode 887 | Reward: 515.0 | Epsilon 0.050
# Episode 888 | Reward: 385.0 | Epsilon 0.050
# Episode 889 | Reward: 235.0 | Epsilon 0.050
# Episode 890 | Reward: 460.0 | Epsilon 0.050
# Episode 891 | Reward: 240.0 | Epsilon 0.050
# Target updated at step 522000
# Episode 892 | Reward: 160.0 | Epsilon 0.050
# Episode 893 | Reward: 510.0 | Epsilon 0.050
# Episode 894 | Reward: 290.0 | Epsilon 0.050
# Episode 895 | Reward: 205.0 | Epsilon 0.050
# Target updated at step 525000
# Episode 896 | Reward: 380.0 | Epsilon 0.050
# Episode 897 | Reward: 400.0 | Epsilon 0.050
# Episode 898 | Reward: 250.0 | Epsilon 0.050
# Episode 899 | Reward: 320.0 | Epsilon 0.050
# Target updated at step 528000
# Episode 900 | Reward: 505.0 | Epsilon 0.050
# Episode 901 | Reward: 35.0 | Epsilon 0.050
# Episode 902 | Reward: 495.0 | Epsilon 0.050
# Episode 903 | Reward: 705.0 | Epsilon 0.050
# Target updated at step 531000
# Episode 904 | Reward: 790.0 | Epsilon 0.050
# Episode 905 | Reward: 310.0 | Epsilon 0.050
# Episode 906 | Reward: 270.0 | Epsilon 0.050
# Episode 907 | Reward: 310.0 | Epsilon 0.050
# Episode 908 | Reward: 325.0 | Epsilon 0.050
# Target updated at step 534000
# Episode 909 | Reward: 455.0 | Epsilon 0.050
# Episode 910 | Reward: 470.0 | Epsilon 0.050
# Episode 911 | Reward: 360.0 | Epsilon 0.050
# Target updated at step 537000
# Episode 912 | Reward: 375.0 | Epsilon 0.050
# Episode 913 | Reward: 355.0 | Epsilon 0.050
# Episode 914 | Reward: 360.0 | Epsilon 0.050
# Episode 915 | Reward: 290.0 | Epsilon 0.050
# Episode 916 | Reward: 225.0 | Epsilon 0.050
# Target updated at step 540000
# Episode 917 | Reward: 555.0 | Epsilon 0.050
# Episode 918 | Reward: 365.0 | Epsilon 0.050
# Episode 919 | Reward: 295.0 | Epsilon 0.050
# Episode 920 | Reward: 415.0 | Epsilon 0.050
# Target updated at step 543000
# Episode 921 | Reward: 340.0 | Epsilon 0.050
# Episode 922 | Reward: 415.0 | Epsilon 0.050
# Episode 923 | Reward: 395.0 | Epsilon 0.050
# Episode 924 | Reward: 305.0 | Epsilon 0.050
# Target updated at step 546000
# Episode 925 | Reward: 175.0 | Epsilon 0.050
# Episode 926 | Reward: 485.0 | Epsilon 0.050
# Episode 927 | Reward: 120.0 | Epsilon 0.050
# Episode 928 | Reward: 490.0 | Epsilon 0.050
# Target updated at step 549000
# Episode 929 | Reward: 405.0 | Epsilon 0.050
# Episode 930 | Reward: 220.0 | Epsilon 0.050
# Episode 931 | Reward: 670.0 | Epsilon 0.050
# Episode 932 | Reward: 405.0 | Epsilon 0.050
# Target updated at step 552000
# Episode 933 | Reward: 365.0 | Epsilon 0.050
# Episode 934 | Reward: 170.0 | Epsilon 0.050
# Episode 935 | Reward: 75.0 | Epsilon 0.050
# Episode 936 | Reward: 740.0 | Epsilon 0.050
# Episode 937 | Reward: 310.0 | Epsilon 0.050
# Target updated at step 555000
# Episode 938 | Reward: 685.0 | Epsilon 0.050
# Episode 939 | Reward: 345.0 | Epsilon 0.050
# Episode 940 | Reward: 265.0 | Epsilon 0.050
# Episode 941 | Reward: 310.0 | Epsilon 0.050
# Target updated at step 558000
# Episode 942 | Reward: 335.0 | Epsilon 0.050
# Episode 943 | Reward: 480.0 | Epsilon 0.050
# Episode 944 | Reward: 185.0 | Epsilon 0.050
# Episode 945 | Reward: 250.0 | Epsilon 0.050
# Target updated at step 561000
# Episode 946 | Reward: 685.0 | Epsilon 0.050
# Episode 947 | Reward: 180.0 | Epsilon 0.050
# Episode 948 | Reward: 155.0 | Epsilon 0.050
# Episode 949 | Reward: 210.0 | Epsilon 0.050
# Episode 950 | Reward: 260.0 | Epsilon 0.050
# Target updated at step 564000
# Episode 951 | Reward: 235.0 | Epsilon 0.050
# Episode 952 | Reward: 340.0 | Epsilon 0.050
# Episode 953 | Reward: 240.0 | Epsilon 0.050
# Episode 954 | Reward: 150.0 | Epsilon 0.050
# Episode 955 | Reward: 365.0 | Epsilon 0.050
# Target updated at step 567000
# Episode 956 | Reward: 245.0 | Epsilon 0.050
# Episode 957 | Reward: 235.0 | Epsilon 0.050
# Episode 958 | Reward: 230.0 | Epsilon 0.050
# Episode 959 | Reward: 430.0 | Epsilon 0.050
# Target updated at step 570000
# Episode 960 | Reward: 400.0 | Epsilon 0.050
# Episode 961 | Reward: 230.0 | Epsilon 0.050
# Episode 962 | Reward: 575.0 | Epsilon 0.050
# Episode 963 | Reward: 470.0 | Epsilon 0.050
# Episode 964 | Reward: 110.0 | Epsilon 0.050
# Target updated at step 573000
# Episode 965 | Reward: 160.0 | Epsilon 0.050
# Episode 966 | Reward: 440.0 | Epsilon 0.050
# Episode 967 | Reward: 290.0 | Epsilon 0.050
# Episode 968 | Reward: 435.0 | Epsilon 0.050
# Episode 969 | Reward: 375.0 | Epsilon 0.050
# Target updated at step 576000
# Episode 970 | Reward: 350.0 | Epsilon 0.050
# Episode 971 | Reward: 490.0 | Epsilon 0.050
# Episode 972 | Reward: 655.0 | Epsilon 0.050
# Target updated at step 579000
# Episode 973 | Reward: 355.0 | Epsilon 0.050
# Episode 974 | Reward: 210.0 | Epsilon 0.050
# Episode 975 | Reward: 185.0 | Epsilon 0.050
# Episode 976 | Reward: 355.0 | Epsilon 0.050
# Episode 977 | Reward: 195.0 | Epsilon 0.050
# Target updated at step 582000
# Episode 978 | Reward: 460.0 | Epsilon 0.050
# Episode 979 | Reward: 165.0 | Epsilon 0.050
# Episode 980 | Reward: 285.0 | Epsilon 0.050
# Episode 981 | Reward: 580.0 | Epsilon 0.050
# Episode 982 | Reward: 280.0 | Epsilon 0.050
# Target updated at step 585000
# Episode 983 | Reward: 235.0 | Epsilon 0.050
# Episode 984 | Reward: 230.0 | Epsilon 0.050
# Episode 985 | Reward: 260.0 | Epsilon 0.050
# Episode 986 | Reward: 475.0 | Epsilon 0.050
# Target updated at step 588000
# Episode 987 | Reward: 610.0 | Epsilon 0.050
# Episode 988 | Reward: 415.0 | Epsilon 0.050
# Episode 989 | Reward: 370.0 | Epsilon 0.050
# Episode 990 | Reward: 485.0 | Epsilon 0.050
# Target updated at step 591000
# Episode 991 | Reward: 385.0 | Epsilon 0.050
# Episode 992 | Reward: 370.0 | Epsilon 0.050
# Episode 993 | Reward: 420.0 | Epsilon 0.050
# Episode 994 | Reward: 490.0 | Epsilon 0.050
# Target updated at step 594000
# Episode 995 | Reward: 345.0 | Epsilon 0.050
# Episode 996 | Reward: 490.0 | Epsilon 0.050
# Episode 997 | Reward: 315.0 | Epsilon 0.050
# Episode 998 | Reward: 495.0 | Epsilon 0.050
# Target updated at step 597000
# Episode 999 | Reward: 250.0 | Epsilon 0.050
# Episode 1000 | Reward: 285.0 | Epsilon 0.050

# %%
torch.save(agent.policy.state_dict(), "SpaceInvaders_double_dqn.pth")

# %%
import re
import matplotlib.pyplot as plt

# Load file
log_path = "/content/space_invaders_double_dqn_results.txt"
with open(log_path, "r") as f:
    lines = f.readlines()

episodes = []
rewards = []


pattern = r"Episode\s+(\d+)\s*\|\s*Reward:\s*(-?\d+\.?\d*)"

for line in lines:
    match = re.search(pattern, line)
    if match:
        ep = int(match.group(1))
        rew = float(match.group(2))
        episodes.append(ep)
        rewards.append(rew)

print("Parsed episodes:", len(episodes))


plt.figure(figsize=(14,6))
plt.plot(episodes, rewards, alpha=0.4, label="Reward (raw)")

# Moving average smoothing
import numpy as np
window = 20
if len(rewards) >= window:
    smooth = np.convolve(rewards, np.ones(window)/window, mode='valid')
    plt.plot(episodes[window-1:], smooth, color='red', linewidth=2, label=f"Moving Avg ({window})")

plt.title("Double DQN Training Reward Over Time (Space Invaders)")
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Parsed episodes: 1000

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

policy = DQN(action_dim=6).to(device)

MODEL_PATH = "/content/SpaceInvaders_double_dqn.pth"  # <-- your file

policy.load_state_dict(torch.load(MODEL_PATH, map_location=device))
policy.eval()

print("Model loaded!")
# Out:
# Model loaded!

# %%
import gymnasium as gym
import ale_py
import numpy as np
import torch
from collections import deque
from gymnasium.wrappers import RecordVideo

# %%
class LazyFrames:
    def __init__(self, frames):
        self._frames = frames

    def __array__(self, dtype=None):
        out = np.concatenate(self._frames, axis=0)
        if dtype:
            out = out.astype(dtype)
        return out


class FrameStack:
    def __init__(self, env, k=4):
        self.env = env
        self.k = k
        self.frames = deque(maxlen=k)

    def reset(self):
        obs, info = self.env.reset()
        processed = np.expand_dims(obs, 0)
        for _ in range(self.k):
            self.frames.append(processed)
        return LazyFrames(list(self.frames)), info

    def step(self, action):
        obs, reward, terminated, truncated, info = self.env.step(action)
        obs = np.expand_dims(obs, 0)
        self.frames.append(obs)
        return LazyFrames(list(self.frames)), reward, terminated, truncated, info

    def close(self):
        if hasattr(self.env, "close"):
            self.env.close()

# %%
def make_eval_env():

    env = gym.make("ALE/SpaceInvaders-v5", render_mode="rgb_array")


    env = gym.wrappers.AtariPreprocessing(
        env,
        grayscale_obs=True,
        frame_skip=1,
        screen_size=84
    )


    env = RecordVideo(
        env,
        video_folder="/content/spaceinvaders_double_dqn_eval/",
        episode_trigger=lambda ep: True
    )


    env = FrameStack(env, k=4)

    return env

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


policy.eval()

env = make_eval_env()
obs, _ = env.reset()

done = False
total_reward = 0

while not done:
    s = torch.tensor(np.array(obs), dtype=torch.float32, device=device).unsqueeze(0)

    with torch.no_grad():
        action = torch.argmax(policy(s)).item()

    obs, reward, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
    total_reward += reward

print(" Episode reward:", total_reward)


try:
    env.env.close()
except:
    pass
# Out:
#  Episode reward: 380.0
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
#   IMAGEMAGICK_BINARY = r"C:\Program Files\ImageMagick-6.8.8-Q16\magick.exe"
